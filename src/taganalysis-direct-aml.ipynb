# %%
import ast
import os
import glob
import itertools as it
import copy
import collections as cc
import pandas as pd
import spacy as sp
import torch as tc
import torch.nn
import torch.cuda
import torch.linalg as tcl
import torch.utils.data as tcd
import logging
import numpy as np
import numpy.random as npr
import argparse

import transformers as transf
import azureml.core as aml

from transformers import BertModel, BertConfig, BertForMaskedLM, BertTokenizer, AdamW
from azureml.core import Run
from enum import Flag

# %%
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)
logging.basicConfig(filename = "./log/logTagAnalysis.txt", format = '%(asctime)s - %(levelname)s - %(name)s -   %(message)s',
                    datefmt = '%m/%d/%Y %H:%M:%S',
                    level = logging.INFO)

__amlrun = Run.get_context()

# %%
class DebugOption(Flag):
    Empty = 0
    General = 1
    ScoreAgg = 2
    Eval = 4

class TrainingConfig:
    def initDevice(self, _useGPU = False):
        logger_ = logging.getLogger(TrainingConfig.__name__)        
        if _useGPU and self.debug == DebugOption.Empty:
            logger_.info("Use GPU Enabled")
            if tc.cuda.is_available():
                self.device = tc.device("cuda")
                logger_.info("GPU initialized")
                return
            else:
                logger_.info("GPU fail to initialize")
        else:
            logger_.info("Use GPU Disabled (or in debugging)")
        logger_.info("Use CPU by default")
        self.device = tc.device("cpu")

    def __init__(self):
        self.learningRate = 0.00005
        self.weightDecay = 0.01
        self.maxSentenceLength = 256
        self.device = tc.device("cpu")
        self.evalEpochs = 1
        self.evalEpochSize = 2500
        self.epochSize = 2500
        self.batchSize = 32
        self.batchAccumulation = 2
        self.epochs = 1
        self.warmUp = 0.2
        self.removeAggBias = 1
        self.maskRate = 0.25
        self.debug = DebugOption.Empty
        self.dataInputPath = "./data/clean/"
        self.dataModelPath = "./models/"
        
    
    def __str__(self):
        return str(vars(self))

# %%
# Global config
__config = TrainingConfig()

# %% [markdown]
# ## Global States

# %%
# Global models
__model = BertForMaskedLM.from_pretrained('bert-base-uncased').to(__config.device)
__tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Global states
__curEpoch = 0
__extraTokens = dict()
__batchTokens = set()

# %%
def saveCheckpoint(_name):
    state_ = {"epoch": __curEpoch, "model" : __model.state_dict(), "extratokens" : __extraTokens}

    tc.save(state_, os.path.join(__config.dataModelPath, _name + ".chk"))
    
def loadCheckpoint(_name):
    global __curEpoch
    global __extraTokens

    state_ = tc.load(os.path.join(__config.dataModelPath, _name + ".chk"), map_location = __config.device)
    __model.load_state_dict(state_["model"])
    __curEpoch = state_["iteration"]
    __extraTokens = state_["extratokens"]
    for token_ in __extraTokens.values():
        token_.to(__config.device)

# %% [markdown]
# ## Data Prep

# %%
def toList(_str):
    try:
        return ast.literal_eval(_str.replace('-', ' '))
    except Exception:
        if "nan" in _str:
            return toList(_str.replace("nan", "''"))
        else:
            return []

# %%
def subTokens(_target, _candidates):
    res_ = [0] * len(_target)
    for k, c in enumerate(_candidates):
        for i, t in enumerate(_target):
            if i + len(c) > len(_target):
                break
            if res_[i] or t != c[0]:
                continue
            for j, w in enumerate(c):
                if w != _target[i + j] or res_[i + j]:
                    break
            else:
                for j in range(i, i + len(c)):
                    res_[j] = k + 1
    return res_
print(subTokens(['abcd', 'def', 'zzz', 'zzz'], [['abc', 'def'], ['def', 'zzz'], ['zzz'], ['xyz']]))
print(subTokens(['that', 'is', 'the', 'right'], [['is', 'the'], ['thats', 'is'], ['is'], ['the', 'right']]))
# Out:
# [0, 2, 2, 3]
# [0, 1, 1, 0]

# %%
def resetEpoch(_vers = 0, _push = True):
    logger_ = logging.getLogger(resetEpoch.__name__)
    
    global __curEpoch
    __curEpoch = _vers    
    assert len(__batchTokens) == 0
    
    logger_.info("Before push extra token count: " + str(len(__extraTokens.values())))
    for sc_ in list(__extraTokens.values()):
        sc_.version = _vers
        if _push:
            if sc_.push() == 0:
                del __extraTokens[sc_.name]
    
    logger_.info("Post push extra token count: " + str(len(__extraTokens.values())))

# %%
class Scores:
    def __init__(self, _words, _embedding, _isEval):        
        self.assign(0, -1)
        self.num = 0
        self.name = _words
        self.tensor = tc.zeros_like(_embedding)
        self.tensor2 = tc.zeros_like(_embedding)
        self.bias = tc.tensor(0.0)
        self.isEval = _isEval
    
    def append(self, _tensor : tc.Tensor):
        assert tc.is_nonzero(_tensor[0])
        with tc.no_grad():
            self.tensor2 += _tensor.detach()
        self.num += 1
    
    def get(self):
        return self.tensor, self.bias
    
    def valid(self):  
        return tc.is_nonzero(self.tensor[0])
    
    def update(self, _decoder, _vers):
        if self.version == _vers:
            #assert _decoder.weight is __model.embeddings.word_embeddings.weight
            with tc.no_grad():
                assert tc.is_nonzero(_decoder.weight[self.id][0])
                self.tensor.copy_(_decoder.weight[self.id].detach())
                self.bias.copy_(_decoder.bias[self.id].detach())

    def getId(self, _version):
        if self.version == _version:
            return self.id
        else:
            return None
    
    def push(self):
        with tc.no_grad():
            self.tensor.copy_(self.tensor2 / self.num if self.num else self.tensor2)
            self.tensor2.zero_()
            self.bias.zero_()
        r = self.num
        self.num = 0
        return r
    
    def assign(self, _id, _version):
        self.id = _id
        self.version = _version
        return _id
    
    def to(self, _device):
        if self.tensor is not None:
            self.tensor.to(_device)
        if self.tensor2 is not None:
            self.tensor2.to(_device)
        if self.bias is not None:
            self.bias.to(_device)

# %%
def extractUnusedIds(_vocab, _range = 1000):
    for i in range(_range):
        t = "[unused{0}]".format(i)
        if t in _vocab:
            yield _vocab[t]

def createTokenName(_words):
    return '+'.join(_words) + '&'

def allocScore(_embedding, _slots, _words, _vers, _isEval = False):
    if _words not in __extraTokens:     
        __extraTokens[_words] = Scores(_words, _embedding.weight[0], _isEval)
        
    sc_ = __extraTokens[_words]
    
    id_ = sc_.getId(_vers)
    if not id_:
        if len(_slots) < 1:
            return None     
        id_ = sc_.assign(_slots.pop(), _vers)
    
    __tokenizer.vocab[_words] = id_
    __tokenizer.ids_to_tokens[id_] = _words
    if not _isEval:
        with tc.no_grad():
            decoder_ = __model.cls.predictions.decoder
            assert decoder_.weight is __model.bert.embeddings.word_embeddings.weight
            weightBias_ = sc_.get()
            decoder_.weight[id_].copy_(weightBias_[0].detach())
            decoder_.bias[id_].copy_(weightBias_[1].detach())           
            decoder_.weight[id_].requires_grad_(True)
        if sc_.isEval:
            __batchTokens.add(sc_)
    return sc_

def resetEmbeddings(_decoder, _slots):
    with tc.no_grad():
        for s in _slots:
            _decoder.weight[s].zero_()
            _decoder.bias[s].zero_()
            
            if _decoder.weight.grad is not None:
                _decoder.weight.grad[s].zero_()
            if _decoder.bias.grad is not None:
                _decoder.bias.grad[s].zero_()

def syncBatchTokens():
    for t in __batchTokens:
        t.update(__model.cls.predictions.decoder, __curEpoch)
    __batchTokens.clear()

# %% [markdown]
# ### Sequence Generation

# %%
def generateTokenizedSequence(_texts, _candidates, _slots, _vers, _isEval = False):
    logger_ = logging.getLogger(generateTokenizedSequence.__name__)
    _candidates = [__tokenizer.tokenize(t) for t in _candidates if t]
    _candidates = [c for c in _candidates if allocScore(__model.bert.embeddings.word_embeddings, _slots, createTokenName(c), _vers, _isEval)]
    
    def generateMaskCopy(_tokens, _kpes, _maskToken):        
        ids_ = [i for i in range(1, len(_tokens) - 1) if _tokens[i] != "[SEP]"]
        npr.shuffle(ids_)
        mask_ = copy.copy(_tokens)
        for i in it.islice(ids_, max(1, int(len(ids_) * __config.maskRate))):
            mask_[i] = _maskToken
        return mask_
    
    def expandSentence(_tokens, _kpes, _candidates):
        i = 0
        tokensExpands_ = list()
        kpesExpands_ = list()

        while i < len(_tokens):
            if not _kpes[i]:
                tokensExpands_.append(_tokens[i])
                kpesExpands_.append(0)
                i += 1
                continue

            j = i + 1            
            while j < len(_tokens) and _kpes[j] == _kpes[i]:
                j += 1
            
            if len(tokensExpands_) + len(_tokens) - i + 4 < __config.maxSentenceLength:
                c = _kpes[i]
                
                for z in range(i, j):
                    tokensExpands_.append(_tokens[z])
                    kpesExpands_.append(0)
                
                tokensExpands_.append('(')
                tokensExpands_.append("aka")                
                name_ = createTokenName(_candidates[c - 1])
                if _isEval:
                    tokensExpands_.append('[MASK]')
                else:
                    assert __extraTokens[name_].valid()
                    tokensExpands_.append(name_)
                tokensExpands_.append(')')
                
                kpesExpands_.append(-1)
                kpesExpands_.append(-1)
                kpesExpands_.append(__extraTokens[name_].getId(_vers))                               
                kpesExpands_.append(-1)
                i = j
            else:
                tokensExpands_.extend(_tokens[i:])
                kpesExpands_.extend(it.repeat(0, len(_tokens) - i))
                break
        assert len(tokensExpands_) == len(kpesExpands_)
        return tokensExpands_, kpesExpands_
        
    tokens_ = ["[CLS]"]
    for text_ in _texts.split("\r\n"):
        curTokens_ = __tokenizer.tokenize(text_)
        if len(tokens_) + len(curTokens_) > __config.maxSentenceLength - 20:
            break
        tokens_ += curTokens_ + ["[SEP]"]

    kpes_ = subTokens(tokens_, _candidates)
    
    tokens_, kpes_ = expandSentence(tokens_, kpes_, _candidates)
    
    if _isEval:
        return tokens_, tokens_, kpes_
    else:
        return tokens_, generateMaskCopy(tokens_, kpes_, "[MASK]"), kpes_
    
def generateTrainingData(_data, _isEval = False):
    logger_ = logging.getLogger(generateTokenizedSequence.__name__)    
    
    slots_ = list(extractUnusedIds(__tokenizer.vocab, 1000))
    resetEmbeddings(__model.cls.predictions.decoder, slots_)
    
    def generateRow(_text, _tags):
        tks_, msks_, kpes_ = generateTokenizedSequence(_text, _tags, slots_, __curEpoch, _isEval)
        tks_ = __tokenizer.convert_tokens_to_ids(tks_)        
        msks_ = __tokenizer.convert_tokens_to_ids(msks_)

        sentLen_ = len(tks_)
        activeMask_ = list(map(lambda x : int(x < sentLen_), range(__config.maxSentenceLength)))
        tks_.extend(it.repeat(0, __config.maxSentenceLength - sentLen_))
        msks_.extend(it.repeat(0, __config.maxSentenceLength - sentLen_))
        kpes_.extend(it.repeat(0, __config.maxSentenceLength - sentLen_))
        return pd.Series([tks_, msks_, activeMask_, kpes_], index = ["tokens", "tokenmasks", "masks", "kpes"])
    
    logger_.info("input raw training data %d", _data.shape[0])
    _data = _data.dropna()
    logger_.info("filtering na training data %d", _data.shape[0])
    
    logger_.info("generating features for questions")
    pd1_ = _data.apply(lambda _row: generateRow(_row.CleanBody, _row.Tag), axis = 1)
    logger_.info("generating features for answers")
    pd2_ = _data.apply(lambda _row: generateRow(_row.AnswerBody, _row.Tag), axis = 1)
    logger_.info("completed generating features")
    
    return pd.concat([pd1_, pd2_])


def convertToTensor(_data):
    tmasks_ = [list(map(lambda x : 1 if x != 0 else 0, kpe_)) for kpe_ in _data.kpes]
    masks_ = tc.tensor(_data.masks.array, dtype = tc.long, device = __config.device)
    tmasks_ = tc.tensor(tmasks_, dtype = tc.long, device = __config.device)
    return tcd.TensorDataset(
        tc.tensor(_data.tokenmasks.array, dtype = tc.long, device = __config.device),
        tmasks_,
        masks_,
        tc.tensor(_data.tokens.array, dtype = tc.long, device = __config.device))

# %% [raw]
# # test mask generation
# __extraTokens.clear()
# print(generateTokenizedSequence("this is the test topic", ["the test", "test topic"], [1, 2, 3, 4], 1))
# print(generateTokenizedSequence("this is the test topic\r\nthe q&a time is here", ["q&a", "test topic"], [1, 2, 3, 4], 1))
# print(generateTokenizedSequence("this is the test topic\r\nthe q&a time is here", ["q&a", "test topic"], [1, 2, 3, 4], 1, True))
#
#
# df_ = pd.DataFrame({"CleanBody": ["this is the test topic\r\nthe q&a time is here"], "AnswerBody": ["My answer for Test Topic is here."], "Tag" : [["q&a", "test topic"]]})
# test_ = generateTrainingData(df_)
# print(test_)

# %% [markdown]
# ## Training

# %%
def createOptimizer(_lrFact = 1):
    FilterNodecay_ = lambda x : any(map(lambda t : t in x, ["bias", "LayerNorm.weight"]))
    parameters_ = list(__model.named_parameters())
    parameters_ = [
        {"params": [p for n, p in parameters_ if not FilterNodecay_(n)], 'weight_decay': __config.weightDecay},
        {"params": [p for n, p in parameters_ if FilterNodecay_(n)], 'weight_decay': 0.0}
    ]
    return AdamW(parameters_, lr = __config.learningRate * _lrFact, correct_bias=False)  # To reproduce BertAdam specific behavior set correct_bias=False

# %% [raw]
# def predCost(_predictions, _labels, _tmasks):
#     loss_ = predCost._lossFunc(_predictions.view(-1, __model.config.vocab_size), _labels.view(-1))
#     # only aggregate token type 0
#     with tc.no_grad():
#         mask_ = (tc.tensor(1) - _tmasks).view(-1)
#     return tc.dot(loss_, mask_.float()) / tc.sum(mask_).detach()
#
# predCost._lossFunc = tc.nn.CrossEntropyLoss(reduction = "none")

# %%
def trainBert(_dataFrame, _optimizer):
    logger_ = logging.getLogger(trainBert.__name__)
    __model.train()
    
    logger_.info("training data frame size %d", _dataFrame.shape[0])
    
    _trainingDataset = convertToTensor(_dataFrame)
    
    trainingSteps_ = len(_trainingDataset) // (__config.batchSize * __config.batchAccumulation)
    
    logger_.info("begin {0} epoch training, with {1} steps on device {2} ...".format(__curEpoch, trainingSteps_, __config.device))
    
    dataReader_ = tcd.DataLoader(_trainingDataset, shuffle = True, batch_size = __config.batchSize, drop_last = True)
    _optimizer.zero_grad()
    for step_, batch_ in enumerate(dataReader_):
        output_ = __model(input_ids = batch_[0], attention_mask = batch_[2], token_type_ids = batch_[1], labels = batch_[3])
        #loss_ = predCost(output_[0], batch_[3], batch_[1]) / __config.batchAccumulation
        loss_ = output_[0] / __config.batchAccumulation

        loss_.backward()
        
        if not ((step_ + 1) % __config.batchAccumulation):
            # tc.nn.utils.clip_grad_norm_(__model.parameters(), 1.0)
            _optimizer.step()
            _optimizer.zero_grad()            
            __amlrun.log('loss', loss_)
            logger_.info("step {0}/{1} finished, loss : {2}".format((step_ + 1) // __config.batchAccumulation, trainingSteps_, loss_))
    
    logger_.info("end {0} epoch training".format(__curEpoch))

# %%
def printTokens(_tokens):
    print(_tokens)
    print(__tokenizer.convert_ids_to_tokens(_tokens.numpy()))

def printEmbedding(_token):
    print(__model.bert.embeddings.word_embeddings.weight[_token])
    print(__model.bert.embeddings.word_embeddings.weight.grad[_token])

# %%
def getEmbeddings(_tokens, _tokenTypes, _masks, _labels = None):
    logger_ = logging.getLogger(getEmbeddings.__name__)
    
    with tc.no_grad():
        output_ = __model(input_ids = _tokens, token_type_ids = _tokenTypes, attention_mask = _masks)
        normalizer_ = tc.nn.Softmax(2)
        output_ = normalizer_(output_[0])
        output_[:, :, : 1000].zero_()
        
        index_ = tc.argmax(output_, dim = 2)
        
        if __config.removeAggBias:
            bias_ = tc.norm(__model.bert.embeddings.word_embeddings.weight, p = 2, dim = 1, keepdim = True) + 1e-12
            bases_ = tc.div(__model.bert.embeddings.word_embeddings.weight, bias_)
            bias_ = tc.mean(bias_)
            output_ = tc.matmul(output_, bases_) # * bias_
        else:
            output_ = tc.matmul(output_, __model.bert.embeddings.word_embeddings.weight)
            
        return output_, index_

def evaluateModel(_dataFrame):
    logger_ = logging.getLogger(evaluateModel.__name__)

    __model.eval()
    evaluationSet_ = convertToTensor(_dataFrame)
    evalSteps_ = len(evaluationSet_) // __config.batchSize

    dataReader_ = tcd.DataLoader(evaluationSet_, shuffle = False, batch_size = __config.batchSize, drop_last = False)
    
    debug_ = 0
    for step_, batch_ in enumerate(dataReader_):
        logger_.info("get gradient for steps %d/%d", step_, evalSteps_)
        embeddings_, ptk_ = getEmbeddings(*batch_)
        batchSize_ = embeddings_.shape[0]
        debug_ += batchSize_
        for i in range(batchSize_):
            recorder_ = _dataFrame.iloc[step_ * __config.batchSize + i]
            if not any(recorder_.kpes):
                continue
            assert len(recorder_.kpes) == len(embeddings_[i])
            for k, e, t in zip(recorder_.kpes, embeddings_[i], ptk_[i]):
                if k > 0:
                    __extraTokens[__tokenizer.convert_ids_to_tokens(k)].append(e)
    assert debug_ == len(_dataFrame)
    logger_.info("grandients update completed")

# %% [raw]
# # least square, but it's not needed
# print(__model.bert.embeddings.word_embeddings.weight.shape)
# print(__model.cls.predictions.decoder.weight.shape)
# x = tc.lstsq(__model.bert.embeddings.word_embeddings.weight, __model.cls.predictions.decoder.weight)
# print(x.solution.shape)

# %% [markdown]
# ## Evaluate and Update

# %%
def readDataFrame(_readChunkSize, _readCounts, _skipFiles = 0):
    counter_ = 0
    for file_ in glob.glob(os.path.join(__config.dataInputPath, "*.csv")):
        if _skipFiles > 0:
            _skipFiles -= 1
            continue

        data_ = pd.read_csv(file_).set_index("Id")
        data_.Tag = data_["Tag"].map(toList)
        for i in range(0, data_.shape[0], _readChunkSize):
            counter_ += 1
            if counter_ > _readCounts:
                return
            yield data_.iloc[i : i + _readChunkSize]

# %%
def train1(_startPoint = 0):
    logger_ = logging.getLogger(train1.__name__)
    
    global __curEpoch
    
    logger_.info("Begin training process")
    resetEpoch(0, False)
    #scheduler_ = createScheduler([__config.epochSize * 2 * __config.epochs])    
    for dataFrame_ in readDataFrame(__config.epochSize, __config.epochs, _startPoint):
        __curEpoch += 1
        optimizer_ = createOptimizer()        
        dataFrame_ = generateTrainingData(dataFrame_)
        trainBert(dataFrame_, optimizer_)
        syncBatchTokens()

# %%
def eval1(_startPoint = 0):
    logger_ = logging.getLogger(eval1.__name__)
    global __curEpoch
 
    logger_.info("Begin aggregation process")
    resetEpoch(0, False)    
    for dataFrame_ in readDataFrame(__config.evalEpochSize, __config.evalEpochs, _startPoint):        
        __curEpoch += 1
        dataFrame_ = generateTrainingData(dataFrame_, True)
        evaluateModel(dataFrame_)

# %%
def trainAll(_startPoint = 0):
    logger_ = logging.getLogger(trainAll.__name__)
    
    global __curEpoch
 
    logger_.info("Begin aggregation process")

    resetEpoch(0, False)
    for dataFrame_ in readDataFrame(__config.evalEpochSize, __config.evalEpochs, _startPoint):        
        __curEpoch += 1
        dataFrame_ = generateTrainingData(dataFrame_, True)
        evaluateModel(dataFrame_)    

    logger_.info("Begin training process")
    resetEpoch()
    testTopics()

    #backups_ = backupTopics()
    # scheduler_ = createScheduler([__config.epochSize * 2 * __config.epochs])    
    for dataFrame_ in readDataFrame(__config.epochSize, __config.epochs, _startPoint):
        __curEpoch += 1
        optimizer_ = createOptimizer()        
        dataFrame_ = generateTrainingData(dataFrame_)
        trainBert(dataFrame_, optimizer_)
        syncBatchTokens()
    
    testTopics()
    logger_.info("training completed aggregation process")

# %%
def backupTopics():
    backup_ = dict()
    for t, v in __extraTokens.items():
        backup_[t] = v.tensor.detach().clone()
    return backup_

# %% [markdown]
# ## Evaluation

# %%
def extractWordEmbeddings():
    tensors_ = list()
    for name_ in topKTopic._names:
        if name_ == "c++++&":
            tokens_ = ['c', '+', '+']
        else:
            tokens_ = name_.strip('&').split('+')
        tokens_ = __tokenizer.convert_tokens_to_ids(tokens_)
        embeddings_ = list(map(lambda x : __model.bert.embeddings.word_embeddings.weight[x], tokens_))
        embedding_ = sum(embeddings_) / len(embeddings_)
        
        tensors_.append(embedding_)
    
    tensors_ = tc.stack(tensors_, dim = 0)    
    tensors_ = tensors_ / (tc.norm(tensors_, p = 2, dim = 1, keepdim = True) + 1e-12)
    
    return tensors_

# %%
def extractTokens():
    names_ = list(map(lambda x : x.name, __extraTokens.values()))
    tensors_ = tc.stack(list(map(lambda x : x.tensor.detach(), __extraTokens.values())), dim = 0)
    tensors_ = tensors_ / (tc.norm(tensors_, p = 2, dim = 1, keepdim = True) + 1e-12)
    return names_, tensors_

def topKTopic(t, _top = 5):    
    if isinstance(t, str):
        t = __extraTokens[t].tensor
    _, ids_ = tc.topk(tc.matmul(topKTopic._tensors, t), _top, dim = 0)
    
    return list(map(lambda x : topKTopic._names[x], ids_))

def distance(_left, _right):
    print(tc.dot(__extraTokens[_left].tensor, __extraTokens[_right].tensor))

# topKTopic("flex&")

# %%
def testTopic(_topic):
    print("Topic '{0}' related to {1}".format(_topic, str(topKTopic(__extraTokens[_topic].tensor))))

def testTopics2():
    topKTopic._names, topKTopic._tensors = extractTokens()
    topKTopic._tensors = extractWordEmbeddings()

    for i, name_ in enumerate(topKTopic._names):
        if len(tc.nonzero(topKTopic._tensors[i])):
            print("Topic '{0}' related to {1}".format(name_, str(topKTopic(topKTopic._tensors[i]))))
    
def testTopics():
    topKTopic._names, topKTopic._tensors = extractTokens()
    for i, name_ in enumerate(topKTopic._names):
        if len(tc.nonzero(topKTopic._tensors[i])):
            testTopic(name_)

# %% [markdown]
# ## Main

# %%
def main(_inputDataPath = None, _outputModelPath = None, _Epochs = 5, _useGPU = False, _debug = DebugOption.Empty):
    logger_ = logging.getLogger(main.__name__)
    __config.initDevice(_useGPU)

    __config.debug = _debug
    
    if _Epochs > 0:
        __config.epochs = _Epochs
        __config.evalEpochs = _Epochs    
    
    if _inputDataPath:
        __config.dataInputPath = _inputDataPath
    if _outputModelPath:
        __config.dataModelPath = _outputModelPath
    
    logger_.info("Configs: " + str(__config))
    
    __extraTokens.clear()
    trainAll()
    saveCheckpoint("base1")
    
    logger_.info("Training completed, begin eval...")    
    testTopics()
    logger_.info("Completed")

# %% [raw]
# if __name__ == "__main__":
#     parser_ = argparse.ArgumentParser(description = "Train and eval topic embedding over LM")
#     parser_.add_argument("InputDataPath", type=str, help = "The input directory path")
#     parser_.add_argument("OutputModelPath", type=str, help = "The model directory path")
#     parser_.add_argument("Epochs", type=int, help = "The epoch size")
#     parser_.add_argument("UseGPU", nargs = '?', type=int, default = 1, help = "use GPU")
#     args_ = parser_.parse_args()
#
#     main(args_.InputDataPath, args_.OutputModelPath, args_.Epochs, args_.UseGPU)

# %%
if __name__ == "__main__":
    main()
# Out:
# Topic 'flex&' related to ['flex&', 'actions+##cript&', 'x+##mp+##p&', 'flash&', 'web+##kit&']
# Topic 'actions+##cript+3&' related to ['actions+##cript+3&', 'dl+##l&', 'file&', 'command+line&', 'per+##l&']
# Topic 'air&' related to ['air&', 'printing&', 'st+##rut+##s+##2&', 'jp+##a&', 'stream&']
# Topic 'sv+##n&' related to ['sv+##n&', 'ii+##s&', 'gi+##t&', 'if+##ram+##e&', 'm+##fc&']
# Topic 'sql&' related to ['sql&', 'lin+##q+to+sql&', 'sql+server&', 'database&', 'sql+##ite&']
# Topic 'as+##p+.+net&' related to ['as+##p+.+net&', 'share+##point&', 'wc+##f&', '.+net&', 'internet+explorer&']
# Topic 'algorithm&' related to ['algorithm&', 'performance&', 'optimization&', 'linked+list&', 'par+##sing&']
# Topic 'language+ag+##nostic&' related to ['language+ag+##nostic&', 'mat+##lab&', 'or+##m&', 'w+##sd+##l&', 'v+##bs+##cript&']
# Topic 'colors&' related to ['colors&', 'themes&', 'background&', 'plot&', 'hyper+##link&']
# Topic 'c+#&' related to ['c+#&', 'c++++&', 'st+##l&', 'g+##cc&', 'per+##l&']
# Topic '.+net&' related to ['.+net&', 'as+##p+.+net&', 'w+##sd+##l&', 'v+##bs+##cript&', 'internet+explorer&']
# Topic 'script+##ing&' related to ['script+##ing&', 'java+##script&', 'documentation&', 'command+line&', 'plug+##ins&']
# Topic 'c++++&' related to ['c++++&', 'c+#&', 'scala&', 'st+##l&', 'os+##x&']
# Topic 'o+##op&' related to ['o+##op&', 'design&', 'user+controls&', 'grid+##view&', 'configuration&']
# Topic 'class&' related to ['class&', 'construct+##or&', 'path&', 'function&', 'package&']
# Topic 'web+services&' related to ['web+services&', 'wc+##f&', 'ss+##is&', 'as+##p+.+net&', '.+net&']
# Topic 'sql+server&' related to ['sql+server&', 'sql+server+2005&', 'reporting+services&', 'lin+##q+to+sql&', 'db+##2&']
# Topic 'sql+server+2005&' related to ['sql+server+2005&', 'ss+##is&', 'as+##p+.+net&', 't+##fs&', 'sql+server&']
# Topic 'deployment&' related to ['deployment&', 'continuous+integration&', 'wi+##x&', 'ms+##bu+##il+##d&', 't+##fs&']
# Topic 'visual+studio&' related to ['visual+studio&', 'visual+studio+2008&', 'id+##e&', 'w+##pf&', 'win+##forms&']
# Topic 'windows&' related to ['windows&', '.+net&', 'internet+explorer&', 'ii+##s&', 'embedded&']
# Topic 'registry&' related to ['registry&', 'o+##db+##c&', 'file&', 'directory&', 'session&']
# Topic 'installation&' related to ['installation&', 'windows+install+##er&', 'wi+##x&', 'auto+##com+##ple+##te&', 'ms+##bu+##il+##d&']
# Topic 'database&' related to ['database&', 'stored+procedures&', 'ss+##is&', 'data+##table&', 'reporting+services&']
# Topic 'loops&' related to ['loops&', 'memory+leaks&', 'performance&', 'algorithm&', 'linked+list&']
# Topic 'connection&' related to ['connection&', 'session&', 'configuration&', 'up+##load&', 'wc+##f&']
# Topic 'unix&' related to ['unix&', 'linux&', 'windows&', 'j+##v+##m&', 'shell&']
# Topic 'size&' related to ['size&', 'print+##f&', 'construct+##or&', 'vector&', 'comparison&']
# Topic 'ms+##bu+##il+##d&' related to ['ms+##bu+##il+##d&', 'de+##bu+##gging&', 'w+##sd+##l&', 'wi+##x&', 'j+##que+##ry&']
# Topic 'web+applications&' related to ['web+applications&', 'web+##forms&', 'plug+##ins&', 'as+##p+.+net+mv+##c&', 'web+con+##fi+##g&']
# Topic 'd+##ns&' related to ['d+##ns&', 'ft+##p&', 'proxy&', 'ss+##is&', 'o+##db+##c&']
# Topic '.+net+3+.+5&' related to ['.+net+3+.+5&', 'google+chrome&', 'windows+services&', 'j+##bos+##s&', 'em+##ac+##s&']
# Topic 'sql+server+2008&' related to ['sql+server+2008&', 'ts+##q+##l&', 'batch+file&', 'ms+access&', 'install&']
# Topic 'unit+testing&' related to ['unit+testing&', 'testing&', 'optimization&', 'documentation&', 'design&']
# Topic 'testing&' related to ['testing&', 'unit+testing&', 'documentation&', 'plug+##ins&', 'ref+##act+##orin+##g&']
# Topic 'version+control&' related to ['version+control&', 'continuous+integration&', 'wi+##x&', 'windows+install+##er&', 'ms+##bu+##il+##d&']
# Topic 'post+##gre+##s+##q+##l&' related to ['post+##gre+##s+##q+##l&', 'my+##s+##q+##l&', '.+h+##ta+##cc+##ess&', 'j+##que+##ry&', 'hi+##ber+##nate&']
# Topic 'stored+procedures&' related to ['stored+procedures&', 'database&', 'documentation&', 'plug+##ins&', 'script+##ing&']
# Topic 'triggers&' related to ['triggers&', 'logging&', 'events&', 'transactions&', 'stored+procedures&']
# Topic 'data+##set&' related to ['data+##set&', 'data+##table&', 'jp+##a&', 'lin+##q&', 'x+##sd&']
# Topic 'data+##table&' related to ['data+##table&', 'database&', 'grid+##view&', 'design&', 'data+binding&']
# Topic 'html&' related to ['html&', 'cs+##s&', 'as+##p+classic&', 'java+##script&', 'browser&']
# Topic 'auto+##com+##ple+##te&' related to ['auto+##com+##ple+##te&', 'j+##que+##ry&', 'windows+install+##er&', 'powers+##hell&', 'w+##pf&']
# Topic 'c&' related to ['c&', 'cu+##da&', 'floating+point&', 'assembly&', 'f+#&']
# Topic 'architecture&' related to ['architecture&', 'documentation&', 'design&', 'design+patterns&', 'script+##ing&']
# Topic 'data+structures&' related to ['data+structures&', 'ann+##ota+##tions&', 'java&', 'generic+##s&', 'import&']
# Topic 'flash&' related to ['flash&', 'web+##kit&', 'sd+##k&', 'silver+##light&', 'ui+##we+##b+##view&']
# Topic 'video&' related to ['video&', 'streaming&', 'sd+##k&', 'compression&', 'audio&']
# Topic 'powers+##hell&' related to ['powers+##hell&', 'del+##phi&', 'visual+studio+2008&', 'fire+##fo+##x&', 'j+##que+##ry&']
# Topic 'optimization&' related to ['optimization&', 'performance&', 'memory+leaks&', 'algorithm&', 'garbage+collection&']
# Topic 'win+##forms&' related to ['win+##forms&', 'w+##pf&', 'silver+##light&', 'visual+studio+2008&', 'powers+##hell&']
# Topic 'error+handling&' related to ['error+handling&', 'par+##sing&', 'de+##bu+##gging&', 'as+##yn+##ch+##ron+##ous&', 'validation&']
# Topic 'user+controls&' related to ['user+controls&', 'res+##ize&', 'pop+##up&', 'command&', 'text+##box&']
# Topic 'php&' related to ['php&', 'image+##ma+##gic+##k&', 'as+##p+classic&', 'java+##script&', 'zen+##d+framework&']
# Topic 'my+##s+##q+##l&' related to ['my+##s+##q+##l&', 'j+##que+##ry&', 'lin+##q&', '.+h+##ta+##cc+##ess&', 'nh+##ibe+##rna+##te&']
# Topic 'security&' related to ['security&', 'model&', 'authentication&', 'encryption&', 'wc+##f&']
# Topic 'full+text+search&' related to ['full+text+search&', 'grid+##view&', 'sorting&', 'nh+##ibe+##rna+##te&', 'linked+list&']
# Topic 'math&' related to ['math&', 'functional+programming&', 'design+patterns&', 'nl+##p&', 'testing&']
# Topic 'ruby&' related to ['ruby&', 'nu+##mp+##y&', 'er+##lang&', 'cy+##g+##win&', 'has+##kell&']
# Topic 'java&' related to ['java&', 'j+##v+##m&', 'cookies&', 'ann+##ota+##tions&', 'apple+##t&']
# Topic 'ad+##o+.+net&' related to ['ad+##o+.+net&', 'oracle&', 'sql+server&', 'or+##m&', 'sql+server+2005&']
# Topic 'w+##sd+##l&' related to ['w+##sd+##l&', 'j+##son&', 'ms+##bu+##il+##d&', 'api&', 'j+##que+##ry&']
# Topic 'j+##ni&' related to ['j+##ni&', 'apple+##t&', 'import&', 'java+##script&', 'j+##v+##m&']
# Topic 'user+interface&' related to ['user+interface&', 'ui+##ima+##ge+##view&', 'interface+builder&', 'charts&', 'ui+##ima+##ge&']
# Topic 'reg+##ex&' related to ['reg+##ex&', 'gr+##ep&', 'vi+##m&', 'per+##l&', 'compilation&']
# Topic 'email&' related to ['email&', 'sm+##tp&', 'proxy&', 'ui+##text+##field&', 'wc+##f&']
# Topic 'forms&' related to ['forms&', 'grid+##view&', 'data+binding&', 'up+##load&', 'validation&']
# Topic 'share+##point&' related to ['share+##point&', 'as+##p+.+net&', 'google+app+engine&', 'wc+##f&', 'cold+##fusion&']
# Topic 'v+##b+.+net&' related to ['v+##b+.+net&', 'g+##cc&', 'per+##l&', 'v+##ba&', 'w+##sd+##l&']
# Topic 'date&' related to ['date&', 'time+##zone&', 'time&', 'calendar&', 'date+##time&']
# Topic 'index+##ing&' related to ['index+##ing&', 'post+##gre+##s+##q+##l&', 'my+##s+##q+##l&', 'lin+##q&', 'par+##sing&']
# Topic 'as+##p+.+net+mv+##c&' related to ['as+##p+.+net+mv+##c&', 'active+##re+##cor+##d&', 'plug+##ins&', 'as+##p+.+net&', 'wi+##x&']
# Topic 'authentication&' related to ['authentication&', 'wc+##f&', 'proxy&', 'encryption&', 'as+##p+.+net&']
# Topic 'foreign+keys&' related to ['foreign+keys&', 'lin+##q&', 'my+##s+##q+##l&', 'nh+##ibe+##rna+##te&', 'validation&']
# Topic 'logging&' related to ['logging&', 'plug+##ins&', 'de+##bu+##gging&', 'active+##re+##cor+##d&', 'wc+##f&']
# Topic 'permission+##s&' related to ['permission+##s&', 'configuration&', 'ca+##ching&', 'plug+##ins&', 'session&']
# Topic 'multi+##th+##rea+##ding&' related to ['multi+##th+##rea+##ding&', 'https&', 'pt+##hre+##ads&', 'files+##yst+##em+##s&', 'file+up+##load&']
# Topic 'animation&' related to ['animation&', 'ui+##ima+##ge+##view&', 'navigation&', 'video&', 'charts&']
# Topic 'continuous+integration&' related to ['continuous+integration&', 'wi+##x&', 't+##fs&', 'ms+##bu+##il+##d&', 'windows+install+##er&']
# Topic 'linux&' related to ['linux&', 'windows&', 'embedded&', 'unix&', 'j+##v+##m&']
# Topic 'ss+##h&' related to ['ss+##h&', 'ft+##p&', 'ii+##s&', 'mall+##oc&', 'ms+access&']
# Topic 'se+##len+##ium&' related to ['se+##len+##ium&', 'silver+##light&', 'tiny+##mc+##e&', 'id+##e&', 'do+##jo&']
# Topic 'java+##script&' related to ['java+##script&', 'j+##son&', 'w+##sd+##l&', '.+net&', 'v+##bs+##cript&']
# Topic 'fire+##fo+##x&' related to ['fire+##fo+##x&', 'silver+##light&', 'del+##phi&', 'internet+explorer&', 'powers+##hell&']
# Topic 'memory&' related to ['memory&', 'file&', 'dl+##l&', 'pipe&', 'it+##era+##tor&']
# Topic 'sw+##t&' related to ['sw+##t&', 'w+##pf&', 'w+##sd+##l&', 'm+##fc&', 'j+##que+##ry&']
# Topic 'file&' related to ['file&', 'dl+##l&', 'directory&', 'batch+file&', 'actions+##cript+3&']
# Topic 'io&' related to ['io&', 'ms+##bu+##il+##d&', 'wi+##x&', 'configuration&', 'ss+##is&']
# Topic 'cs+##s&' related to ['cs+##s&', 'j+##que+##ry&', 'x+##sl+##t&', 'if+##ram+##e&', 'v+##ba&']
# Topic 'validation&' related to ['validation&', 'performance&', 'par+##sing&', 'v+##ba&', 'memory+leaks&']
# Topic 'x+##ht+##ml&' related to ['x+##ht+##ml&', 'encoding&', 'http&', 'html&', 'xp+##ath&']
# Topic 'windows+services&' related to ['windows+services&', '.+net+3+.+5&', 'q+##t&', 'j+##bos+##s&', 'silver+##light&']
# Topic 'printing&' related to ['printing&', 'jasper+reports&', 'browser&', 'pdf&', 'cs+##s&']
# Topic 'plug+##ins&' related to ['plug+##ins&', 'as+##p+.+net+mv+##c&', 'active+##re+##cor+##d&', 'documentation&', 'de+##bu+##gging&']
# Topic 'ant&' related to ['ant&', 'g+##wt&', 'x+##code&', 'tom+##cat&', 'log+##4+##j&']
# Topic 'collections&' related to ['collections&', 'sorting&', 'data+##table&', 'j+##table&', 'permission+##s&']
# Topic 'win+##ap+##i&' related to ['win+##ap+##i&', 'configuration&', 'wi+##x&', 'console&', 'user+controls&']
# Topic 'objective+c&' related to ['objective+c&', 'c++++&', 'scheme&', 'c+#&', 'assembly&']
# Topic 'os+##x&' related to ['os+##x&', 'st+##l&', 'c+#&', 'g+##db&', 'c++++&']
# Topic 'function&' related to ['function&', 'closure+##s&', 'pointer+##s&', 'initial+##ization&', 'it+##era+##tor&']
# Topic 'pointer+##s&' related to ['pointer+##s&', 'closure+##s&', 'initial+##ization&', 'function&', 'it+##era+##tor&']
# Topic 'syntax&' related to ['syntax&', 'format+##ting&', 'xp+##ath&', 'operator+over+##loading&', 'names+##pace+##s&']
# Topic 'parameters&' related to ['parameters&', 'properties&', 'scope&', 'closure+##s&', 'combo+##box&']
# Topic 'scheme&' related to ['scheme&', 'python&', 'c++++&', 'objective+c&', 'c+#&']
# Topic 'lin+##q&' related to ['lin+##q&', 'nh+##ibe+##rna+##te&', 'my+##s+##q+##l&', 'or+##m&', '.+h+##ta+##cc+##ess&']
# Topic 'pa+##gina+##tion&' related to ['pa+##gina+##tion&', 'routing&', 'web+con+##fi+##g&', 'full+text+search&', 'file+up+##load&']
# Topic 'string&' related to ['string&', 'construct+##or&', 'print+##f&', 'segment+##ation+fault&', 'pointer+##s&']
# Topic 'binding&' related to ['binding&', 'data+binding&', 'methods&', 'properties&', 'scope&']
# Topic 'drag+and+drop&' related to ['drag+and+drop&', 'code+##ign+##iter&', 'active+##re+##cor+##d&', 'ref+##act+##orin+##g&', 'dj+##ango&']
# Topic 'em+##ac+##s&' related to ['em+##ac+##s&', 'x+##code&', 'm+##fc&', 'del+##phi&', 'silver+##light&']
# Topic 'apache&' related to ['apache&', 'ng+##in+##x&', 'image+##ma+##gic+##k&', 'php&', 'ajax&']
# Topic 'up+##load&' related to ['up+##load&', 'download&', 'session&', 'configuration&', 'text+##box&']
# Topic 'python&' related to ['python&', 'scheme&', 'multi+##pro+##ces+##sing&', 'nu+##mp+##y&', 'cm+##d&']
# Topic 'ts+##q+##l&' related to ['ts+##q+##l&', 'sub+##que+##ry&', 'sql+server+2008&', 'ms+access&', 'validation&']
# Topic 'sql+##ite&' related to ['sql+##ite&', 'jd+##bc&', 'per+##l&', 'mat+##lab&', 'or+##m&']
# Topic 'ii+##s&' related to ['ii+##s&', 'm+##fc&', 'sv+##n&', 'gi+##t&', 'w+##pf&']
# Topic 'ajax&' related to ['ajax&', 'java+##script&', 'as+##p+.+net&', 'zen+##d+framework&', 'internet+explorer&']
# Topic 'performance&' related to ['performance&', 'memory+leaks&', 'validation&', 'optimization&', 'w+##sd+##l&']
# Topic 'design+patterns&' related to ['design+patterns&', 'layout&', 'reflection&', 'drag+and+drop&', 'ref+##act+##orin+##g&']
# Topic 'internet+explorer&' related to ['internet+explorer&', 'as+##p+.+net&', 'fire+##fo+##x&', '.+net&', 'google+app+engine&']
# Topic 'unicode&' related to ['unicode&', 'encoding&', 'base+##64&', 'aw+##k&', 'font+##s&']
# Topic 'or+##m&' related to ['or+##m&', 'w+##sd+##l&', 'ss+##is&', '.+net&', 'api&']
# Topic 'xml&' related to ['xml&', 'xp+##ath&', 'x+##ht+##ml&', 'html&', 'x+##sl+##t&']
# Topic 'sockets&' related to ['sockets&', 'wc+##f&', 'de+##bu+##gging&', 'proxy&', 'active+##re+##cor+##d&']
# Topic 'ip&' related to ['ip&', 'apple+##t&', 'http&', 'log+##4+##j&', 'd+##ns&']
# Topic 'content+management+system&' related to ['content+management+system&', 't+##fs&', 'continuous+integration&', 'as+##p+.+net+mv+##c&', 'share+##point&']
# Topic 'v+##bs+##cript&' related to ['v+##bs+##cript&', 'j+##que+##ry&', 'w+##sd+##l&', '.+net&', 'j+##son&']
# Topic 'depend+##encies&' related to ['depend+##encies&', 'generic+##s&', 'performance&', 'memory+leaks&', 'garbage+collection&']
# Topic 'j+##sp&' related to ['j+##sp&', 'per+##l&', 'reg+##ex&', 'v+##b+##6&', 'g+##db&']
# Topic 'tom+##cat&' related to ['tom+##cat&', 'fire+##fo+##x&', 'j+##bos+##s&', 'dj+##ango&', 'id+##e&']
# Topic 'resources&' related to ['resources&', 'plug+##ins&', 'grid+##view&', 'permission+##s&', 'database&']
# Topic 'exception&' related to ['exception&', 'methods&', 'poly+##morphism&', 'connection&', 'reference&']
# Topic 'ii+##s+7&' related to ['ii+##s+7&', 'mage+##nto&', 'jett+##y&', 'sv+##g&', 'luce+##ne&']
# Topic 'process&' related to ['process&', 'build&', 'session&', 'command&', 'user+controls&']
# Topic 'batch+file&' related to ['batch+file&', 'file&', 'install&', 'session&', 'command+line&']
# Topic 'open+##gl&' related to ['open+##gl&', 'visual+studio&', 'sw+##t&', '.+net&', 'w+##pf&']
# Topic 'menu&' related to ['menu&', 'list+##box&', 'combo+##box&', 'user+controls&', 'focus&']
# Topic 'vi+##m&' related to ['vi+##m&', 'per+##l&', 'v+##b+##6&', 'ur+##l&', 'g+##db&']
# Topic 'lin+##q+to+sql&' related to ['lin+##q+to+sql&', 'sql&', 'sql+server&', 'database&', 'stored+procedures&']
# Topic 'attributes&' related to ['attributes&', 'variables&', 'properties&', 'methods&', 'cs+##s+selector+##s&']
# Topic 'u+##bu+##nt+##u&' related to ['u+##bu+##nt+##u&', 'em+##ac+##s&', 'x+##code&', 'del+##phi&', 'ii+##s&']
# Topic 'del+##phi&' related to ['del+##phi&', 'powers+##hell&', 'em+##ac+##s&', 'x+##code&', 'fire+##fo+##x&']
# Topic 'id+##e&' related to ['id+##e&', 'del+##phi&', 'fire+##fo+##x&', 'do+##jo&', 'x+##code&']
# Topic 'reporting+services&' related to ['reporting+services&', 'web+services&', 'sql+server+2005&', 'sql+server&', 'database&']
# Topic 'design&' related to ['design&', 'performance&', 'validation&', 'entity+framework&', 'configuration&']
# Topic 'outlook&' related to ['outlook&', 'maps&', 'word+##press&', 'share+##point&', 'user+interface&']
# Topic 'graphics&' related to ['graphics&', 'open+##gl&', 'visual+studio&', 'cs+##s&', 'interface+builder&']
# Topic 'en+##ums&' related to ['en+##ums&', 'performance&', 'lin+##q&', 'algorithm&', 'memory+leaks&']
# Topic 'text+##box&' related to ['text+##box&', 'pop+##up&', 'data+##gr+##id&', 'res+##ize&', 'user+controls&']
# Topic 'spring&' related to ['spring&', 'os+##gi&', 'j+##sf&', 'hi+##ber+##nate&', 'gi+##t&']
# Topic 'os+##gi&' related to ['os+##gi&', 'j+##bos+##s&', 'silver+##light&', 'q+##t&', 'tiny+##mc+##e&']
# Topic 'hash&' related to ['hash&', 'it+##era+##tor&', 'select&', 'split&', 'sub+##que+##ry&']
# Topic 'international+##ization&' related to ['international+##ization&', 'local+##ization&', 'documentation&', 'plug+##ins&', 'as+##p+.+net+mv+##c&']
# Topic 'has+##kell&' related to ['has+##kell&', 'fort+##ran&', 'er+##lang&', 'per+##l&', 'st+##l&']
# Topic 'types&' related to ['types&', 'initial+##ization&', 'arrays&', 'pointer+##s&', 'properties&']
# Topic 'functional+programming&' related to ['functional+programming&', 'optimization&', 'language+ag+##nostic&', 'documentation&', 'script+##ing&']
# Topic 'api&' related to ['api&', 'w+##sd+##l&', 'as+##p+.+net&', 'j+##que+##ry&', 'ss+##is&']
# Topic 'zip&' related to ['zip&', 'per+##l&', 'slide+##r&', 'j+##son&', 'opens+##sl&']
# Topic 'encryption&' related to ['encryption&', 'authentication&', 'wc+##f&', 'cold+##fusion&', 'web+services&']
# Topic 'par+##sing&' related to ['par+##sing&', 'v+##ba&', 'performance&', 'de+##bu+##gging&', 'memory+leaks&']
# Topic 'ruby+on+rails&' related to ['ruby+on+rails&', 'web+##ser+##ver&', 'active+##re+##cor+##d&', 'maps&', 'p+##y+##game&']
# Topic 'mono&' related to ['mono&', 'lu+##a&', 'dev+##ex+##press&', 'st+##l&', 'g+##db&']
# Topic 'directory&' related to ['directory&', 'file&', 'session&', 'batch+file&', 'insert&']
# Topic 'grid+##view&' related to ['grid+##view&', 'text+##box&', 'data+##gr+##id&', 'pop+##up&', 'user+controls&']
# Topic 'x+##code&' related to ['x+##code&', 'em+##ac+##s&', 'del+##phi&', 'silver+##light&', 'm+##fc&']
# Topic 'ref+##act+##orin+##g&' related to ['ref+##act+##orin+##g&', 'code+##ign+##iter&', 'plug+##ins&', 'de+##bu+##gging&', 'active+##re+##cor+##d&']
# Topic 'ms+word&' related to ['ms+word&', 'cs+##s+selector+##s&', 'label&', 'text+##box&', 'forms&']
# Topic 'swing&' related to ['swing&', 'jp+##ane+##l&', 'web+##kit&', 'do+##jo&', 'w+##pf&']
# Topic 'jp+##ane+##l&' related to ['jp+##ane+##l&', 'j+##que+##ry&', 'as+##p+.+net+mv+##c&', 'pop+##up&', 'auto+##com+##ple+##te&']
# Topic 'silver+##light&' related to ['silver+##light&', 'q+##t&', 'w+##pf&', 'fire+##fo+##x&', 'x+##code&']
# Topic 'dj+##ango&' related to ['dj+##ango&', 'php+##my+##ad+##min&', 'del+##phi&', 'dr+##up+##al&', 'fire+##fo+##x&']
# Topic 'ur+##l&' related to ['ur+##l&', 'download&', 'if+##ram+##e&', 'load&', 'v+##ba&']
# Topic 'ca+##ching&' related to ['ca+##ching&', 'wc+##f&', 'configuration&', 'proxy&', 'de+##bu+##gging&']
# Topic 'wc+##f&' related to ['wc+##f&', 'proxy&', 'as+##p+.+net&', 'wi+##x&', 't+##fs&']
# Topic 'networking&' related to ['networking&', 'j+##ms&', 'wc+##f&', 'proxy&', 'internet+explorer&']
# Topic 'session&' related to ['session&', 'connection&', 'process&', 'download&', 'command&']
# Topic 'cookies&' related to ['cookies&', 'net+##be+##ans&', 'apple+##t&', 'java+##script&', 'log+##4+##j&']
# Topic 'arrays&' related to ['arrays&', 'array+##list&', 'sorting&', 'operator+over+##loading&', 'reference&']
# Topic 'coding+style&' related to ['coding+style&', 'initial+##ization&', 'view&', 'closure+##s&', 'pointer+##s&']
# Topic 'active+directory&' related to ['active+directory&', 'o+##db+##c&', 'wc+##f&', 'proxy&', 'web+services&']
# Topic 'database+design&' related to ['database+design&', 'database&', 'data+binding&', 'ref+##act+##orin+##g&', 'stored+procedures&']
# Topic 'concurrency&' related to ['concurrency&', 'logging&', 'multi+##dim+##ens+##ional+array&', 'ref+##act+##orin+##g&', 'active+##re+##cor+##d&']
# Topic 'serial+##ization&' related to ['serial+##ization&', 'xp+##ath&', 'format+##ting&', 'encoding&', 'g+##cc&']
# Topic 'lambda&' related to ['lambda&', 'c+#&', 'pointer+##s&', 'c++++&', 'g++++&']
# Topic 'v+##b+##6&' related to ['v+##b+##6&', 'per+##l&', 'm+##fc&', 'g+##db&', 'g+##cc&']
# Topic 'as+##p+classic&' related to ['as+##p+classic&', 'java+##script&', 'j+##son&', 'html&', 'image+##ma+##gic+##k&']
# Topic 'dom&' related to ['dom&', 'ms+##bu+##il+##d&', 'j+##que+##ry&', 'w+##sd+##l&', 'de+##bu+##gging&']
# Topic 'db+##2&' related to ['db+##2&', 'ss+##is&', 'or+##m&', 'my+##s+##q+##l&', 'jd+##bc&']
# Topic 'pdf&' related to ['pdf&', 'printing&', 'jasper+reports&', 'html&', 'report&']
# Topic 'import&' related to ['import&', 'java+##script&', 'format+##ting&', 'apple+##t&', 'depend+##encies&']
# Topic 'memory+leaks&' related to ['memory+leaks&', 'performance&', 'par+##sing&', 'de+##bu+##gging&', 'command+line&']
# Topic 'hi+##ber+##nate&' related to ['hi+##ber+##nate&', 'del+##phi&', 'j+##que+##ry&', 'gi+##t&', 'ma+##ven+2&']
# Topic 'j+##que+##ry&' related to ['j+##que+##ry&', 'if+##ram+##e&', 'w+##pf&', '.+h+##ta+##cc+##ess&', 'w+##sd+##l&']
# Topic 'j+##son&' related to ['j+##son&', 'w+##sd+##l&', 'v+##bs+##cript&', 'j+##que+##ry&', 'java+##script&']
# Topic 'character+encoding&' related to ['character+encoding&', 'java+##script&', 'as+##p+classic&', 'html&', 'import&']
# Topic 'cold+##fusion&' related to ['cold+##fusion&', 'as+##p+.+net&', 'share+##point&', 'auto+##com+##ple+##te&', 'hi+##ber+##nate&']
# Topic 'xp+##ath&' related to ['xp+##ath&', 'x+##sl+##t&', 'format+##ting&', 'names+##pace+##s&', 'j+##son&']
# Topic 'browser&' related to ['browser&', 'as+##p+.+net&', 'internet+explorer&', 'if+##ram+##e&', 'cs+##s&']
# Topic 'excel&' related to ['excel&', 'v+##b+##6&', 'v+##ba&', 'text&', 'late+##x&']
# Topic 'excel+v+##ba&' related to ['excel+v+##ba&', 'reg+##ex&', 'aw+##k&', 'cu+##rso+##r&', 'gr+##ep&']
# Topic 'comparison&' related to ['comparison&', 'string&', 'print+##f&', 'list&', 'segment+##ation+fault&']
# Topic 'rec+##urs+##ion&' related to ['rec+##urs+##ion&', 'algorithm&', 'multi+##dim+##ens+##ional+array&', 'optimization&', 'sorting&']
# Topic 'q+##t&' related to ['q+##t&', 'silver+##light&', 'm+##fc&', 'w+##pf&', 'gi+##t&']
# Topic 'm+##fc&' related to ['m+##fc&', 'ii+##s&', 'w+##pf&', 'em+##ac+##s&', 'q+##t&']
# Topic 'files+##yst+##em+##s&' related to ['files+##yst+##em+##s&', 'xml+##ht+##tp+##re+##quest&', 'file+up+##load&', 'sockets&', 'web+applications&']
# Topic 'casting&' related to ['casting&', 'en+##ums&', 'run+##time&', 'par+##sing&', 'linked+list&']
# Topic 'date+##time&' related to ['date+##time&', 'time+##zone&', 'time&', 'calendar&', 'timer&']
# Topic 'android&' related to ['android&', 'java+me&', 'fire+##fo+##x&', 'google+app+engine&', 'j+##bos+##s&']
# Topic 'proxy&' related to ['proxy&', 'wc+##f&', 'as+##p+.+net&', 'd+##ns&', 'wi+##x&']
# Topic 'database+connection&' related to ['database+connection&', 'database&', 'data+##table&', 'permission+##s&', 'transactions&']
# Topic 'rest&' related to ['rest&', 'select&', 'return&', 'make+##fi+##le&', 'save&']
# Topic 'soap&' related to ['soap&', 'service&', 'wc+##f&', 'wi+##dget&', 'google+app+engine&']
# Topic 'w+##pf&' related to ['w+##pf&', 'win+##forms&', 'm+##fc&', 'j+##que+##ry&', 'silver+##light&']
# Topic 'windows+install+##er&' related to ['windows+install+##er&', 'wi+##x&', 'ms+##bu+##il+##d&', 'auto+##com+##ple+##te&', 'powers+##hell&']
# Topic 'ud+##p&' related to ['ud+##p&', 'tc+##p&', 'http&', 'd+##ns&', 'certificate&']
# Topic 'oracle&' related to ['oracle&', 'ad+##o+.+net&', 'sql+server&', 'jd+##bc&', 'db+##2&']
# Topic 'http&' related to ['http&', 'v+##b+##6&', 'ft+##p&', 'per+##l&', 'd+##ns&']
# Topic 'visual+studio+2008&' related to ['visual+studio+2008&', 'visual+studio&', 'powers+##hell&', 'del+##phi&', 'silver+##light&']
# Topic 'de+##bu+##gging&' related to ['de+##bu+##gging&', 'ms+##bu+##il+##d&', 'j+##que+##ry&', 'command+line&', 'wi+##x&']
# Topic 'log+##4+##j&' related to ['log+##4+##j&', 'g+##wt&', 'slide+##r&', 'm+##fc&', 'per+##l&']
# Topic 'x+##sl+##t&' related to ['x+##sl+##t&', 'j+##son&', 'w+##sd+##l&', 'v+##ba&', 'xp+##ath&']
# Topic 'sm+##tp&' related to ['sm+##tp&', 'email&', 'proxy&', 'wc+##f&', 'local+##hos+##t&']
# Topic 'gma+##il&' related to ['gma+##il&', 'word+##press&', 'dr+##up+##al&', 'php+##my+##ad+##min&', 'ss+##l&']
# Topic 'client&' related to ['client&', 'proxy&', 'cr+##on&', 'd+##ns&', 'wc+##f&']
# Topic 'mocking&' related to ['mocking&', 'code+##ign+##iter&', 'word+##press&', 'dj+##ango&', 'php+##my+##ad+##min&']
# Topic 'image&' related to ['image&', 'load&', 'cs+##s&', 'pop+##up&', 'text+##box&']
# Topic '64+##bit&' related to ['64+##bit&', 'memory&', 'c++++&', 'keyboard&', 'arm&']
# Topic 'template+##s&' related to ['template+##s&', 'ms+##bu+##il+##d&', 'w+##sd+##l&', 'j+##que+##ry&', 'v+##ba&']
# Topic '.+h+##ta+##cc+##ess&' related to ['.+h+##ta+##cc+##ess&', 'j+##que+##ry&', 'del+##phi&', 'my+##s+##q+##l&', 'if+##ram+##e&']
# Topic 'eclipse&' related to ['eclipse&', 'intel+##li+##j+idea&', 'cm+##ake&', 'jun+##it&', 'id+##e&']
# Topic 'com&' related to ['com&', 'o+##db+##c&', 'dl+##l&', 'ms+access&', 'serial+port&']
# Topic 'per+##l&' related to ['per+##l&', 'g+##cc&', 'v+##b+##6&', 'st+##l&', 'vi+##m&']
# Topic 'locking&' related to ['locking&', 'ur+##l+re+##writing&', 'as+##yn+##ch+##ron+##ous&', 'log+##in&', 'concurrency&']
# Topic 'if+##ram+##e&' related to ['if+##ram+##e&', 'j+##que+##ry&', 'w+##pf&', 'sv+##n&', 'tree+##view&']
# Topic 'audio&' related to ['audio&', 'ff+##mp+##eg&', 'streaming&', 'video&', 'sd+##k&']
# Topic 'sorting&' related to ['sorting&', 'grid+##view&', 'par+##sing&', 'filter&', 'array+##list&']
# Topic 'f+#&' related to ['f+#&', 'base+##64&', 'c++++&', 'x+##86&', 'aw+##k&']
# Topic 'count&' related to ['count&', 'list+##box&', 'combo+##box&', 'array+##list&', 'label&']
# Topic 'x+##86&' related to ['x+##86&', 'he+##x&', 'st+##l&', 'g+##db&', 'arm&']
# Topic 'assembly&' related to ['assembly&', 'c++++&', 'kernel&', 'call+##back&', 'objective+c&']
# Topic 'documentation&' related to ['documentation&', 'plug+##ins&', 'ms+##bu+##il+##d&', 'as+##p+.+net+mv+##c&', 'api&']
# Topic 'download&' related to ['download&', 'ur+##l&', 'if+##ram+##e&', 'res+##ize&', 'up+##load&']
# Topic 'maps&' related to ['maps&', 'google+app+engine&', 'internet+explorer&', 'fire+##fo+##x&', 'as+##p+.+net&']
# Topic 'bash&' related to ['bash&', 'em+##ac+##s&', 'cy+##g+##win&', 'x+##code&', 'del+##phi&']
# Topic 'data+binding&' related to ['data+binding&', 'design&', 'entity+framework&', 'grid+##view&', 'configuration&']
# Topic 'ft+##p&' related to ['ft+##p&', 'ii+##s&', 'v+##b+##6&', 'd+##ns&', 'sv+##n&']
# Topic 'tags&' related to ['tags&', 'filter&', 'j+##que+##ry&', 'if+##ram+##e&', 'nh+##ibe+##rna+##te&']
# Topic 'ss+##is&' related to ['ss+##is&', 'w+##sd+##l&', '.+net&', 'or+##m&', 'api&']
# Topic 'sync+##hr+##oni+##zation&' related to ['sync+##hr+##oni+##zation&', 'concurrency&', 'multi+##th+##rea+##ding&', 'pt+##hre+##ads&', 'file+up+##load&']
# Topic 'methods&' related to ['methods&', 'initial+##ization&', 'scope&', 'properties&', 'reference&']
# Topic 'cs+##s+selector+##s&' related to ['cs+##s+selector+##s&', 'properties&', 'data+##table&', 'scope&', 'label&']
# Topic 'code+##ign+##iter&' related to ['code+##ign+##iter&', 'dj+##ango&', 'php+##my+##ad+##min&', 'word+##press&', 'active+##re+##cor+##d&']
# Topic 'zen+##d+framework&' related to ['zen+##d+framework&', 'as+##p+.+net&', 'active+##re+##cor+##d&', 'wc+##f&', 'google+app+engine&']
# Topic 'crypt+##ography&' related to ['crypt+##ography&', 'encryption&', 'cold+##fusion&', 'web+services&', 'algorithm&']
# Topic 'names+##pace+##s&' related to ['names+##pace+##s&', 'xp+##ath&', 'closure+##s&', 'actions+##cript+3&', 'dl+##l&']
# Topic 'command+line&' related to ['command+line&', 'w+##sd+##l&', 'de+##bu+##gging&', 'v+##ba&', 'ms+##bu+##il+##d&']
# Topic 'shell&' related to ['shell&', 'cm+##d&', 'g+##cc&', 'per+##l&', 'command+line&']
# Topic 't+##fs&' related to ['t+##fs&', 'wi+##x&', 'wc+##f&', 'ms+##bu+##il+##d&', 'as+##p+.+net&']
# Topic 'logic&' related to ['logic&', 'math&', 'design+patterns&', 'functional+programming&', 'multi+##dim+##ens+##ional+array&']
# Topic 'configuration&' related to ['configuration&', 'wi+##x&', 'de+##bu+##gging&', 'ms+##bu+##il+##d&', 'command+line&']
# Topic 'mer+##cu+##rial&' related to ['mer+##cu+##rial&', 'gr+##ail+##s&', 'word+##press&', 'gma+##il&', 'dr+##up+##al&']
# Topic 'operating+system&' related to ['operating+system&', 'windows&', 'cy+##g+##win&', 'linux&', 'em+##ac+##s&']
# Topic 'kernel&' related to ['kernel&', 'keyboard&', 'c++++&', 'arm&', 'os+##x&']
# Topic 'nh+##ibe+##rna+##te&' related to ['nh+##ibe+##rna+##te&', 'lin+##q&', 'my+##s+##q+##l&', 'j+##que+##ry&', 'hi+##ber+##nate&']
# Topic 'group+by&' related to ['group+by&', 'include&', 'class&', 'construct+##or&', 'get&']
# Topic 'ff+##mp+##eg&' related to ['ff+##mp+##eg&', 'audio&', 'streaming&', 'video&', 'compression&']
# Topic 'dictionary&' related to ['dictionary&', 'reference&', 'xp+##ath&', 'array+##list&', 'sorting&']
# Topic 'properties&' related to ['properties&', 'methods&', 'initial+##ization&', 'scope&', 'parameters&']
# Topic 'keyboard&' related to ['keyboard&', 'terminal&', 'serial+port&', 'c++++&', 'os+##x&']
# Topic 'macro+##s&' related to ['macro+##s&', 'dl+##l&', 'g+##cc&', 'actions+##cript+3&', 'c+#&']
# Topic 'interface&' related to ['interface&', 'methods&', 'initial+##ization&', 'properties&', 'scope&']
# Topic 'dial+##og&' related to ['dial+##og&', 'tree+##view&', 'j+##que+##ry&', 'if+##ram+##e&', 'w+##pf&']
# Topic 'iphone&' related to ['iphone&', 'ios&', 'android&', 'apples+##cript&', 'maps&']
# Topic 'reference&' related to ['reference&', 'methods&', 'initial+##ization&', 'it+##era+##tor&', 'operator+over+##loading&']
# Topic 'ms+access&' related to ['ms+access&', 'o+##db+##c&', 'certificate&', 'batch+file&', 'jp+##a&']
# Topic 'v+##ba&' related to ['v+##ba&', 'j+##que+##ry&', 'command+line&', 'w+##pf&', 'v+##bs+##cript&']
# Topic 'focus&' related to ['focus&', 'menu&', 'button&', 'save&', 'data+##gr+##id&']
# Topic 'it+##era+##tor&' related to ['it+##era+##tor&', 'initial+##ization&', 'construct+##or&', 'map&', 'fore+##ach&']
# Topic 'visual+c++++&' related to ['visual+c++++&', 'c++++&', 'objective+c&', 'assembly&', 'c+#&']
# Topic 'link+##er&' related to ['link+##er&', 'per+##l&', 'm+##fc&', 'cr+##on&', 'sv+##n&']
# Topic 'mod+re+##write&' related to ['mod+re+##write&', 'time+##out&', 'click&', 'ur+##l+re+##writing&', 'stream&']
# Topic 'cocoa&' related to ['cocoa&', 'net+##be+##ans&', '.+net&', 'cookies&', 'java+me&']
# Topic 'events&' related to ['events&', 'configuration&', 'grid+##view&', 'pop+##up&', 'connection&']
# Topic 'garbage+collection&' related to ['garbage+collection&', 'w+##sd+##l&', 'de+##bu+##gging&', 'v+##bs+##cript&', 'memory+leaks&']
# Topic 'user&' related to ['user&', 'gi+##t&', 'cr+##on&', 'x+##code&', 'em+##ac+##s&']
# Topic 'time&' related to ['time&', 'date+##time&', 'time+##zone&', 'date&', 'calendar&']
# Topic 'routing&' related to ['routing&', 'local+##hos+##t&', 'web+con+##fi+##g&', 'log+##in&', 'ur+##l+re+##writing&']
# Topic 'apple+##t&' related to ['apple+##t&', 'java+##script&', 'w+##sd+##l&', 'j+##son&', 'slide+##r&']
# Topic 'path&' related to ['path&', 'dl+##l&', 'file&', 'scroll&', 'actions+##cript+3&']
# Topic 'charts&' related to ['charts&', 'ui+##ima+##ge+##view&', 'maps&', 'google+app+engine&', 'it+##ex+##t&']
# Topic 'graph&' related to ['graph&', 'sorting&', 'layout&', 'data+##table&', 'grid+##view&']
# Topic 'run+##time&' related to ['run+##time&', 'res+##ize&', 'data+##gr+##id&', 'v+##ba&', 'command&']
# Topic 'object&' related to ['object&', 'interface&', 'initial+##ization&', 'properties&', 'class&']
# Topic 'operators&' related to ['operators&', 'methods&', 'operator+over+##loading&', 'scope&', 'reference&']
# Topic 'gi+##t&' related to ['gi+##t&', 'sv+##n&', 'cr+##on&', 'q+##t&', 'ii+##s&']
# Topic 'pay+##pal&' related to ['pay+##pal&', 'gma+##il&', 'glass+##fish&', 'facebook&', 'https&']
# Topic 'scala&' related to ['scala&', 'c++++&', 'c+#&', 'st+##l&', 'lu+##a&']
# Topic 'list&' related to ['list&', 'construct+##or&', 'string&', 'class&', 'comparison&']
# Topic 'cake+##ph+##p&' related to ['cake+##ph+##p&', 'word+##press&', 'gr+##ail+##s&', 'dr+##up+##al&', 'php+##my+##ad+##min&']
# Topic 'pd+##o&' related to ['pd+##o&', 'array+##list&', 'reference&', 'par+##sing&', 'sorting&']
# Topic 'ss+##l&' related to ['ss+##l&', 'dr+##up+##al&', 'gma+##il&', 'j+##bos+##s&', 'cl+##oj+##ure&']
# Topic 'https&' related to ['https&', 'spring+security&', 'web+crawl+##er&', 'word+##press&', 'gma+##il&']
# Topic 'variables&' related to ['variables&', 'methods&', 'attributes&', 'arrays&', 'operator+over+##loading&']
# Topic 'service&' related to ['service&', 'wc+##f&', 'web+services&', 'ss+##is&', 'wi+##x&']
# Topic 'merge&' related to ['merge&', 'copy&', 'make+##fi+##le&', 'select&', 'vi+##m&']
# Topic 'floating+point&' related to ['floating+point&', 'cu+##da&', 'f+#&', 'base+##64&', 'boo+##lean&']
# Topic 'internet+explorer+8&' related to ['internet+explorer+8&', 'include&', 'ss+##h&', 'ms+access&', 'ts+##q+##l&']
# Topic 'gr+##ail+##s&' related to ['gr+##ail+##s&', 'gma+##il&', 'mer+##cu+##rial&', 'app+store&', 'glass+##fish&']
# Topic 'x+##na&' related to ['x+##na&', 'gr+##ail+##s&', 'mer+##cu+##rial&', 'glass+##fish&', 'it+##ex+##t&']
# Topic 'exception+handling&' related to ['exception+handling&', 'logging&', 'version+control&', 'plug+##ins&', 'wc+##f&']
# Topic 'google+analytics&' related to ['google+analytics&', 'maps&', 'google+app+engine&', 'website&', 'share+##point&']
# Topic 'sv+##g&' related to ['sv+##g&', 'ii+##s+7&', 'luce+##ne&', 'fluent+nh+##ibe+##rna+##te&', 'jett+##y&']
# Topic 'local+##ization&' related to ['local+##ization&', 'international+##ization&', 'documentation&', 'script+##ing&', 'plug+##ins&']
# Topic 'reflection&' related to ['reflection&', 'as+##p+.+net+mv+##c&', 'ref+##act+##orin+##g&', 'nh+##ibe+##rna+##te&', 'multi+##dim+##ens+##ional+array&']
# Topic 'combo+##box&' related to ['combo+##box&', 'list+##box&', 'menu&', 'label&', 'pop+##up&']
# Topic 'g+##cc&' related to ['g+##cc&', 'per+##l&', 'mat+##lab&', 'v+##b+.+net&', 'v+##b+##6&']
# Topic 'inheritance&' related to ['inheritance&', 'methods&', 'entity+framework&', 'design&', 'data+binding&']
# Topic 'web+##ser+##ver&' related to ['web+##ser+##ver&', 'code+##ign+##iter&', 'active+##re+##cor+##d&', 'share+##point&', 'google+app+engine&']
# Topic 'console&' related to ['console&', 'command+line&', 'terminal&', 'user+controls&', 'dl+##l&']
# Topic 'terminal&' related to ['terminal&', 'console&', 'v+##b+##6&', 'serial+port&', 'dl+##l&']
# Topic 'layout&' related to ['layout&', 'grid+##view&', 'res+##ize&', 'tree+##view&', 'text+##box&']
# Topic 'sum&' related to ['sum&', 'order&', 'comparison&', 'print+##f&', 'join&']
# Topic 'entity+framework&' related to ['entity+framework&', 'design&', 'data+binding&', 'database&', 'configuration&']
# Topic 'st+##l&' related to ['st+##l&', 'g+##db&', 'per+##l&', 'v+##b+##6&', 'c+#&']
# Topic 'crash&' related to ['crash&', 'memory+leaks&', 'de+##bu+##gging&', 'garbage+collection&', 'performance&']
# Topic 'scroll&' related to ['scroll&', 'copy&', 'reg+##ex&', 'path&', 'file&']
# Topic 'key&' related to ['key&', 'insert&', 'construct+##or&', 'string&', 'print+##f&']
# Topic 'camera&' related to ['camera&', 'w+##pf&', 'silver+##light&', 'q+##t&', 'load&']
# Topic 'actions+##cript&' related to ['actions+##cript&', 'flex&', 'flash&', 'x+##mp+##p&', 'open+##gl&']
# Topic 'word+##press&' related to ['word+##press&', 'gma+##il&', 'php+##my+##ad+##min&', 'fire+##fo+##x&', 'dr+##up+##al&']
# Topic 'text&' related to ['text&', 'v+##b+##6&', 'v+##ba&', 'load&', 'cs+##s&']
# Topic 'j+##v+##m&' related to ['j+##v+##m&', 'apple+##t&', 'er+##lang&', 'jd+##bc&', 'net+##be+##ans&']
# Topic 'embedded&' related to ['embedded&', '.+net&', 'windows&', 'm+##fc&', 'ss+##is&']
# Topic 'random&' related to ['random&', 'hash&', 'algorithm&', 'data+##gr+##id+##view&', 'en+##ums&']
# Topic 'google+chrome&' related to ['google+chrome&', 'silver+##light&', '.+net+3+.+5&', 'g+##wt&', 'em+##ac+##s&']
# Topic 'gt+##k&' related to ['gt+##k&', 'cl+##oj+##ure&', 'mat+##pl+##ot+##lib&', 'dr+##up+##al&', 'cy+##g+##win&']
# Topic 'rs+##pe+##c&' related to ['rs+##pe+##c&', 'performance&', 'validation&', 'build&', 'v+##ba&']
# Topic 'make+##fi+##le&' related to ['make+##fi+##le&', 'vi+##m&', 'per+##l&', 'actions+##cript+3&', 'dl+##l&']
# Topic 'wi+##dget&' related to ['wi+##dget&', 'framework+##s&', 'ajax&', 'maps&', 'java+##script&']
# Topic 'j+##ms&' related to ['j+##ms&', 'as+##p+.+net&', 'wc+##f&', 'google+app+engine&', '.+net&']
# Topic 'e+##j+##b&' related to ['e+##j+##b&', 'j+##bos+##s&', 'tom+##cat&', 'dj+##ango&', 'dr+##up+##al&']
# Topic 'generic+##s&' related to ['generic+##s&', 'depend+##encies&', 'java+##script&', 'w+##sd+##l&', 'j+##son&']
# Topic 'se+##d&' related to ['se+##d&', 'f+#&', 'floating+point&', 'cu+##da&', 'r&']
# Topic 'framework+##s&' related to ['framework+##s&', 'wi+##dget&', 'java+##script&', 'maps&', 'google+app+engine&']
# Topic 'st+##ru+##ct&' related to ['st+##ru+##ct&', 'size&', 'binding&', 'object&', 'types&']
# Topic 'apples+##cript&' related to ['apples+##cript&', 'safari&', 'fire+##fo+##x&', 'internet+explorer&', 'maps&']
# Topic 'safari&' related to ['safari&', 'apples+##cript&', 'internet+explorer&', 'fire+##fo+##x&', 'google+app+engine&']
# Topic 'statistics&' related to ['statistics&', 'resources&', 'lin+##q+to+entities&', 'stored+procedures&', 'testing&']
# Topic 'password+##s&' related to ['password+##s&', 'log+##in&', 'authentication&', 'encryption&', 'foreign+keys&']
# Topic 'format+##ting&' related to ['format+##ting&', 'xp+##ath&', 'x+##sl+##t&', 'performance&', 'j+##son&']
# Topic 'memory+management&' related to ['memory+management&', 'garbage+collection&', '.+net&', 'v+##bs+##cript&', 'm+##fc&']
# Topic 'ma+##ven+2&' related to ['ma+##ven+2&', 'hi+##ber+##nate&', 'do+##jo&', 'q+##t&', 'powers+##hell&']
# Topic 'list+##view&' related to ['list+##view&', 'list+##box&', 'search&', 'download&', 'combo+##box&']
# Topic 'header&' related to ['header&', 'file&', 'encoding&', 'scroll&', 'reg+##ex&']
# Topic 'themes&' related to ['themes&', 'cs+##s&', 'background&', 'data+##gr+##id+##view&', 'text&']
# Topic 'times+##tam+##p&' related to ['times+##tam+##p&', 'reg+##ex&', 'compilation&', 'construct+##or&', 'st+##l&']
# Topic 'window&' related to ['window&', 'check+##box&', 'data+##gr+##id+##view&', 'hyper+##link&', 'data+##gr+##id&']
# Topic 'delegates&' related to ['delegates&', 'plug+##ins&', 'ref+##act+##orin+##g&', 'code+##ign+##iter&', 'nh+##ibe+##rna+##te&']
# Topic 'jp+##a&' related to ['jp+##a&', 'ss+##is&', 'performance&', 'w+##sd+##l&', 'o+##db+##c&']
# Topic 'transactions&' related to ['transactions&', 'database&', 'stored+procedures&', 'logging&', 'ca+##ching&']
# Topic 'encoding&' related to ['encoding&', 'binary&', 'header&', 'xp+##ath&', 'serial+##ization&']
# Topic 'module&' related to ['module&', 'dl+##l&', 'process&', 'macro+##s&', 'make+##fi+##le&']
# Topic 'build&' related to ['build&', 'install&', 'process&', 'run+##time&', 'res+##ize&']
# Topic 'automation&' related to ['automation&', 'import&', 'format+##ting&', 'script+##ing&', 'command+line&']
# Topic 'post&' related to ['post&', 'red+##ire+##ct&', 'combo+##box&', 'select&', 'batch+file&']
# Topic 'google+app+engine&' related to ['google+app+engine&', 'as+##p+.+net&', 'share+##point&', 'maps&', 'internet+explorer&']
# Topic 'file+up+##load&' related to ['file+up+##load&', 'web+applications&', 'files+##yst+##em+##s&', 'web+##forms&', 'logging&']
# Topic 'jar&' related to ['jar&', 'per+##l&', 'apple+##t&', 'log+##4+##j&', 'g+##wt&']
# Topic 'facebook&' related to ['facebook&', 'gma+##il&', 'twitter&', 'word+##press&', 'maps&']
# Topic 'gr+##oo+##vy&' related to ['gr+##oo+##vy&', 'dr+##up+##al&', 'gma+##il&', 'php+##my+##ad+##min&', 'cl+##oj+##ure&']
# Topic 'p+##y+##q+##t&' related to ['p+##y+##q+##t&', 'text+##box&', 'pop+##up&', 'auto+##com+##ple+##te&', 'wi+##x&']
# Topic 'mat+##lab&' related to ['mat+##lab&', 'g+##cc&', 'per+##l&', 'v+##b+.+net&', 'late+##x&']
# Topic 'font+##s&' related to ['font+##s&', 'excel&', 'v+##b+##6&', 'x+##86&', 'text&']
# Topic 'calendar&' related to ['calendar&', 'time+##zone&', 'data+##gr+##id&', 'text+##box&', 'timer&']
# Topic 'ld+##ap&' related to ['ld+##ap&', 'd+##ns&', 'wc+##f&', '.+net&', 'w+##sd+##l&']
# Topic 'fore+##ach&' related to ['fore+##ach&', 'it+##era+##tor&', 'initial+##ization&', 'pointer+##s&', 'function&']
# Topic 'report&' related to ['report&', 'cs+##v&', 'text&', 'scroll&', 'format+##ting&']
# Topic 'as+##yn+##ch+##ron+##ous&' related to ['as+##yn+##ch+##ron+##ous&', 'nest+##ed&', 'logging&', 'de+##bu+##gging&', 'sockets&']
# Topic 'tree&' related to ['tree&', 'map&', 'pro+##log&', 'it+##era+##tor&', 'path&']
# Topic 'active+##re+##cor+##d&' related to ['active+##re+##cor+##d&', 'as+##p+.+net+mv+##c&', 'as+##p+.+net&', 'plug+##ins&', 'auto+##com+##ple+##te&']
# Topic 'gr+##ep&' related to ['gr+##ep&', 'reg+##ex&', 'he+##x&', 'compilation&', 'st+##l&']
# Topic 'array+##list&' related to ['array+##list&', 'it+##era+##tor&', 'list+##box&', 'sub+##que+##ry&', 'reference&']
# Topic 'jd+##bc&' related to ['jd+##bc&', '.+net&', 'opens+##sl&', 'sql+##ite&', 'er+##lang&']
# Topic 'late+##x&' related to ['late+##x&', 'mat+##lab&', 'v+##b+.+net&', 'per+##l&', 'format+##ting&']
# Topic 'nl+##p&' related to ['nl+##p&', 'functional+programming&', 'math&', 'international+##ization&', 'mocking&']
# Topic 'web+##forms&' related to ['web+##forms&', 'as+##p+.+net+mv+##c&', 'web+applications&', 'plug+##ins&', 'installation&']
# Topic 'export&' related to ['export&', 'batch+file&', 'session&', 'install&', 'run+##time&']
# Topic 'search&' related to ['search&', 'list+##view&', 'data+##gr+##id+##view&', 'list+##box&', 'download&']
# Topic 'java+me&' related to ['java+me&', 'j+##ms&', '.+net&', 'as+##p+.+net&', 'google+app+engine&']
# Topic 'mobile&' related to ['mobile&', 'embedded&', 'java+me&', 'android&', 'iphone&']
# Topic 'x+##am+##l&' related to ['x+##am+##l&', 'grid&', 'j+##que+##ry&', 'v+##ba&', 'w+##sd+##l&']
# Topic 'streaming&' related to ['streaming&', 'video&', 'audio&', 'compression&', 'ff+##mp+##eg&']
# Topic 'java+ee&' related to ['java+ee&', 'framework+##s&', 'java&', 'cookies&', 'java+me&']
# Topic 'ser+##v+##lets&' related to ['ser+##v+##lets&', 'as+##p+.+net&', '.+net&', 'internet+explorer&', 'visual+studio+2008&']
# Topic 'construct+##or&' related to ['construct+##or&', 'it+##era+##tor&', 'class&', 'string&', 'copy&']
# Topic 'ng+##in+##x&' related to ['ng+##in+##x&', '.+net&', 'php+##my+##ad+##min&', 'tom+##cat&', 'id+##e&']
# Topic 'copy&' related to ['copy&', 'insert&', 'file&', 'construct+##or&', 'scroll&']
# Topic 'local+##hos+##t&' related to ['local+##hos+##t&', 'wc+##f&', 'proxy&', 'active+##re+##cor+##d&', 'wi+##x&']
# Topic 'cs+##v&' related to ['cs+##v&', 'xp+##ath&', 'file&', 'text&', 'actions+##cript+3&']
# Topic 'binary&' related to ['binary&', 'encoding&', 'xp+##ath&', 'string&', 'header&']
# Topic 'log+##in&' related to ['log+##in&', 'proxy&', 'local+##hos+##t&', 'auto+##com+##ple+##te&', 'wc+##f&']
# Topic 'get&' related to ['get&', 'return&', 'string&', 'split&', 'construct+##or&']
# Topic 'jett+##y&' related to ['jett+##y&', 'luce+##ne&', 'ii+##s+7&', 'fluent+nh+##ibe+##rna+##te&', 'glass+##fish&']
# Topic 'install&' related to ['install&', 'build&', 'batch+file&', 'session&', 'download&']
# Topic 'seo&' related to ['seo&', 'website&', 'google+analytics&', 'google+app+engine&', 'word+##press&']
# Topic 'g+##wt&' related to ['g+##wt&', 'log+##4+##j&', 'google+chrome&', 'em+##ac+##s&', 'jax+##b&']
# Topic 'j+##bos+##s&' related to ['j+##bos+##s&', 'silver+##light&', 'tom+##cat&', 'x+##code&', 'fire+##fo+##x&']
# Topic 'tree+##view&' related to ['tree+##view&', 'if+##ram+##e&', 'w+##pf&', 'data+##gr+##id&', 'data+##gr+##id+##view&']
# Topic 'x+##mp+##p&' related to ['x+##mp+##p&', 'j+##ms&', 'version+control&', 'wc+##f&', '.+net&']
# Topic 'hash+##ma+##p&' related to ['hash+##ma+##p&', 'fore+##ach&', 'sub+##que+##ry&', 'pointer+##s&', 'print+##f&']
# Topic 'compression&' related to ['compression&', 'version+control&', 'as+##p+.+net+mv+##c&', 'par+##sing&', 'sd+##k&']
# Topic 'view&' related to ['view&', 'construct+##or&', 'it+##era+##tor&', 'sub+##que+##ry&', 'pointer+##s&']
# Topic 'tc+##p&' related to ['tc+##p&', 'ft+##p&', 'v+##b+##6&', 'd+##ns&', 'opens+##sl&']
# Topic 'curl&' related to ['curl&', 'j+##que+##ry&', 'hi+##ber+##nate&', 'cr+##on&', 'if+##ram+##e&']
# Topic 'web+##kit&' related to ['web+##kit&', 'fire+##fo+##x&', 'do+##jo&', 'silver+##light&', 'google+app+engine&']
# Topic 'j+##que+##ry+ui&' related to ['j+##que+##ry+ui&', 'run+##time&', 'de+##bu+##gging&', 'nh+##ibe+##rna+##te&', 'res+##ize&']
# Topic 'nu+##mp+##y&' related to ['nu+##mp+##y&', 'er+##lang&', 'log+##4+##j&', 'net+##be+##ans&', 'g+##wt&']
# Topic 'luce+##ne&' related to ['luce+##ne&', 'jett+##y&', 'ii+##s+7&', 'fluent+nh+##ibe+##rna+##te&', 'sv+##g&']
# Topic 'navigation&' related to ['navigation&', 'w+##pf&', 'if+##ram+##e&', 'j+##que+##ry&', 'tab+##s&']
# Topic 'poly+##morphism&' related to ['poly+##morphism&', 'initial+##ization&', 'methods&', 'operator+over+##loading&', 'it+##era+##tor&']
# Topic 'ssr+##s+2008&' related to ['ssr+##s+2008&', 'calendar&', 'date+##pic+##ker&', 'time+##zone&', 'data+##gr+##id+##view&']
# Topic 'boost&' related to ['boost&', 'template+##s&', 'g+##cc&', 'm+##fc&', 'ms+##bu+##il+##d&']
# Topic 'routes&' related to ['routes&', 'routing&', 'map&', 'google+maps&', 'grid+##view&']
# Topic 'mapping&' related to ['mapping&', 'google+analytics&', 'google+maps&', 'web+##ser+##ver&', 'maps&']
# Topic 'image+processing&' related to ['image+processing&', 'interface+builder&', 'charts&', 'compression&', 'ui+##ima+##ge&']
# Topic 'gps&' related to ['gps&', 'ant&', 'reg+##ex&', 'st+##rut+##s+##2&', 'tc+##p&']
# Topic 'migration&' related to ['migration&', 'merge&', 'sql+server+2008&', 'process&', 'performance&']
# Topic '3d&' related to ['3d&', 'open+##gl&', 'graphics&', 'visual+studio&', 'cs+##s&']
# Topic 'geometry&' related to ['geometry&', 'dr+##up+##al&', 'tiny+##mc+##e&', 'dj+##ango&', 'silver+##light&']
# Topic 'certificate&' related to ['certificate&', 'v+##b+##6&', 'ft+##p&', 'ms+access&', 'per+##l&']
# Topic 'singleton&' related to ['singleton&', 'methods&', 'operator+over+##loading&', 'reference&', 'initial+##ization&']
# Topic 'icons&' related to ['icons&', 'tab+##s&', 'ui+##we+##b+##view&', 'w+##pf&', 'navigation&']
# Topic 'split&' related to ['split&', 'copy&', 'string&', 'insert&', 'select&']
# Topic 'web+con+##fi+##g&' related to ['web+con+##fi+##g&', 'web+applications&', 'as+##p+.+net+mv+##c&', 'permission+##s&', 'plug+##ins&']
# Topic 'http+header+##s&' related to ['http+header+##s&', 'spring+mv+##c&', 'xml+##ht+##tp+##re+##quest&', 'https&', 'files+##yst+##em+##s&']
# Topic 'wi+##x&' related to ['wi+##x&', 'windows+install+##er&', 'ms+##bu+##il+##d&', 't+##fs&', 'wc+##f&']
# Topic 'cr+##on&' related to ['cr+##on&', 'sv+##n&', 'gi+##t&', 'if+##ram+##e&', 'ii+##s&']
# Topic 'bit+##ma+##p&' related to ['bit+##ma+##p&', 'open+##gl+es&', 'dev+##ex+##press&', 'ui+##view&', 'g+##wt&']
# Topic 'serial+port&' related to ['serial+port&', 'st+##l&', 'g+##db&', 'terminal&', 'v+##b+##6&']
# Topic 'app+store&' related to ['app+store&', 'gr+##ail+##s&', 'gma+##il&', 'word+##press&', 'windows+services&']
# Topic 'de+##bian&' related to ['de+##bian&', 'id+##e&', '.+net&', 'image+##ma+##gic+##k&', 'framework+##s&']
# Topic 'print+##f&' related to ['print+##f&', 'string&', 'segment+##ation+fault&', 'construct+##or&', 'pointer+##s&']
# Topic 'plot&' related to ['plot&', 'check+##box&', 'data+##gr+##id&', 'layout&', 'tree+##view&']
# Topic 'cm+##ake&' related to ['cm+##ake&', 'jun+##it&', 'intel+##li+##j+idea&', 'eclipse&', 'tom+##cat&']
# Topic 'duplicate+##s&' related to ['duplicate+##s&', 'dr+##up+##al&', 'ss+##l&', 'jax+##b&', 'em+##ac+##s&']
# Topic 'st+##rut+##s+##2&' related to ['st+##rut+##s+##2&', 'm+##fc&', 'v+##b+##6&', 'q+##t&', 'ii+##s&']
# Topic 'net+##be+##ans&' related to ['net+##be+##ans&', 'log+##4+##j&', 'slide+##r&', 'em+##ac+##s&', 'g+##wt&']
# Topic 'lin+##q+to+entities&' related to ['lin+##q+to+entities&', 'data+##table&', 'database&', 'entity+framework&', 'stored+procedures&']
# Topic 'dr+##up+##al&' related to ['dr+##up+##al&', 'ss+##l&', 'dj+##ango&', 'gma+##il&', 'php+##my+##ad+##min&']
# Topic 'arguments&' related to ['arguments&', 'if+statement&', 'include&', 'input&', 'group+by&']
# ...
# Topic 'blackberry&' related to ['blackberry&', 'silver+##light&', 'web+##kit&', 'background&', 'fire+##fo+##x&']
# Topic 'char&' related to ['char&', 'pointer+##s&', 'print+##f&', 'string&', 'segment+##ation+fault&']
# Topic 'tel+##erik&' related to ['tel+##erik&', 'glass+##fish&', 'jett+##y&', 'dr+##up+##al&', 'gma+##il&']
# Topic 'click&' related to ['click&', 'time+##out&', 'focus&', 'data+##gr+##id&', 'save&']
# Topic 'apache+##2&' related to ['apache+##2&', 'd+##ns&', 'as+##p+.+net&', 'ii+##s&', 'wc+##f&']
# Topic 'azure&' related to ['azure&', 'amazon+s+##3&', 'fire+##fo+##x&', 'se+##len+##ium&', 'tom+##cat&']
# Topic 'do+##jo&' related to ['do+##jo&', 'id+##e&', 'm+##fc&', 'q+##t&', 'silver+##light&']
# Topic 'styles&' related to ['styles&', 'data+binding&', 'layout&', 'grid+##view&', 'design&']
# Topic 'format&' related to ['format&', 'xp+##ath&', 'format+##ting&', 'x+##sl+##t&', 'file&']
# Topic 'res+##ize&' related to ['res+##ize&', 'run+##time&', 'user+controls&', 'data+##gr+##id&', 'if+##ram+##e&']
# Topic 'machine+learning&' related to ['machine+learning&', 'fluent+nh+##ibe+##rna+##te&', 'jett+##y&', 'se+##len+##ium&', 'ruby+on+rails&']
# Topic 'return&' related to ['return&', 'get&', 'join&', 'function&', 'insert&']
# Topic 'dynamic&' related to ['dynamic&', 'initial+##ization&', 'methods&', 'it+##era+##tor&', 'properties&']
# Topic 'compilation&' related to ['compilation&', 'g+##db&', 'reg+##ex&', 'st+##l&', 'he+##x&']
# Topic 'call+##back&' related to ['call+##back&', 'c++++&', 'f+#&', 'assembly&', 'c+#&']
# Topic 'aw+##k&' related to ['aw+##k&', 'reg+##ex&', 'st+##l&', 'has+##kell&', 'c++++&']
# Topic 'sql+##al+##che+##my&' related to ['sql+##al+##che+##my&', 'my+##s+##q+##l&', 'nh+##ibe+##rna+##te&', 'linked+list&', 'active+##re+##cor+##d&']
# Topic 'p+##y+##game&' related to ['p+##y+##game&', 'x+##na&', 'it+##ex+##t&', 'user+interface&', 'charts&']
# Topic 'youtube&' related to ['youtube&', 'facebook&', 'twitter&', 'google+analytics&', 'website&']
# Topic 'dev+##ex+##press&' related to ['dev+##ex+##press&', 'x+##86&', 'he+##x&', 'g+##db&', 'f+#&']
# Topic 'joo+##ml+##a&' related to ['joo+##ml+##a&', 'api&', 'as+##p+.+net+mv+##c&', 'ui+##table+##view&', 'plug+##ins&']
# Topic 'fluent+nh+##ibe+##rna+##te&' related to ['fluent+nh+##ibe+##rna+##te&', 'jett+##y&', 'luce+##ne&', 'cl+##oj+##ure&', 'sv+##g&']
# Topic 'canvas&' related to ['canvas&', 'button&', 'plot&', 'image&', 'layout&']
# Topic 'glass+##fish&' related to ['glass+##fish&', 'jett+##y&', 'gr+##ail+##s&', 'tel+##erik&', 'gma+##il&']
# Topic 'java+##f+##x&' related to ['java+##f+##x&', 'it+##ex+##t&', 'x+##na&', 'p+##y+##game&', 'user+interface&']
# Topic 'computer+vision&' related to ['computer+vision&', 'mage+##nto&', 'sv+##g&', 'ii+##s+7&', 'luce+##ne&']
# Topic 'ur+##l+re+##writing&' related to ['ur+##l+re+##writing&', 'routing&', 'de+##bu+##gging&', 'local+##hos+##t&', 'sockets&']
# Topic 'null+##point+##ere+##x+##ception&' related to ['null+##point+##ere+##x+##ception&', 'mocking&', 'ur+##l+re+##writing&', 'log+##in&', 'ref+##act+##orin+##g&']
# Topic 'web&' related to ['web&', 'spring+mv+##c&', 'gi+##th+##ub&', 'youtube&', 'twitter&']
# Topic 'xml+##ht+##tp+##re+##quest&' related to ['xml+##ht+##tp+##re+##quest&', 'zen+##d+framework&', 'wc+##f&', 'ajax&', 'active+##re+##cor+##d&']
# Topic 'it+##ex+##t&' related to ['it+##ex+##t&', 'word+##press&', 'mer+##cu+##rial&', 'gr+##ail+##s&', 'gma+##il&']
# Topic 'segment+##ation+fault&' related to ['segment+##ation+fault&', 'pointer+##s&', 'string&', 'print+##f&', 'it+##era+##tor&']
# Topic 'tiny+##mc+##e&' related to ['tiny+##mc+##e&', 'silver+##light&', 'em+##ac+##s&', 'x+##code&', 'q+##t&']
# Topic 'windows+7&' related to ['windows+7&', 'open+##gl&', 'visual+studio+2008&', 'silver+##light&', 'windows&']
# Topic 'cu+##rso+##r&' related to ['cu+##rso+##r&', 'g+##db&', 'compilation&', 'jax+##b&', 'reg+##ex&']
# Topic 'r&' related to ['r&', 'f+#&', 'dev+##ex+##press&', 'x+##86&', 'he+##x&']
# Topic 'pipe&' related to ['pipe&', 'timer&', 'copy&', 'iteration&', 'it+##era+##tor&']
# Topic 'arm&' related to ['arm&', 'st+##l&', 'os+##x&', 'x+##86&', 'g+##cc&']
# Topic 'cl+##oj+##ure&' related to ['cl+##oj+##ure&', 'dr+##up+##al&', 'gt+##k&', 'fluent+nh+##ibe+##rna+##te&', 'jett+##y&']
# Topic 'pt+##hre+##ads&' related to ['pt+##hre+##ads&', 'active+##re+##cor+##d&', 'sockets&', 'version+control&', 'multi+##dim+##ens+##ional+array&']
# Topic 'int&' related to ['int&', 'reg+##ex&', 'gr+##ep&', 'vector&', 'string&']
# Topic 'sd+##k&' related to ['sd+##k&', 'windows+install+##er&', 'google+app+engine&', 'silver+##light&', 'visual+studio&']
# Topic 'ui+##view&' related to ['ui+##view&', 'jax+##b&', 'had+##oop&', 'g+##wt&', '.+net+3+.+5&']
# Topic 'text+##view&' related to ['text+##view&', 'text+##box&', 'data+##gr+##id&', 'pop+##up&', 'menu&']
# Topic 'sms&' related to ['sms&', 'email&', 'sm+##tp&', 'tc+##p&', 'ip&']
# Topic 'jax+##b&' related to ['jax+##b&', 'g+##wt&', '.+net+3+.+5&', 'google+chrome&', 'em+##ac+##s&']
# Topic 'nsa+##rra+##y&' related to ['nsa+##rra+##y&', 'computer+vision&', 'mage+##nto&', 'ii+##s+7&', 'luce+##ne&']
# Topic 'j+##table&' related to ['j+##table&', 'sorting&', 'arrays&', 'grid+##view&', 'multi+##dim+##ens+##ional+array&']
# Topic 'ui+##text+##field&' related to ['ui+##text+##field&', 'word+##press&', 'j+##que+##ry&', 'if+##ram+##e&', 'fire+##fo+##x&']
# Topic 'mage+##nto&' related to ['mage+##nto&', 'ii+##s+7&', 'luce+##ne&', 'sv+##g&', 'jett+##y&']
# Topic 'pattern+matching&' related to ['pattern+matching&', 'exception&', 'hash+##ma+##p&', 'sub+##que+##ry&', 'replace&']
# Topic 'find&' related to ['find&', 'scala&', 'gr+##ep&', 'input&', 'c++++&']
# Topic 'compare&' related to ['compare&', 'website&', 'twitter&', 'email&', 'download&']
# Topic 'multi+##pro+##ces+##sing&' related to ['multi+##pro+##ces+##sing&', 'c++++&', 'c+#&', 'python&', 'sql+##ite&']
# Topic 'image+##ma+##gic+##k&' related to ['image+##ma+##gic+##k&', 'zen+##d+framework&', 'java+##script&', '.+net&', 'v+##bs+##cript&']
# Topic 'ui+##ima+##ge+##view&' related to ['ui+##ima+##ge+##view&', 'ui+##we+##b+##view&', 'as+##p+.+net+mv+##c&', 'auto+##com+##ple+##te&', 'user+interface&']
# Topic 'syntax+error&' related to ['syntax+error&', 'hash+##ma+##p&', 'print+##f&', 'if+statement&', 'segment+##ation+fault&']
# Topic 'ad+##mo+##b&' related to ['ad+##mo+##b&', 'ui+##we+##b+##view&', 'text+##box&', 'p+##y+##q+##t&', 'navigation&']
# Topic 'save&' related to ['save&', 'download&', 'res+##ize&', 'user+controls&', 'select&']
# Topic 'mat+##pl+##ot+##lib&' related to ['mat+##pl+##ot+##lib&', 'gt+##k&', 'cl+##oj+##ure&', 'dr+##up+##al&', 'sv+##g&']
# Topic 'life+##ray&' related to ['life+##ray&', 'combo+##box&', 'events&', 'label&', 'click&']
# Topic 'sas&' related to ['sas&', 'em+##ac+##s&', 'x+##code&', 'g+##wt&', 'jax+##b&']
# Attempted to log scalar metric loss:
# 6.127195358276367
# Attempted to log scalar metric loss:
# 3.801973819732666
# Attempted to log scalar metric loss:
# 2.7268950939178467
# Attempted to log scalar metric loss:
# 1.5874143838882446
# Attempted to log scalar metric loss:
# 0.8178501129150391
# Attempted to log scalar metric loss:
# 0.5340755581855774
# Attempted to log scalar metric loss:
# 0.46648940443992615
# Attempted to log scalar metric loss:
# 0.3713251054286957
# Attempted to log scalar metric loss:
# 0.3529081344604492
# Attempted to log scalar metric loss:
# 0.3385196030139923
# Attempted to log scalar metric loss:
# 0.3244844973087311
# Attempted to log scalar metric loss:
# 0.2652318775653839
# Attempted to log scalar metric loss:
# 0.329950213432312
# Attempted to log scalar metric loss:
# 0.2419331818819046
# Attempted to log scalar metric loss:
# 0.22145986557006836
# Attempted to log scalar metric loss:
# 0.24602025747299194
# Attempted to log scalar metric loss:
# 0.20343710482120514
# Attempted to log scalar metric loss:
# 0.19506849348545074
# Attempted to log scalar metric loss:
# 0.23848843574523926
# Attempted to log scalar metric loss:
# 0.25753459334373474
# Attempted to log scalar metric loss:
# 0.23522254824638367
# Attempted to log scalar metric loss:
# 0.23253077268600464
# Attempted to log scalar metric loss:
# 0.2270219624042511
# Attempted to log scalar metric loss:
# 0.16481707990169525
# Attempted to log scalar metric loss:
# 0.20618708431720734
# Attempted to log scalar metric loss:
# 0.23264922201633453
# Attempted to log scalar metric loss:
# 0.20234955847263336
# Attempted to log scalar metric loss:
# 0.23306459188461304
# Attempted to log scalar metric loss:
# 0.17743784189224243
# Attempted to log scalar metric loss:
# 0.23231810331344604
# Attempted to log scalar metric loss:
# 0.18134404718875885
# Attempted to log scalar metric loss:
# 0.24642764031887054
# Attempted to log scalar metric loss:
# 0.23446965217590332
# Attempted to log scalar metric loss:
# 0.22859032452106476
# Attempted to log scalar metric loss:
# 0.20709103345870972
# Attempted to log scalar metric loss:
# 0.2113642394542694
# Attempted to log scalar metric loss:
# 0.2668842077255249
# Attempted to log scalar metric loss:
# 0.2232387214899063
# Attempted to log scalar metric loss:
# 0.19456888735294342
# Attempted to log scalar metric loss:
# 0.19258424639701843
# Attempted to log scalar metric loss:
# 0.18334320187568665
# Attempted to log scalar metric loss:
# 0.2186310887336731
# Attempted to log scalar metric loss:
# 0.19600367546081543
# Attempted to log scalar metric loss:
# 0.20699243247509003
# Attempted to log scalar metric loss:
# 0.19605320692062378
# Attempted to log scalar metric loss:
# 0.23244860768318176
# Attempted to log scalar metric loss:
# 0.20328406989574432
# Attempted to log scalar metric loss:
# 0.1748829036951065
# Attempted to log scalar metric loss:
# 0.16693493723869324
# Attempted to log scalar metric loss:
# 0.17592282593250275
# Attempted to log scalar metric loss:
# 0.18595421314239502
# Attempted to log scalar metric loss:
# 0.16291707754135132
# Attempted to log scalar metric loss:
# 0.17838779091835022
# Attempted to log scalar metric loss:
# 0.1860586702823639
# Attempted to log scalar metric loss:
# 0.17615874111652374
# Attempted to log scalar metric loss:
# 0.16589176654815674
# Attempted to log scalar metric loss:
# 0.16313746571540833
# Attempted to log scalar metric loss:
# 0.1747010350227356
# Attempted to log scalar metric loss:
# 0.18103407323360443
# Attempted to log scalar metric loss:
# 0.139871746301651
# Attempted to log scalar metric loss:
# 0.18879710137844086
# Attempted to log scalar metric loss:
# 0.17269904911518097
# Attempted to log scalar metric loss:
# 0.17349888384342194
# Attempted to log scalar metric loss:
# 0.16991090774536133
# Attempted to log scalar metric loss:
# 0.18520446121692657
# Attempted to log scalar metric loss:
# 0.1397324800491333
# Attempted to log scalar metric loss:
# 0.16118209064006805
# Attempted to log scalar metric loss:
# 0.20977792143821716
# Attempted to log scalar metric loss:
# 0.17775478959083557
# Attempted to log scalar metric loss:
# 0.18598389625549316
# Attempted to log scalar metric loss:
# 0.17571374773979187
# Attempted to log scalar metric loss:
# 0.19115209579467773
# Attempted to log scalar metric loss:
# 0.18706722557544708
# Attempted to log scalar metric loss:
# 0.20993705093860626
# Attempted to log scalar metric loss:
# 0.1786150485277176
# Attempted to log scalar metric loss:
# 0.188182532787323
# Attempted to log scalar metric loss:
# 0.16672997176647186
# Attempted to log scalar metric loss:
# 0.17249521613121033
# Attempted to log scalar metric loss:
# 0.21714286506175995
# Attempted to log scalar metric loss:
# 0.13798604905605316
# Attempted to log scalar metric loss:
# 0.1770774871110916
# Attempted to log scalar metric loss:
# 0.1642841398715973
# Attempted to log scalar metric loss:
# 0.1738610416650772
# Attempted to log scalar metric loss:
# 0.1749715805053711
# Attempted to log scalar metric loss:
# 0.17959846556186676
# Attempted to log scalar metric loss:
# 0.1562797576189041
# Attempted to log scalar metric loss:
# 0.11404792964458466
# Attempted to log scalar metric loss:
# 0.190233051776886
# Attempted to log scalar metric loss:
# 0.16777625679969788
# Attempted to log scalar metric loss:
# 0.16378600895404816
# Attempted to log scalar metric loss:
# 0.16703452169895172
# Attempted to log scalar metric loss:
# 0.16174094378948212
# Attempted to log scalar metric loss:
# 0.15160535275936127
# Attempted to log scalar metric loss:
# 0.15926149487495422
# Attempted to log scalar metric loss:
# 0.20756810903549194
# Attempted to log scalar metric loss:
# 0.19641955196857452
# Attempted to log scalar metric loss:
# 0.18227508664131165
# Attempted to log scalar metric loss:
# 0.16443705558776855
# Attempted to log scalar metric loss:
# 0.14168553054332733
# Attempted to log scalar metric loss:
# 0.17412656545639038
# Attempted to log scalar metric loss:
# 0.180338054895401
# Attempted to log scalar metric loss:
# 0.17230865359306335
# Attempted to log scalar metric loss:
# 0.131812185049057
# Attempted to log scalar metric loss:
# 0.13359609246253967
# Attempted to log scalar metric loss:
# 0.16982078552246094
# Attempted to log scalar metric loss:
# 0.13229438662528992
# Attempted to log scalar metric loss:
# 0.1412210911512375
# Attempted to log scalar metric loss:
# 0.15756909549236298
# Attempted to log scalar metric loss:
# 0.1748151183128357
# Attempted to log scalar metric loss:
# 0.17150342464447021
# Attempted to log scalar metric loss:
# 0.18730156123638153
# Attempted to log scalar metric loss:
# 0.1924683302640915
# Attempted to log scalar metric loss:
# 0.1661938726902008
# Attempted to log scalar metric loss:
# 0.14508239924907684
# Attempted to log scalar metric loss:
# 0.15403345227241516
# Attempted to log scalar metric loss:
# 0.16799353063106537
# Attempted to log scalar metric loss:
# 0.14299187064170837
# Attempted to log scalar metric loss:
# 0.17644844949245453
# Attempted to log scalar metric loss:
# 0.15340816974639893
# Attempted to log scalar metric loss:
# 0.14793696999549866
# Attempted to log scalar metric loss:
# 0.15565495193004608
# Attempted to log scalar metric loss:
# 0.12043645977973938
# Attempted to log scalar metric loss:
# 0.17669588327407837
# Attempted to log scalar metric loss:
# 0.14428485929965973
# Attempted to log scalar metric loss:
# 0.15788473188877106
# Attempted to log scalar metric loss:
# 0.1471317708492279
# Attempted to log scalar metric loss:
# 0.14755424857139587
# Attempted to log scalar metric loss:
# 0.1634928584098816
# Attempted to log scalar metric loss:
# 0.16216318309307098
# Attempted to log scalar metric loss:
# 0.1603013575077057
# Attempted to log scalar metric loss:
# 0.14634807407855988
# Attempted to log scalar metric loss:
# 0.16924957931041718
# Attempted to log scalar metric loss:
# 0.13893605768680573
# Attempted to log scalar metric loss:
# 0.17259249091148376
# Attempted to log scalar metric loss:
# 0.1490669697523117
# Attempted to log scalar metric loss:
# 0.16586054861545563
# Attempted to log scalar metric loss:
# 0.16840502619743347
# Attempted to log scalar metric loss:
# 0.15940634906291962
# Attempted to log scalar metric loss:
# 0.14624731242656708
# Attempted to log scalar metric loss:
# 0.18793410062789917
# Attempted to log scalar metric loss:
# 0.169444739818573
# Attempted to log scalar metric loss:
# 0.15023383498191833
# Attempted to log scalar metric loss:
# 0.1450463831424713
# Attempted to log scalar metric loss:
# 0.1514863818883896
# Attempted to log scalar metric loss:
# 0.16638170182704926
# Attempted to log scalar metric loss:
# 0.17544463276863098
# Attempted to log scalar metric loss:
# 0.17595183849334717
# Attempted to log scalar metric loss:
# 0.1762388050556183
# Attempted to log scalar metric loss:
# 0.14801324903964996
# Attempted to log scalar metric loss:
# 0.16752026975154877
# Attempted to log scalar metric loss:
# 0.16393063962459564
# Attempted to log scalar metric loss:
# 0.14901939034461975
# Attempted to log scalar metric loss:
# 0.15417879819869995
# Attempted to log scalar metric loss:
# 0.15560710430145264
# Attempted to log scalar metric loss:
# 0.14793464541435242
# Attempted to log scalar metric loss:
# 0.14939680695533752
# Attempted to log scalar metric loss:
# 0.13968738913536072
# Attempted to log scalar metric loss:
# 0.1775808483362198
# Attempted to log scalar metric loss:
# 0.14843371510505676
# Attempted to log scalar metric loss:
# 0.15234626829624176
# Attempted to log scalar metric loss:
# 0.15091948211193085
# Attempted to log scalar metric loss:
# 0.15800867974758148

# %% [raw]
# import pdb
# pdb.pm()
