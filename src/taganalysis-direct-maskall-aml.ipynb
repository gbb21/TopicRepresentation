# %%
import ast
import os
import glob
import itertools as it
import copy
import collections as cc
import pandas as pd
import spacy as sp
import torch as tc
import torch.nn
import torch.cuda
import torch.linalg as tcl
import torch.utils.data as tcd
import logging
import numpy as np
import numpy.random as npr
import argparse

import transformers as transf
import azureml.core as aml

from transformers import BertModel, BertConfig, BertForMaskedLM, BertTokenizer, AdamW
from azureml.core import Run
from enum import Flag

# %%
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)
logging.basicConfig(filename = "./log/logTagAnalysis.txt", format = '%(asctime)s - %(levelname)s - %(name)s -   %(message)s',
                    datefmt = '%m/%d/%Y %H:%M:%S',
                    level = logging.INFO)

__amlrun = Run.get_context()

# %%
class DebugOption(Flag):
    Empty = 0
    General = 1
    ScoreAgg = 2
    Eval = 4

class TrainingConfig:
    def initDevice(self, _useGPU = False):
        logger_ = logging.getLogger(TrainingConfig.__name__)        
        if _useGPU and self.debug == DebugOption.Empty:
            logger_.info("Use GPU Enabled")
            if tc.cuda.is_available():
                self.device = tc.device("cuda")
                logger_.info("GPU initialized")
                return
            else:
                logger_.info("GPU fail to initialize")
        else:
            logger_.info("Use GPU Disabled (or in debugging)")
        logger_.info("Use CPU by default")
        self.device = tc.device("cpu")

    def __init__(self):
        self.learningRate = 0.00003
        self.weightDecay = 0.01
        self.maxSentenceLength = 256
        self.device = tc.device("cpu")
        self.evalEpochs = 1
        self.evalEpochSize = 2500
        self.epochSize = 2500
        self.batchSize = 32
        self.batchAccumulation = 2
        self.epochs = 1
        self.warmUp = 0.2
        self.removeAggBias = 1
        self.maskRate = 0.25
        self.debug = DebugOption.Empty
        self.dataInputPath = "./data/rclean/"
        self.dataModelPath = "./models/"
        
    
    def __str__(self):
        return str(vars(self))

# %%
# Global config
__config = TrainingConfig()

# %% [markdown]
# ## Global States

# %%
# Global models
__model = BertForMaskedLM.from_pretrained('bert-base-uncased').to(__config.device)
__tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
__tokenizer.convert_tokens_to_ids("[CLS]")
# Out:
# 101

# %%
def printToken(_id):
    if isinstance(_id, str):
        _id = __tokenizer.convert_tokens_to_ids(_id)
    print(_id, tc.norm(__model.cls.predictions.decoder.weight[_id]), __model.cls.predictions.decoder.bias[_id])

printToken("[CLS]")
printToken("[MASK]")
printToken("[SEP]")
# Out:
# 101 tensor(2.0308, grad_fn=<CopyBackwards>) tensor(-3.5362, grad_fn=<SelectBackward>)
# 103 tensor(1.5410, grad_fn=<CopyBackwards>) tensor(-4.1730, grad_fn=<SelectBackward>)
# 102 tensor(0.7657, grad_fn=<CopyBackwards>) tensor(-4.5105, grad_fn=<SelectBackward>)

# %%
# Global states
__curEpoch = 0
__extraTokens = dict()

# %%
def saveCheckpoint(_name):
    state_ = {"epoch": __curEpoch, "model" : __model.state_dict(), "extratokens" : __extraTokens}

    tc.save(state_, os.path.join(__config.dataModelPath, _name + ".chk"))
    
def loadCheckpoint(_name):
    global __curEpoch
    global __extraTokens

    state_ = tc.load(os.path.join(__config.dataModelPath, _name + ".chk"), map_location = __config.device)
    __model.load_state_dict(state_["model"])
    __curEpoch = state_["epoch"]
    __extraTokens = state_["extratokens"]
    for token_ in __extraTokens.values():
        token_.to(__config.device)

# %% [markdown]
# ## Data Prep

# %%
def toList(_str):
    try:
        return ast.literal_eval(_str.replace('-', ' '))
    except Exception:
        if "nan" in _str:
            return toList(_str.replace("nan", "''"))
        else:
            return []

# %%
def subTokens(_target, _candidates):
    res_ = [0] * len(_target)
    for k, c in enumerate(_candidates):
        for i, t in enumerate(_target):
            if i + len(c) > len(_target):
                break
            if res_[i] or t != c[0]:
                continue
            for j, w in enumerate(c):
                if w != _target[i + j] or res_[i + j]:
                    break
            else:
                for j in range(i, i + len(c)):
                    res_[j] = k + 1
    return res_
print(subTokens(['abcd', 'def', 'zzz', 'zzz'], [['abc', 'def'], ['def', 'zzz'], ['zzz'], ['xyz']]))
print(subTokens(['that', 'is', 'the', 'right'], [['is', 'the'], ['thats', 'is'], ['is'], ['the', 'right']]))
# Out:
# [0, 2, 2, 3]
# [0, 1, 1, 0]

# %%
def generateBias(_vec: tc.tensor):
    with tc.no_grad():
        w = tc.norm(_vec).item()
        b = tc.tensor(-3.0)
        return _vec * 2.0 / w, b

# %%
def resetEpoch(_vers = 0, _push = True):
    logger_ = logging.getLogger(resetEpoch.__name__)
    
    global __curEpoch
    __curEpoch = _vers    
    
    logger_.info("Before push extra token count: " + str(len(__extraTokens.values())))
    for sc_ in list(__extraTokens.values()):
        sc_.version = _vers
        if _push:
            if sc_.push(__model.cls.predictions.decoder) == 0:
                __extraTokens[sc_.name].isEval = False
    
    logger_.info("Post push extra token count: " + str(len(__extraTokens.values())))

def syncBatchTokens():
    for sc_ in list(__extraTokens.values()):
        if sc_.isEval:
            sc_.update(__model.cls.predictions.decoder)

# %%
class Scores:
    def __init__(self, _words, _embedding, _isEval):        
        self.isEval = _isEval
        self.assign(0, -1)
        self.num = 0
        self.name = _words
        self.tensor = tc.zeros_like(_embedding)
        self.tensor2 = tc.zeros_like(_embedding)
        self.bias = tc.tensor(0.0)
        self.bias2 = tc.tensor(0.0)
    
    def assign(self, _slot, _vers):
        assert(self.isEval)        
        self.id = _slot
        self.version = _vers
    
    def append(self, _tensor : tc.Tensor, _bias : tc.Tensor = tc.tensor(0.0)):
        assert tc.is_nonzero(_tensor[0])
        with tc.no_grad():
            self.tensor2 += _tensor.detach()
            self.bias2 += _bias.detach()
        
        self.num += 1
    
    def get(self):
        return self.tensor, self.bias
    
    def valid(self):  
        return self.isEval and tc.is_nonzero(self.tensor[0])
    
    def update(self, _decoder):
        with tc.no_grad():
            assert tc.is_nonzero(_decoder.weight[self.id][0])
            self.tensor.copy_(_decoder.weight[self.id].detach())
            self.bias.copy_(_decoder.bias[self.id].detach())

    def getId(self, _version):
        return self.id
    
    def push(self, _decoder = None):
        with tc.no_grad():
            self.tensor.copy_(self.tensor2 / self.num if self.num else self.tensor2)
            self.bias.copy_(self.bias2 / self.num if self.num else self.bias2)            
            self.tensor2.zero_()
            self.bias2.zero_()
            
            if self.num > 0 and _decoder:
                _decoder.weight[self.id].copy_(self.tensor.detach())
                _decoder.bias[self.id].copy_(self.bias.detach())
                _decoder.weight[self.id].requires_grad_(True)
                _decoder.bias[self.id].requires_grad_(True)

        r = self.num
        self.num = 0
        return r
    
    def to(self, _device):
        if self.tensor is not None:
            self.tensor.to(_device)
        if self.tensor2 is not None:
            self.tensor2.to(_device)
        if self.bias is not None:
            self.bias.to(_device)
        if self.bias2 is not None:
            self.bias2.to(_device)

# %%
def extractUnusedIds(_vocab, _range = 1000):
    for i in range(_range):
        t = "[unused{0}]".format(i)
        if t in _vocab:
            yield _vocab[t]

def createTokenName(_words):
    return '+'.join(_words) + '&'

def allocScore(_embedding, _slots, _words, _vers, _isEval = False):
    if _words not in __extraTokens:
        __extraTokens[_words] = Scores(_words, _embedding.weight[0], _isEval)
        assert not __extraTokens[_words].id
    
    sc_ = __extraTokens[_words]
    
    id_ = sc_.getId(_vers)
    
    if not id_:
        assert len(_slots) > 1
        id_ = sc_.assign(_slots.pop(), _vers)
    
    __tokenizer.vocab[_words] = id_
    __tokenizer.ids_to_tokens[id_] = _words
    
    return sc_

# %% [markdown]
# ### Sequence Generation

# %%
def generateTokenizedSequence(_texts, _candidates, _slots, _vers, _isEval = False):
    logger_ = logging.getLogger(generateTokenizedSequence.__name__)
    _candidates = [__tokenizer.tokenize(t) for t in _candidates if t]
    _candidates = [c for c in _candidates if allocScore(__model.bert.embeddings.word_embeddings, _slots, createTokenName(c), _vers, _isEval)]
    
    def generateMaskCopy(_tokens, _kpes, _maskToken):        
        ids_ = [i for i in range(1, len(_tokens) - 1) if _tokens[i] != "[SEP]"]
        npr.shuffle(ids_)
        mask_ = copy.copy(_tokens)
        for i in it.islice(ids_, max(1, int(len(ids_) * __config.maskRate))):
            mask_[i] = _maskToken
        return mask_
    
    def expandSentence(_tokens, _kpes, _candidates):
        i = 0
        tokensExpands_ = list()
        kpesExpands_ = list()

        while i < len(_tokens):
            if not _kpes[i]:
                tokensExpands_.append(_tokens[i])
                kpesExpands_.append(0)
                i += 1
                continue

            j = i + 1            
            while j < len(_tokens) and _kpes[j] == _kpes[i]:
                j += 1
            
            if len(tokensExpands_) + len(_tokens) - i + 4 < __config.maxSentenceLength:
                c = _kpes[i]
                
                for z in range(i, j):
                    tokensExpands_.append(_tokens[z])
                    kpesExpands_.append(0)
                
                tokensExpands_.append('(')
                tokensExpands_.append("aka")                
                name_ = createTokenName(_candidates[c - 1])
                if _isEval:
                    tokensExpands_.append('[MASK]')
                else:
                    assert __extraTokens[name_].valid()
                    tokensExpands_.append(name_)
                tokensExpands_.append(')')
                
                kpesExpands_.append(-1)
                kpesExpands_.append(-1)
                kpesExpands_.append(__extraTokens[name_].getId(_vers))                               
                kpesExpands_.append(-1)
                i = j
            else:
                tokensExpands_.extend(_tokens[i:])
                kpesExpands_.extend(it.repeat(0, len(_tokens) - i))
                break
        assert len(tokensExpands_) == len(kpesExpands_)
        return tokensExpands_, kpesExpands_
        
    tokens_ = ["[CLS]"]
    for text_ in _texts.split("\r\n"):
        curTokens_ = __tokenizer.tokenize(text_)
        if len(tokens_) + len(curTokens_) > __config.maxSentenceLength - 20:
            break
        tokens_ += curTokens_ + ["[SEP]"]

    kpes_ = subTokens(tokens_, _candidates)
    
    tokens_, kpes_ = expandSentence(tokens_, kpes_, _candidates)
    
    if _isEval:
        return tokens_, tokens_, kpes_
    else:
        return tokens_, generateMaskCopy(tokens_, kpes_, "[MASK]"), kpes_
    
def generateTrainingData(_data, _slots, _isEval = False):
    logger_ = logging.getLogger(generateTokenizedSequence.__name__)    
    
    slots_ = _slots
    def generateRow(_text, _tags):
        tks_, msks_, kpes_ = generateTokenizedSequence(_text, _tags, slots_, __curEpoch, _isEval)
        tks_ = __tokenizer.convert_tokens_to_ids(tks_)        
        msks_ = __tokenizer.convert_tokens_to_ids(msks_)

        sentLen_ = len(tks_)
        activeMask_ = list(map(lambda x : int(x < sentLen_), range(__config.maxSentenceLength)))
        tks_.extend(it.repeat(0, __config.maxSentenceLength - sentLen_))
        msks_.extend(it.repeat(0, __config.maxSentenceLength - sentLen_))
        kpes_.extend(it.repeat(0, __config.maxSentenceLength - sentLen_))
        return pd.Series([tks_, msks_, activeMask_, kpes_], index = ["tokens", "tokenmasks", "masks", "kpes"])
    
    logger_.info("input raw training data %d", _data.shape[0])
    _data = _data.dropna()
    logger_.info("filtering na training data %d", _data.shape[0])
    
    logger_.info("generating features for questions")
    pd1_ = _data.apply(lambda _row: generateRow(_row.CleanBody, _row.Tag), axis = 1)
    logger_.info("generating features for answers")
    pd2_ = _data.apply(lambda _row: generateRow(_row.AnswerBody, _row.Tag), axis = 1)
    logger_.info("completed generating features")
    
    return pd.concat([pd1_, pd2_])


def convertToTensor(_data):
    #tmasks_ = [list(map(lambda x : 1 if x != 0 else 0, kpe_)) for kpe_ in _data.kpes]
    masks_ = tc.tensor(_data.masks.array, dtype = tc.long, device = __config.device)
    #tmasks_ = tc.tensor(tmasks_, dtype = tc.long, device = __config.device)
    tmasks_ = tc.zeros_like(masks_, dtype = tc.long, device = __config.device)
    return tcd.TensorDataset(
        tc.tensor(_data.tokenmasks.array, dtype = tc.long, device = __config.device),
        tmasks_,
        masks_,
        tc.tensor(_data.tokens.array, dtype = tc.long, device = __config.device))

# %% [raw]
# # test mask generation
# __extraTokens.clear()
# print(generateTokenizedSequence("this is the test topic", ["the test", "test topic"], [1, 2, 3, 4], 1))
# print(generateTokenizedSequence("this is the test topic\r\nthe q&a time is here", ["q&a", "test topic"], [1, 2, 3, 4], 1))
# print(generateTokenizedSequence("this is the test topic\r\nthe q&a time is here", ["q&a", "test topic"], [1, 2, 3, 4], 1, True))
#
#
# df_ = pd.DataFrame({"CleanBody": ["this is the test topic\r\nthe q&a time is here"], "AnswerBody": ["My answer for Test Topic is here."], "Tag" : [["q&a", "test topic"]]})
# test_ = generateTrainingData(df_)
# print(test_)

# %% [markdown]
# ## Training

# %%
def createOptimizer(_lrFact = 1):
    FilterNodecay_ = lambda x : any(map(lambda t : t in x, ["bias", "LayerNorm.weight"]))
    parameters_ = list(__model.named_parameters())
    parameters_ = [
        {"params": [p for n, p in parameters_ if not FilterNodecay_(n)], 'weight_decay': __config.weightDecay},
        {"params": [p for n, p in parameters_ if FilterNodecay_(n)], 'weight_decay': 0.0}
    ]
    return AdamW(parameters_, lr = __config.learningRate * _lrFact, correct_bias=False)  # To reproduce BertAdam specific behavior set correct_bias=False

# %% [raw]
# def predCost(_predictions, _labels, _tmasks):
#     loss_ = predCost._lossFunc(_predictions.view(-1, __model.config.vocab_size), _labels.view(-1))
#     # only aggregate token type 0
#     with tc.no_grad():
#         mask_ = (tc.tensor(1) - _tmasks).view(-1)
#     return tc.dot(loss_, mask_.float()) / tc.sum(mask_).detach()
#
# predCost._lossFunc = tc.nn.CrossEntropyLoss(reduction = "none")

# %%
def trainBert(_dataFrame, _optimizer):
    logger_ = logging.getLogger(trainBert.__name__)
    __model.train()
    
    logger_.info("training data frame size %d", _dataFrame.shape[0])
    
    _trainingDataset = convertToTensor(_dataFrame)
    
    trainingSteps_ = len(_trainingDataset) // (__config.batchSize * __config.batchAccumulation)
    
    logger_.info("begin {0} epoch training, with {1} steps on device {2} ...".format(__curEpoch, trainingSteps_, __config.device))
    
    dataReader_ = tcd.DataLoader(_trainingDataset, shuffle = True, batch_size = __config.batchSize, drop_last = True)
    _optimizer.zero_grad()
    for step_, batch_ in enumerate(dataReader_):
        output_ = __model(input_ids = batch_[0], attention_mask = batch_[2], token_type_ids = batch_[1], labels = batch_[3])
        #loss_ = predCost(output_[0], batch_[3], batch_[1]) / __config.batchAccumulation
        loss_ = output_[0] / __config.batchAccumulation

        loss_.backward()
        
        if not ((step_ + 1) % __config.batchAccumulation):
            # tc.nn.utils.clip_grad_norm_(__model.parameters(), 1.0)
            _optimizer.step()
            _optimizer.zero_grad()            
            __amlrun.log('loss', loss_)
            logger_.info("step {0}/{1} finished, loss : {2}".format((step_ + 1) // __config.batchAccumulation, trainingSteps_, loss_))
    
    logger_.info("end {0} epoch training".format(__curEpoch))

# %%
def printTokens(_tokens):
    print(_tokens)
    print(__tokenizer.convert_ids_to_tokens(_tokens.numpy()))

def printEmbedding(_token):
    print(__model.bert.embeddings.word_embeddings.weight[_token])
    print(__model.bert.embeddings.word_embeddings.weight.grad[_token])

# %%
def getEmbeddings2(_tokens, _tokenTypes, _masks, _labels = None):
    logger_ = logging.getLogger(getEmbeddings.__name__)
    
    with tc.no_grad():
        outputs_ = __model.bert(
            _tokens,
            attention_mask=_masks,
            token_type_ids=_tokenTypes)
        output_ = __model.cls.predictions.transform(outputs_[0])

        indexes_ = __model.cls.predictions.decoder(output_)
        index_ = tc.argmax(indexes_, dim = 2)
        return output_, index_

def getEmbeddings(_tokens, _tokenTypes, _masks, _labels = None):
    logger_ = logging.getLogger(getEmbeddings.__name__)
    
    with tc.no_grad():
        output_ = __model(input_ids = _tokens, token_type_ids = _tokenTypes, attention_mask = _masks)
        normalizer_ = tc.nn.Softmax(2)
        output_ = normalizer_(output_[0])
        output_[:, :, : 1000].zero_()
        
        index_ = tc.argmax(output_, dim = 2)
        
        if __config.removeAggBias:
            bias_ = tc.norm(__model.bert.embeddings.word_embeddings.weight, p = 2, dim = 1, keepdim = True) + 1e-12
            bases_ = tc.div(__model.bert.embeddings.word_embeddings.weight, bias_)
            bias_ = tc.mean(bias_)
            output_ = tc.matmul(output_, bases_) # * bias_
        else:
            
            output_ = tc.matmul(output_, __model.bert.embeddings.word_embeddings.weight)
            
        return output_, index_

def evaluateModel(_dataFrame):
    logger_ = logging.getLogger(evaluateModel.__name__)

    __model.eval()
    evaluationSet_ = convertToTensor(_dataFrame)
    evalSteps_ = len(evaluationSet_) // __config.batchSize

    dataReader_ = tcd.DataLoader(evaluationSet_, shuffle = False, batch_size = __config.batchSize, drop_last = False)
    
    debug_ = 0
    for step_, batch_ in enumerate(dataReader_):
        logger_.info("get gradient for steps %d/%d", step_, evalSteps_)
        embeddings_, ptk_ = getEmbeddings2(*batch_)
        batchSize_ = embeddings_.shape[0]
        debug_ += batchSize_
        for i in range(batchSize_):
            recorder_ = _dataFrame.iloc[step_ * __config.batchSize + i]
            if not any(recorder_.kpes):
                continue
            assert len(recorder_.kpes) == len(embeddings_[i])
            for k, e, t in zip(recorder_.kpes, embeddings_[i], ptk_[i]):
                if k > 0:
                    __extraTokens[__tokenizer.convert_ids_to_tokens(k)].append(*generateBias(e))
    assert debug_ == len(_dataFrame)
    logger_.info("grandients update completed")

# %% [raw]
# # least square, but it's not needed
# print(__model.bert.embeddings.word_embeddings.weight.shape)
# print(__model.cls.predictions.decoder.weight.shape)
# x = tc.lstsq(__model.bert.embeddings.word_embeddings.weight, __model.cls.predictions.decoder.weight)
# print(x.solution.shape)

# %% [markdown]
# ## Evaluate and Update

# %%
def readDataFrame(_readChunkSize, _readCounts, _skipFiles = 0):
    counter_ = 0
    for file_ in glob.glob(os.path.join(__config.dataInputPath, "*.csv")):
        if _skipFiles > 0:
            _skipFiles -= 1
            continue

        data_ = pd.read_csv(file_)
        data_.Tag = data_["Tag"].map(toList)
        for i in range(0, data_.shape[0], _readChunkSize):
            counter_ += 1
            if counter_ > _readCounts:
                return
            yield data_.iloc[i : i + _readChunkSize]

# %% [raw]
# def train1(_startPoint = 0):
#     logger_ = logging.getLogger(train1.__name__)
#
#     global __curEpoch
#
#     logger_.info("Begin training process")
#     resetEpoch(0, False)
#     #scheduler_ = createScheduler([__config.epochSize * 2 * __config.epochs])
#     for dataFrame_ in readDataFrame(__config.epochSize, __config.epochs, _startPoint):
#         __curEpoch += 1
#         optimizer_ = createOptimizer()
#         dataFrame_ = generateTrainingData(dataFrame_)
#         trainBert(dataFrame_, optimizer_)
#         syncBatchTokens()

# %%
def eval1(_startPoint = 0):
    logger_ = logging.getLogger(eval1.__name__)
    global __curEpoch
 
    logger_.info("Begin aggregation process")
    __extraTokens.clear()
    slots_ = list(extractUnusedIds(__tokenizer.vocab, 1000))

    resetEpoch(0, False)
    for dataFrame_ in readDataFrame(__config.evalEpochSize, __config.evalEpochs, _startPoint):        
        __curEpoch += 1
        dataFrame_ = generateTrainingData(dataFrame_, slots_, True)
        evaluateModel(dataFrame_)    
    
    resetEpoch()

# %%
def trainAll(_startPoint = 0):
    logger_ = logging.getLogger(trainAll.__name__)
    
    global __curEpoch
 
    logger_.info("Begin aggregation process")
    slots_ = list(extractUnusedIds(__tokenizer.vocab, 1000))

    resetEpoch(0, False)
    for dataFrame_ in readDataFrame(__config.evalEpochSize, __config.evalEpochs, _startPoint):        
        __curEpoch += 1
        dataFrame_ = generateTrainingData(dataFrame_, slots_, True)
        evaluateModel(dataFrame_)    

    logger_.info("Begin training process")
    
    resetEpoch()
    testTopics()
    testTopics3()
    optimizer_ = createOptimizer()
    backups_ = backupTopics()
    for dataFrame_ in readDataFrame(__config.epochSize, __config.epochs, _startPoint):
        __curEpoch += 1
        dataFrame_ = generateTrainingData(dataFrame_, slots_)
        trainBert(dataFrame_, optimizer_)
    
    syncBatchTokens()
    testTopics()
    testTopics3()    
    logger_.info("training completed aggregation process")

# %%
def backupTopics():
    backup_ = dict()
    for t, v in __extraTokens.items():
        backup_[t] = v.tensor.detach().clone()
    return backup_

# %% [markdown]
# ## Evaluation

# %%
def extractWordEmbeddings():
    tensors_ = list()
    for name_ in topKTopic._names:
        if name_ == "c++++&":
            tokens_ = ['c', '+', '+']
        else:
            tokens_ = name_.strip('&').split('+')
        tokens_ = __tokenizer.convert_tokens_to_ids(tokens_)
        embeddings_ = list(map(lambda x : __model.bert.embeddings.word_embeddings.weight[x], tokens_))
        embedding_ = sum(embeddings_) / len(embeddings_)
        
        tensors_.append(embedding_)
    
    tensors_ = tc.stack(tensors_, dim = 0)    
    tensors_ = tensors_ / (tc.norm(tensors_, p = 2, dim = 1, keepdim = True) + 1e-12)
    
    return tensors_

# %%
tc.norm(tc.sub(tc.tensor([[1, 2], [3, 4]], dtype = tc.float), tc.tensor([2, 3], dtype = tc.float)), dim = 1)
# Out:
# tensor([1.4142, 1.4142])

# %%
def extractTokens():
    goodTokens_ = list(filter(lambda x : x.isEval, __extraTokens.values()))
    names_ = list(map(lambda x : x.name, goodTokens_))
    tensors_ = tc.stack(list(map(lambda x : x.tensor.detach(), goodTokens_)), dim = 0)
    tensors_ = tensors_ / (tc.norm(tensors_, p = 2, dim = 1, keepdim = True) + 1e-12)
    return names_, tensors_

def extractTokens2():
    goodTokens_ = list(filter(lambda x : x.isEval, __extraTokens.values()))
    names_ = list(map(lambda x : x.name, goodTokens_))
    tensors_ = tc.stack(list(map(lambda x : x.tensor.detach(), goodTokens_)), dim = 0)
    #tensors_ = tensors_ / (tc.norm(tensors_, p = 2, dim = 1, keepdim = True) + 1e-12)
    return names_, tensors_

def topKTopic2(t, _top = 5):
    if isinstance(t, str):
        t = __extraTokens[t].tensor
    
    distances_ = tc.norm(tc.sub(topKTopic2._tensors, t), dim = 1)
    _, ids_ = tc.topk(distances_, _top, dim = 0, largest = False)
    
    return list(map(lambda x : topKTopic2._names[x], ids_))

def topKTopic(t, _top = 5):    
    if isinstance(t, str):
        t = __extraTokens[t].tensor
    _, ids_ = tc.topk(tc.matmul(topKTopic._tensors, t), _top, dim = 0)
    
    return list(map(lambda x : topKTopic._names[x], ids_))

def distance(_left, _right):
    print(tc.dot(__extraTokens[_left].tensor, __extraTokens[_right].tensor))

# topKTopic("flex&")

# %%
def testTopic(_topic):
    print("Topic '{0}' related to {1}".format(_topic, str(topKTopic(__extraTokens[_topic].tensor))))

def testTopic2(_topic):
    print("Topic '{0}' related to {1}".format(_topic, str(topKTopic2(__extraTokens[_topic].tensor))))

def testTopics2():
    topKTopic._names, topKTopic._tensors = extractTokens()
    topKTopic._tensors = extractWordEmbeddings()

    for i, name_ in enumerate(topKTopic._names):
        if len(tc.nonzero(topKTopic._tensors[i])):
            print("Topic '{0}' related to {1}".format(name_, str(topKTopic(topKTopic._tensors[i]))))
    
def testTopics():
    topKTopic._names, topKTopic._tensors = extractTokens()
    for i, name_ in enumerate(topKTopic._names):
        assert(tc.is_nonzero(topKTopic._tensors[i, 0]))
        testTopic(name_)
    print("-------------------------")
        
def testTopics3():
    topKTopic2._names, topKTopic2._tensors = extractTokens2()
    for i, name_ in enumerate(topKTopic2._names):
        assert(tc.is_nonzero(topKTopic2._tensors[i, 0]))
        testTopic2(name_)
    print("-------------------------")

# %% [markdown]
# ## Main

# %%
def main(_inputDataPath = None, _outputModelPath = None, _Epochs = 4, _useGPU = False, _debug = DebugOption.Empty):
    logger_ = logging.getLogger(main.__name__)
    __config.initDevice(_useGPU)

    __config.debug = _debug
    
    if _Epochs > 0:
        __config.epochs = _Epochs
        __config.evalEpochs = _Epochs    
    
    if _inputDataPath:
        __config.dataInputPath = _inputDataPath
    if _outputModelPath:
        __config.dataModelPath = _outputModelPath
    
    logger_.info("Configs: " + str(__config))
    
    __extraTokens.clear()
    trainAll()
    saveCheckpoint("base1")
    
    logger_.info("Training completed, begin eval...")    
    eval1()
    testTopics()
    logger_.info("Completed")

# %% [raw]
# if __name__ == "__main__":
#     parser_ = argparse.ArgumentParser(description = "Train and eval topic embedding over LM")
#     parser_.add_argument("InputDataPath", type=str, help = "The input directory path")
#     parser_.add_argument("OutputModelPath", type=str, help = "The model directory path")
#     parser_.add_argument("Epochs", type=int, help = "The epoch size")
#     parser_.add_argument("UseGPU", nargs = '?', type=int, default = 1, help = "use GPU")
#     args_ = parser_.parse_args()
#
#     main(args_.InputDataPath, args_.OutputModelPath, args_.Epochs, args_.UseGPU)

# %%
testTopics()
# Out:
# Topic 'sv+##n&' related to ['sv+##n&', 'd+##ns&', 'j+##son&', 'cm+##d&', 'ss+##l&']
# Topic 'sql&' related to ['sql&', 'lin+##q+to+sql&', 'sql+##ite&', 'database&', 'sql+server&']
# Topic 'as+##p+.+net&' related to ['as+##p+.+net&', '.+net&', 'v+##b+.+net&', 'web&', 'net+##be+##ans&']
# Topic 'algorithm&' related to ['algorithm&', 'encoding&', 'if+##ram+##e&', 'reference&', 'routing&']
# Topic 'colors&' related to ['colors&', 'types&', 'pointer+##s&', 'font+##s&', 'plug+##ins&']
# Topic 'c+#&' related to ['c+#&', 'f+#&', 'c&', 'c++++&', 'c+#+4+.+0&']
# Topic '.+net&' related to ['.+net&', 'as+##p+.+net&', 'v+##b+.+net&', 'web&', 'net+##be+##ans&']
# Topic 'c++++&' related to ['c++++&', 'visual+c++++&', 'c&', 'c+#&', 'objective+c&']
# Topic 'class&' related to ['class&', '.+h+##ta+##cc+##ess&', 'se+##d&', 'if+##ram+##e&', 'cm+##d&']
# Topic 'web+services&' related to ['web+services&', 'reporting+services&', 'service&', 'web+applications&', 'generic+##s&']
# Topic 'sql+server&' related to ['sql+server&', 'database&', 'sql&', 'lin+##q+to+sql&', 'rs+##pe+##c&']
# Topic 'sql+server+2005&' related to ['sql+server+2005&', 'sd+##k&', 'actions+##cript+3&', 'ss+##h&', 'v+##bs+##cript&']
# Topic 'deployment&' related to ['deployment&', 'build&', 'up+##load&', 'file+up+##load&', 'serial+##ization&']
# Topic 'visual+studio&' related to ['visual+studio&', 'visual+c++++&', 'rs+##pe+##c&', 'powers+##hell&', 'cm+##d&']
# Topic 'windows&' related to ['windows&', 'win+##ap+##i&', 'azure&', 'os+##x&', 'ui+##we+##b+##view&']
# Topic 'database&' related to ['database&', 'lin+##q+to+sql&', 'sql&', 'sql+##ite&', 'sql+server&']
# Topic 'd+##ns&' related to ['d+##ns&', 'ss+##is&', 'net+##be+##ans&', 'sv+##n&', 'ii+##s&']
# Topic 'unit+testing&' related to ['unit+testing&', 'testing&', 'de+##bu+##gging&', 'validation&', 'par+##sing&']
# Topic 'testing&' related to ['testing&', 'unit+testing&', 'validation&', 'par+##sing&', 'de+##bu+##gging&']
# Topic 'post+##gre+##s+##q+##l&' related to ['post+##gre+##s+##q+##l&', 'my+##s+##q+##l&', 'ts+##q+##l&', 'x+##am+##l&', 'dr+##up+##al&']
# Topic 'stored+procedures&' related to ['stored+procedures&', 'methods&', 'collections&', 'transactions&', 'template+##s&']
# Topic 'data+##table&' related to ['data+##table&', 'rs+##pe+##c&', 'data+##gr+##id&', 'if+##ram+##e&', 'ur+##l&']
# Topic 'html&' related to ['html&', 'http&', 'php&', 'if+##ram+##e&', 'java+##script&']
# Topic 'c&' related to ['c&', 'objective+c&', 'c++++&', 'visual+c++++&', 'c+#&']
# Topic 'flash&' related to ['flash&', 'hyper+##link&', 'if+##ram+##e&', 'silver+##light&', 'j+##que+##ry&']
# Topic 'video&' related to ['video&', 'hyper+##link&', 'text&', 'scroll&', 'data+##gr+##id&']
# Topic 'powers+##hell&' related to ['powers+##hell&', 'cm+##d&', '.+h+##ta+##cc+##ess&', 'file&', 'j+##que+##ry&']
# Topic 'optimization&' related to ['optimization&', 'index+##ing&', 'ca+##ching&', 'par+##sing&', 'algorithm&']
# Topic 'win+##forms&' related to ['win+##forms&', 'web+##forms&', 'forms&', 'ex+##t+##js&', 'ser+##v+##lets&']
# Topic 'php&' related to ['php&', 'html&', 'my+##s+##q+##l&', 'php+##my+##ad+##min&', 'post+##gre+##s+##q+##l&']
# Topic 'my+##s+##q+##l&' related to ['my+##s+##q+##l&', 'post+##gre+##s+##q+##l&', 'ts+##q+##l&', 'my+##s+##q+##li&', 'dr+##up+##al&']
# Topic 'ruby&' related to ['ruby&', 'ruby+on+rails&', 'data+##gr+##id&', 'my+##s+##q+##l&', 'post+##gre+##s+##q+##l&']
# Topic 'mod+re+##write&' related to ['mod+re+##write&', 'ur+##l+re+##writing&', 'replace&', 'rec+##urs+##ion&', 'de+##bu+##gging&']
# Topic 'sd+##k&' related to ['sd+##k&', 'aw+##k&', 'post+##gre+##s+##q+##l&', 'cm+##d&', 'if+##ram+##e&']
# Topic 'ui+##we+##b+##view&' related to ['ui+##we+##b+##view&', 'ui+##sc+##roll+##view&', 'ui+##view&', 'ui+##table+##view&', 'data+##gr+##id+##view&']
# Topic 'compilation&' related to ['compilation&', 'serial+##ization&', 'download&', 'up+##load&', 'pa+##gina+##tion&']
# Topic 'graph&' related to ['graph&', 'if+##ram+##e&', 'hyper+##link&', 'browser&', 'post+##gre+##s+##q+##l&']
# Topic 'mage+##nto&' related to ['mage+##nto&', 'fore+##ach&', 'java+##script&', 'log+##in&', 'j+##bos+##s&']
# Topic 'ui+##view&' related to ['ui+##view&', 'ui+##we+##b+##view&', 'ui+##table+##view&', 'ui+##sc+##roll+##view&', 'data+##gr+##id+##view&']
# Topic 'visual+studio+2010&' related to ['visual+studio+2010&', 'c+#+4+.+0&', 'visual+studio+2008&', 'sql+server+2008&', 'x+##sl+##t&']
# Topic 'cocoa+touch&' related to ['cocoa+touch&', 'word+##press&', 'make+##fi+##le&', 'st+##ru+##ct&', 'x+##sl+##t&']
# Topic 'character+encoding&' related to ['character+encoding&', 'encoding&', 'script+##ing&', 'serial+##ization&', 'x+##code&']
# Topic 'mat+##pl+##ot+##lib&' related to ['mat+##pl+##ot+##lib&', 'nu+##mp+##y&', 'post+##gre+##s+##q+##l&', 'python&', 'my+##s+##q+##l&']
# Topic 'amazon+ec+##2&' related to ['amazon+ec+##2&', 'st+##rut+##s+##2&', 'as+##p+.+net+mv+##c&', 'amazon+s+##3&', 'rs+##pe+##c&']
# Topic 'ui+##sc+##roll+##view&' related to ['ui+##sc+##roll+##view&', 'ui+##table+##view&', 'ui+##we+##b+##view&', 'ui+##view&', 'data+##gr+##id+##view&']
# Topic 'core+data&' related to ['core+data&', 'memory&', 'data+##gr+##id&', 'database&', 'data+##table&']
# Topic 'ui+##view+##con+##tro+##ller&' related to ['ui+##view+##con+##tro+##ller&', 'ui+##we+##b+##view&', 'ui+##sc+##roll+##view&', 'ui+##view&', 'ui+##table+##view&']
# Topic 'blue+##tooth&' related to ['blue+##tooth&', 'networking&', 'ajax&', 'dj+##ango&', 'mobile&']
# Topic 'map+##red+##uce&' related to ['map+##red+##uce&', 'if+##ram+##e&', 'hyper+##link&', 'cl+##oj+##ure&', 'ur+##l&']
# Topic 'sol+##r&' related to ['sol+##r&', 'ss+##l&', 'st+##l&', 'x+##am+##l&', 'dr+##up+##al&']
# -------------------------

# %%
testTopics()
# Out:
# Topic 'sv+##n&' related to ['sv+##n&', 'gi+##t&', 'ft+##p&', 'wc+##f&', 'cm+##d&']
# Topic 'sql&' related to ['sql&', 'lin+##q+to+sql&', 'ts+##q+##l&', 'sql+##ite&', 'my+##s+##q+##l&']
# Topic 'as+##p+.+net&' related to ['as+##p+.+net&', '.+net&', 'share+##point&', 'as+##p+.+net+mv+##c&', 'j+##bos+##s&']
# Topic 'algorithm&' related to ['algorithm&', 'rec+##urs+##ion&', 'or+##m&', 'optimization&', 'graph&']
# Topic 'colors&' related to ['colors&', 'background&', 'canvas&', 'image&', 'plot&']
# Topic 'c+#&' related to ['c+#&', 'c++++&', 'c&', 'f+#&', 'per+##l&']
# Topic '.+net&' related to ['.+net&', 'as+##p+.+net&', 'v+##b+.+net&', 'net+##be+##ans&', 'as+##p+.+net+mv+##c&']
# Topic 'c++++&' related to ['c++++&', 'c+#&', 'c&', 'st+##l&', 'objective+c&']
# Topic 'class&' related to ['class&', 'object&', 'construct+##or&', 'module&', 'function&']
# Topic 'web+services&' related to ['web+services&', 'reporting+services&', 'web+applications&', 'service&', 'ss+##is&']
# Topic 'sql+server&' related to ['sql+server&', 'ss+##is&', 'oracle&', 'as+##p+.+net&', 'share+##point&']
# Topic 'sql+server+2005&' related to ['sql+server+2005&', 'sql+server+2008&', 'sql+server&', 'visual+studio+2008&', 'j+##bos+##s&']
# Topic 'deployment&' related to ['deployment&', 'configuration&', 'build&', 'service&', 'testing&']
# Topic 'visual+studio&' related to ['visual+studio&', 'open+##gl&', '.+net&', 'silver+##light&', 'visual+c++++&']
# Topic 'windows&' related to ['windows&', 'os+##x&', 'linux&', 'unix&', 'ii+##s&']
# Topic 'database&' related to ['database&', 'jp+##a&', 'data+##table&', 'configuration&', 'or+##m&']
# Topic 'd+##ns&' related to ['d+##ns&', 'ss+##l&', 'proxy&', 'http&', 'ft+##p&']
# Topic 'unit+testing&' related to ['unit+testing&', 'testing&', 'design&', 'deployment&', 'validation&']
# Topic 'testing&' related to ['testing&', 'unit+testing&', 'deployment&', 'validation&', 'design&']
# Topic 'post+##gre+##s+##q+##l&' related to ['post+##gre+##s+##q+##l&', 'my+##s+##q+##l&', 'ts+##q+##l&', 'per+##l&', 'php&']
# Topic 'stored+procedures&' related to ['stored+procedures&', 'template+##s&', 'transactions&', 'triggers&', 'methods&']
# Topic 'data+##table&' related to ['data+##table&', 'data+##gr+##id&', 'database&', 'grid+##view&', 'object&']
# Topic 'html&' related to ['html&', 'cs+##s&', 'java+##script&', 'x+##sl+##t&', 'xml&']
# Topic 'c&' related to ['c&', 'c++++&', 'c+#&', 'st+##l&', 'objective+c&']
# Topic 'flash&' related to ['flash&', 'silver+##light&', 'w+##pf&', 'safari&', 'fire+##fo+##x&']
# Topic 'video&' related to ['video&', 'audio&', 'flash&', 'animation&', 'pdf&']
# Topic 'powers+##hell&' related to ['powers+##hell&', 'em+##ac+##s&', 'shell&', 'os+##x&', 'cm+##d&']
# Topic 'optimization&' related to ['optimization&', 'rec+##urs+##ion&', 'performance&', 'algorithm&', 'design&']
# Topic 'win+##forms&' related to ['win+##forms&', 'as+##p+.+net+mv+##c&', 'w+##pf&', 'j+##que+##ry&', 'v+##b+.+net&']
# Topic 'php&' related to ['php&', 'php+##my+##ad+##min&', 'my+##s+##q+##l&', 'java+##script&', 'post+##gre+##s+##q+##l&']
# Topic 'command+line&' related to ['command+line&', 'dl+##l&', 'shell&', 'cm+##d&', 'auto+##com+##ple+##te&']
# Topic 'parameters&' related to ['parameters&', 'variables&', 'properties&', 'events&', 'pointer+##s&']
# Topic 'macro+##s&' related to ['macro+##s&', 'template+##s&', 'stored+procedures&', 'generic+##s&', 'plug+##ins&']
# Topic 'permission+##s&' related to ['permission+##s&', 'triggers&', 'events&', 'parameters&', 'stored+procedures&']
# Topic 'u+##bu+##nt+##u&' related to ['u+##bu+##nt+##u&', 'fire+##fo+##x&', 'os+##x&', '.+net&', 'linux&']
# Topic 'iphone&' related to ['iphone&', 'ios&', 'android&', 'mobile&', 'safari&']
# Topic 'reference&' related to ['reference&', 'function&', 'construct+##or&', 'object&', 'st+##ru+##ct&']
# Topic 'v+##ba&' related to ['v+##ba&', 'x+##am+##l&', 'lu+##a&', 'dl+##l&', 'excel&']
# Topic 'cocoa&' related to ['cocoa&', 'net+##be+##ans&', 'java&', 'x+##code&', '.+net&']
# Topic 'events&' related to ['events&', 'triggers&', 'parameters&', 'variables&', 'permission+##s&']
# Topic 'time&' related to ['time&', 'date+##time&', 'date&', 'timer&', 'memory&']
# Topic 'win+##ap+##i&' related to ['win+##ap+##i&', 'm+##fc&', 'x+##code&', 'x+##am+##l&', 'command+line&']
# Topic 'routing&' related to ['routing&', 'ca+##ching&', 'pa+##gina+##tion&', 'log+##in&', '.+h+##ta+##cc+##ess&']
# Topic 'math&' related to ['math&', 'design&', 'syntax&', 'o+##op&', 'rec+##urs+##ion&']
# Topic 'path&' related to ['path&', 'dl+##l&', 'file&', 'class&', 'ur+##l&']
# Topic 'loops&' related to ['loops&', 'arrays&', 'methods&', 'pointer+##s&', 'variables&']
# Topic 'object&' related to ['object&', 'class&', 'construct+##or&', 'st+##ru+##ct&', 'reference&']
# Topic 'design+patterns&' related to ['design+patterns&', 'design&', 'data+structures&', 'stored+procedures&', 'template+##s&']
# Topic 'gi+##t&' related to ['gi+##t&', 'sv+##n&', 'cm+##d&', 'dl+##l&', 'vi+##m&']
# Topic 'pay+##pal&' related to ['pay+##pal&', 'facebook&', 'share+##point&', 'cold+##fusion&', 'youtube&']
# Topic 'scala&' related to ['scala&', 'java&', 'st+##l&', 'net+##be+##ans&', 'python&']
# Topic 'list&' related to ['list&', 'array+##list&', 'dictionary&', 'string&', 'data+##table&']
# Topic 'cake+##ph+##p&' related to ['cake+##ph+##p&', 'dr+##up+##al&', 'gr+##ail+##s&', 'j+##que+##ry&', 'as+##p+.+net+mv+##c&']
# Topic 'pd+##o&' related to ['pd+##o&', 'my+##s+##q+##l&', 'ts+##q+##l&', 'lin+##q&', 'per+##l&']
# Topic 'https&' related to ['https&', 'ss+##l&', 'http&', 'd+##ns&', 'ft+##p&']
# Topic 'variables&' related to ['variables&', 'parameters&', 'pointer+##s&', 'types&', 'methods&']
# Topic 'service&' related to ['service&', 'proxy&', 'wc+##f&', 'ft+##p&', 'ss+##is&']
# Topic 'merge&' related to ['merge&', 'build&', 'insert&', 'replace&', 'binding&']
# Topic 'st+##ru+##ct&' related to ['st+##ru+##ct&', 'object&', 'construct+##or&', 'function&', 'reference&']
# Topic 'safari&' related to ['safari&', 'google+chrome&', 'fire+##fo+##x&', 'silver+##light&', 'internet+explorer&']
# Topic 'auto+##com+##ple+##te&' related to ['auto+##com+##ple+##te&', 'x+##am+##l&', 'j+##que+##ry&', 'command+line&', 'dl+##l&']
# Topic 'list+##view&' related to ['list+##view&', 'data+##gr+##id+##view&', 'data+##gr+##id&', 'grid+##view&', 'if+##ram+##e&']
# Topic 'jp+##a&' related to ['jp+##a&', 'oracle&', 'or+##m&', 'j+##sp&', 'database&']
# Topic 'transactions&' related to ['transactions&', 'stored+procedures&', 'triggers&', 'events&', 'collections&']
# Topic 'encoding&' related to ['encoding&', 'bit+##ma+##p&', 'binary&', 'character+encoding&', 'xp+##ath&']
# Topic 'module&' related to ['module&', 'class&', 'construct+##or&', 'interface&', 'dl+##l&']
# Topic 'build&' related to ['build&', 'up+##load&', 'configuration&', 'de+##bu+##gging&', 'process&']
# Topic 'networking&' related to ['networking&', 'wc+##f&', 'tc+##p&', 'ft+##p&', 'ss+##l&']
# Topic 'post&' related to ['post&', 'red+##ire+##ct&', 'get&', 'ur+##l&', 'download&']
# Topic 'google+app+engine&' related to ['google+app+engine&', 'share+##point&', 'as+##p+.+net&', 'as+##p+.+net+mv+##c&', 'zen+##d+framework&']
# Topic 'file+up+##load&' related to ['file+up+##load&', 'up+##load&', 'ca+##ching&', 'download&', 'pa+##gina+##tion&']
# Topic 'jar&' related to ['jar&', 'dl+##l&', 'cm+##d&', 'gi+##t&', 'batch+file&']
# Topic 'facebook&' related to ['facebook&', 'twitter&', 'youtube&', 'word+##press&', 'amazon+s+##3&']
# Topic 'gr+##oo+##vy&' related to ['gr+##oo+##vy&', 'cl+##oj+##ure&', 'gr+##ail+##s&', 'j+##que+##ry&', 'vi+##m&']
# Topic 'mat+##lab&' related to ['mat+##lab&', 'python&', 'per+##l&', 'v+##b+.+net&', 'em+##ac+##s&']
# Topic 'font+##s&' related to ['font+##s&', 'cs+##s&', 'forms&', 'pdf&', 'html&']
# Topic 'unix&' related to ['unix&', 'linux&', 'os+##x&', 'windows&', 'powers+##hell&']
# Topic 'shell&' related to ['shell&', 'cm+##d&', 'powers+##hell&', 'command+line&', 'per+##l&']
# Topic 'fore+##ach&' related to ['fore+##ach&', 'function&', 'construct+##or&', 'st+##ru+##ct&', 'reg+##ex&']
# Topic 'as+##yn+##ch+##ron+##ous&' related to ['as+##yn+##ch+##ron+##ous&', 'static&', 'dynamic&', 'fore+##ach&', 'serial+##ization&']
# Topic 'tree&' related to ['tree&', 'graph&', 'list&', 'data+##table&', 'class&']
# Topic 'active+##re+##cor+##d&' related to ['active+##re+##cor+##d&', 'rs+##pe+##c&', 'nh+##ibe+##rna+##te&', 'as+##p+.+net+mv+##c&', 'or+##m&']
# Topic 'array+##list&' related to ['array+##list&', 'list&', 'arrays&', 'string&', 'st+##ru+##ct&']
# Topic 'reporting+services&' related to ['reporting+services&', 'web+services&', 'ss+##is&', 'sql+server&', 'web+applications&']
# Topic 'controller&' related to ['controller&', 'interface&', 'module&', 'process&', 'configuration&']
# Topic 'j+##son&' related to ['j+##son&', 'j+##sp&', 'xp+##ath&', 'x+##sl+##t&', 'x+##am+##l&']
# Topic 'jun+##it&' related to ['jun+##it&', 'rs+##pe+##c&', 'nh+##ibe+##rna+##te&', 'j+##sp&', 'q+##t&']
# Topic 'j+##sf&' related to ['j+##sf&', 'w+##pf&', 'j+##sp&', 'st+##rut+##s+##2&', 'j+##que+##ry&']
# Topic 'internet+explorer&' related to ['internet+explorer&', 'fire+##fo+##x&', 'as+##p+.+net&', 'sd+##k&', 'safari&']
# Topic 'batch+file&' related to ['batch+file&', 'file&', 'dl+##l&', 'command+line&', 'cm+##d&']
# Topic 'replace&' related to ['replace&', 'insert&', 'select&', 'get&', 'string&']
# Topic 'lu+##a&' related to ['lu+##a&', 'st+##l&', 'dl+##l&', 'x+##am+##l&', 'shell&']
# Topic 'en+##ums&' related to ['en+##ums&', 'arrays&', 'types&', 'variables&', 'methods&']
# Topic 'st+##l&' related to ['st+##l&', 'c++++&', 'per+##l&', 'g+##cc&', 'c&']
# Topic 'data+##gr+##id+##view&' related to ['data+##gr+##id+##view&', 'data+##gr+##id&', 'grid+##view&', 'list+##view&', 'combo+##box&']
# Topic 'data+binding&' related to ['data+binding&', 'binding&', 'serial+##ization&', 'inheritance&', 'validation&']
# Topic 'curl&' related to ['curl&', 'lin+##q&', 'st+##rut+##s+##2&', 'pd+##o&', 'vi+##m&']
# Topic 'join&' related to ['join&', 'select&', 'list&', 'hash&', 'insert&']
# Topic 'ex+##t+##js&' related to ['ex+##t+##js&', 'as+##p+.+net+mv+##c&', 'net+##be+##ans&', 'as+##p+.+net&', 'j+##que+##ry&']
# Topic 'select&' related to ['select&', 'insert&', 'replace&', 'get&', 'red+##ire+##ct&']
# Topic 'twitter&' related to ['twitter&', 'facebook&', 'word+##press&', 'dr+##up+##al&', 'email&']
# Topic 'tc+##p&' related to ['tc+##p&', 'ft+##p&', 'ss+##l&', 'd+##ns&', 'wc+##f&']
# Topic 'background&' related to ['background&', 'image&', 'hyper+##link&', 'menu&', 'canvas&']
# Topic 'charts&' related to ['charts&', 'cs+##s&', 'layout&', 'web+##forms&', 'forms&']
# Topic 'check+##box&' related to ['check+##box&', 'combo+##box&', 'data+##gr+##id&', 'reg+##ex&', 'if+##ram+##e&']
# Topic 'cu+##da&' related to ['cu+##da&', 'c&', 'st+##l&', 'c++++&', 'lu+##a&']
# Topic 'image+processing&' related to ['image+processing&', 'graphics&', '3d&', 'memory+management&', 'script+##ing&']
# Topic 'red+##ire+##ct&' related to ['red+##ire+##ct&', 'post&', 'log+##in&', 'download&', 'if+##ram+##e&']
# Topic 'scope&' related to ['scope&', 'st+##ru+##ct&', 'object&', 'function&', 'reference&']
# Topic 'dl+##l&' related to ['dl+##l&', 'x+##am+##l&', 'st+##l&', 'lu+##a&', 'j+##sp&']
# Topic 'date+##pic+##ker&' related to ['date+##pic+##ker&', 'auto+##com+##ple+##te&', 'if+##ram+##e&', '.+h+##ta+##cc+##ess&', 'j+##que+##ry&']
# Topic 'web+##forms&' related to ['web+##forms&', 'as+##p+.+net+mv+##c&', 'win+##forms&', 'w+##pf&', 'j+##que+##ry&']
# Topic 'call+##back&' related to ['call+##back&', '.+h+##ta+##cc+##ess&', 'gi+##t&', 'post&', 'auto+##com+##ple+##te&']
# Topic 'aw+##k&' related to ['aw+##k&', 'reg+##ex&', 'se+##d&', 'nu+##mp+##y&', 'x+##am+##l&']
# Topic 'youtube&' related to ['youtube&', 'facebook&', 'word+##press&', 'dr+##up+##al&', 'share+##point&']
# Topic 'mv+##v+##m&' related to ['mv+##v+##m&', 'w+##pf&', 'as+##p+.+net+mv+##c&', 'm+##fc&', 'or+##m&']
# Topic 'canvas&' related to ['canvas&', 'image&', 'view&', 'background&', 'hyper+##link&']
# Topic 'java+##f+##x&' related to ['java+##f+##x&', 'had+##oop&', 'fire+##fo+##x&', 'eclipse&', 'open+##c+##v&']
# Topic 'ur+##l+re+##writing&' related to ['ur+##l+re+##writing&', 'mod+re+##write&', 'pa+##gina+##tion&', 'routing&', '.+h+##ta+##cc+##ess&']
# Topic 'null+##point+##ere+##x+##ception&' related to ['null+##point+##ere+##x+##ception&', 'exception&', 'for+loop&', 'get&', '.+h+##ta+##cc+##ess&']
# Topic 'web&' related to ['web&', 'share+##point&', 'facebook&', 'twitter&', 'gi+##th+##ub&']
# Topic 'ser+##v+##lets&' related to ['ser+##v+##lets&', 'wc+##f&', 'ng+##in+##x&', 'as+##p+.+net+mv+##c&', 'post+##gre+##s+##q+##l&']
# Topic 'j+##que+##ry+ui&' related to ['j+##que+##ry+ui&', 'j+##que+##ry&', 'ui+##we+##b+##view&', 'ui+##view&', 'ui+##table+##view&']
# Topic 'log+##in&' related to ['log+##in&', 'session&', 'red+##ire+##ct&', 'download&', '.+h+##ta+##cc+##ess&']
# Topic 'ios&' related to ['ios&', 'iphone&', 'android&', 'mobile&', 'sd+##k&']
# Topic 'joo+##ml+##a&' related to ['joo+##ml+##a&', 'ex+##t+##js&', 'zen+##d+framework&', 'net+##be+##ans&', 'as+##p+.+net+mv+##c&']
# Topic 'while+loop&' related to ['while+loop&', 'for+loop&', 'string&', 'pointer+##s&', 'if+statement&']
# Topic 'windows+7&' related to ['windows+7&', 'windows&', 'visual+studio+2008&', 'visual+studio+2010&', 'sql+server+2005&']
# Topic 'camera&' related to ['camera&', 'flash&', 'video&', 'sd+##k&', 'browser&']
# Topic 'r&' related to ['r&', 'c&', 'st+##l&', 'f+#&', 'nu+##mp+##y&']
# Topic 'insert&' related to ['insert&', 'select&', 'replace&', 'red+##ire+##ct&', 'get&']
# Topic 'multi+##dim+##ens+##ional+array&' related to ['multi+##dim+##ens+##ional+array&', 'array+##list&', 'arrays&', 'data+##table&', 'st+##ru+##ct&']
# Topic 'spring+mv+##c&' related to ['spring+mv+##c&', 'java+##script&', 'as+##p+.+net+mv+##c&', 'as+##p+.+net&', 'ajax&']
# Topic 'cl+##oj+##ure&' related to ['cl+##oj+##ure&', 'gr+##oo+##vy&', 'nu+##mp+##y&', 'per+##l&', 'em+##ac+##s&']
# Topic 'mod+re+##write&' related to ['mod+re+##write&', 'ur+##l+re+##writing&', '.+h+##ta+##cc+##ess&', 'de+##bu+##gging&', 'make+##fi+##le&']
# Topic 'sd+##k&' related to ['sd+##k&', 'ii+##s&', 'as+##p+.+net+mv+##c&', 'share+##point&', 'as+##p+.+net&']
# Topic 'ui+##we+##b+##view&' related to ['ui+##we+##b+##view&', 'ui+##table+##view&', 'data+##gr+##id+##view&', 'ui+##sc+##roll+##view&', 'if+##ram+##e&']
# Topic 'compilation&' related to ['compilation&', 'serial+##ization&', 'binding&', 'data+binding&', 'par+##sing&']
# Topic 'graph&' related to ['graph&', 'tree&', 'data+##table&', 'grid+##view&', 'data+##gr+##id&']
# Topic 'mage+##nto&' related to ['mage+##nto&', 'pay+##pal&', 'facebook&', 'amazon+s+##3&', 'amazon+ec+##2&']
# Topic 'ui+##view&' related to ['ui+##view&', 'ui+##we+##b+##view&', 'ui+##table+##view&', 'ui+##sc+##roll+##view&', 'w+##pf&']
# Topic 'visual+studio+2010&' related to ['visual+studio+2010&', 'c+#+4+.+0&', 'visual+studio+2008&', 'visual+studio&', 'eclipse&']
# Topic 'cocoa+touch&' related to ['cocoa+touch&', 'active+##re+##cor+##d&', 'm+##fc&', 'as+##p+.+net+mv+##c&', 'cocoa&']
# Topic 'character+encoding&' related to ['character+encoding&', 'encoding&', 'x+##sl+##t&', 'cs+##s&', 'par+##sing&']
# Topic 'mat+##pl+##ot+##lib&' related to ['mat+##pl+##ot+##lib&', 'gr+##oo+##vy&', 'nu+##mp+##y&', 'python&', 'em+##ac+##s&']
# Topic 'amazon+ec+##2&' related to ['amazon+ec+##2&', 'amazon+s+##3&', 'open+##c+##v&', 'tom+##cat&', 'fire+##fo+##x&']
# Topic 'ui+##sc+##roll+##view&' related to ['ui+##sc+##roll+##view&', 'ui+##table+##view&', 'ui+##we+##b+##view&', 'grid+##view&', 'ui+##view&']
# Topic 'core+data&' related to ['core+data&', 'data+##table&', 'object&', 'reference&', 'scope&']
# Topic 'ui+##view+##con+##tro+##ller&' related to ['ui+##view+##con+##tro+##ller&', 'ui+##we+##b+##view&', 'win+##forms&', 'plug+##ins&', 'controller&']
# Topic 'blue+##tooth&' related to ['blue+##tooth&', 'tc+##p&', 'networking&', 'mobile&', 'ss+##l&']
# Topic 'map+##red+##uce&' related to ['map+##red+##uce&', 'as+##p+.+net+mv+##c&', 'cake+##ph+##p&', 'pa+##gina+##tion&', 'active+##re+##cor+##d&']
# Topic 'sol+##r&' related to ['sol+##r&', 'pd+##o&', 'reg+##ex&', 'lin+##q&', 'vi+##m&']
# -------------------------

# %%
loadCheckpoint("base1")

# %%
if __name__ == "__main__":
    main()
# Out:
# Topic 'sv+##n&' related to ['sv+##n&', 'gi+##t&', 'wc+##f&', 'ft+##p&', 'ss+##l&']
# Topic 'sql&' related to ['sql&', 'lin+##q+to+sql&', 'ts+##q+##l&', 'sql+##ite&', 'my+##s+##q+##l&']
# Topic 'as+##p+.+net&' related to ['as+##p+.+net&', '.+net&', 'as+##p+.+net+mv+##c&', 'share+##point&', 'v+##b+.+net&']
# Topic 'algorithm&' related to ['algorithm&', 'rec+##urs+##ion&', 'or+##m&', 'graph&', 'optimization&']
# Topic 'colors&' related to ['colors&', 'background&', 'canvas&', 'image&', 'tab+##s&']
# Topic 'c+#&' related to ['c+#&', 'c++++&', 'c&', 'f+#&', 'per+##l&']
# Topic '.+net&' related to ['.+net&', 'as+##p+.+net&', 'v+##b+.+net&', 'net+##be+##ans&', 'as+##p+.+net+mv+##c&']
# Topic 'c++++&' related to ['c++++&', 'c+#&', 'c&', 'st+##l&', 'objective+c&']
# Topic 'class&' related to ['class&', 'object&', 'construct+##or&', 'module&', 'function&']
# Topic 'web+services&' related to ['web+services&', 'reporting+services&', 'web+applications&', 'service&', 'ss+##is&']
# Topic 'sql+server&' related to ['sql+server&', 'ss+##is&', 'oracle&', 'as+##p+.+net&', 'share+##point&']
# Topic 'sql+server+2005&' related to ['sql+server+2005&', 'sql+server+2008&', 'sql+server&', 'visual+studio+2008&', 'j+##bos+##s&']
# Topic 'deployment&' related to ['deployment&', 'configuration&', 'build&', 'service&', 'ss+##is&']
# Topic 'visual+studio&' related to ['visual+studio&', 'open+##gl&', '.+net&', 'silver+##light&', 'v+##b+.+net&']
# Topic 'windows&' related to ['windows&', 'os+##x&', 'linux&', 'ii+##s&', 'unix&']
# Topic 'database&' related to ['database&', 'jp+##a&', 'data+##table&', 'configuration&', 'or+##m&']
# Topic 'd+##ns&' related to ['d+##ns&', 'ss+##l&', 'proxy&', 'http&', 'ft+##p&']
# Topic 'unit+testing&' related to ['unit+testing&', 'testing&', 'design&', 'deployment&', 'validation&']
# Topic 'testing&' related to ['testing&', 'unit+testing&', 'deployment&', 'validation&', 'design&']
# Topic 'post+##gre+##s+##q+##l&' related to ['post+##gre+##s+##q+##l&', 'my+##s+##q+##l&', 'ts+##q+##l&', 'per+##l&', 'php&']
# Topic 'stored+procedures&' related to ['stored+procedures&', 'template+##s&', 'transactions&', 'triggers&', 'methods&']
# Topic 'data+##table&' related to ['data+##table&', 'data+##gr+##id&', 'database&', 'object&', 'grid+##view&']
# Topic 'html&' related to ['html&', 'cs+##s&', 'x+##sl+##t&', 'java+##script&', 'xml&']
# Topic 'c&' related to ['c&', 'c++++&', 'c+#&', 'st+##l&', 'f+#&']
# Topic 'flash&' related to ['flash&', 'silver+##light&', 'w+##pf&', 'fire+##fo+##x&', 'safari&']
# Topic 'video&' related to ['video&', 'audio&', 'flash&', 'animation&', 'image&']
# Topic 'powers+##hell&' related to ['powers+##hell&', 'em+##ac+##s&', 'shell&', 'v+##b+.+net&', 'os+##x&']
# Topic 'optimization&' related to ['optimization&', 'rec+##urs+##ion&', 'performance&', 'algorithm&', 'design&']
# Topic 'win+##forms&' related to ['win+##forms&', 'as+##p+.+net+mv+##c&', 'w+##pf&', 'j+##que+##ry&', 'x+##code&']
# Topic 'php&' related to ['php&', 'php+##my+##ad+##min&', 'my+##s+##q+##l&', 'post+##gre+##s+##q+##l&', 'java+##script&']
# Topic 'objective+c&' related to ['objective+c&', 'c++++&', 'c&', 'c+#&', 'python&']
# Topic 'function&' related to ['function&', 'construct+##or&', 'reference&', 'object&', 'class&']
# Topic 'pointer+##s&' related to ['pointer+##s&', 'variables&', 'arrays&', 'parameters&', 'methods&']
# Topic 'lin+##q&' related to ['lin+##q&', 'ts+##q+##l&', 'reg+##ex&', 'x+##am+##l&', 'pd+##o&']
# Topic 'string&' related to ['string&', 'reg+##ex&', 'input&', 'function&', 'st+##ru+##ct&']
# Topic 'as+##p+.+net+mv+##c&' related to ['as+##p+.+net+mv+##c&', 'as+##p+.+net&', 'win+##forms&', 'j+##que+##ry&', 'w+##pf&']
# Topic 'binding&' related to ['binding&', 'data+binding&', 'model&', 'reference&', 'construct+##or&']
# Topic 'flex&' related to ['flex&', 'st+##rut+##s+##2&', 'q+##t&', 'w+##pf&', 'flash&']
# Topic 'em+##ac+##s&' related to ['em+##ac+##s&', 'x+##code&', 'powers+##hell&', 'v+##b+.+net&', 'os+##x&']
# Topic 'up+##load&' related to ['up+##load&', 'download&', 'if+##ram+##e&', 'file&', 'build&']
# Topic 'python&' related to ['python&', 'java&', 'c++++&', 'per+##l&', 'c+#&']
# Topic 'sql+##ite&' related to ['sql+##ite&', 'sql&', 'post+##gre+##s+##q+##l&', 'my+##s+##q+##l&', 'oracle&']
# Topic 'sql+server+2008&' related to ['sql+server+2008&', 'sql+server+2005&', 'visual+studio+2008&', 'sql+server&', 'del+##phi&']
# Topic 'ii+##s&' related to ['ii+##s&', 'ss+##is&', 'j+##bos+##s&', 'wc+##f&', 'net+##be+##ans&']
# Topic 'ajax&' related to ['ajax&', 'j+##que+##ry&', 'java+##script&', 'php&', 'j+##son&']
# Topic 'performance&' related to ['performance&', 'optimization&', 'validation&', 'model&', 'memory+leaks&']
# Topic 'xml&' related to ['xml&', 'xp+##ath&', 'x+##sl+##t&', 'x+##sd&', 'j+##son&']
# Topic 'v+##bs+##cript&' related to ['v+##bs+##cript&', 'per+##l&', 'my+##s+##q+##l&', 'c+#&', 'j+##que+##ry&']
# Topic 'j+##sp&' related to ['j+##sp&', 'j+##son&', 'xp+##ath&', 'x+##sl+##t&', 'x+##am+##l&']
# Topic 'exception&' related to ['exception&', 'binding&', 'reference&', 'construct+##or&', 'function&']
# Topic 'open+##gl&' related to ['open+##gl&', 'em+##ac+##s&', 'silver+##light&', '.+net&', 'x+##code&']
# Topic 'actions+##cript+3&' related to ['actions+##cript+3&', 'v+##bs+##cript&', 'st+##rut+##s+##2&', 'w+##pf&', 'c++++&']
# Topic 'security&' related to ['security&', 'authentication&', 'encryption&', 'deployment&', 'ss+##is&']
# Topic 'menu&' related to ['menu&', 'view&', 'combo+##box&', 'hyper+##link&', 'button&']
# Topic 'vi+##m&' related to ['vi+##m&', 'x+##am+##l&', 'x+##code&', 'cm+##d&', 'j+##que+##ry&']
# Topic 'del+##phi&' related to ['del+##phi&', 'v+##b+.+net&', 'em+##ac+##s&', 'powers+##hell&', '.+net&']
# Topic 'design&' related to ['design&', 'o+##op&', 'model&', 'testing&', 'validation&']
# Topic 'outlook&' related to ['outlook&', 'word+##press&', 'sd+##k&', 'fire+##fo+##x&', 'cold+##fusion&']
# Topic 'spring&' related to ['spring&', 'st+##rut+##s+##2&', 'j+##sf&', 'hi+##ber+##nate&', 'jp+##a&']
# Topic 'or+##m&' related to ['or+##m&', 'nh+##ibe+##rna+##te&', 'post+##gre+##s+##q+##l&', 'j+##sf&', 'jp+##a&']
# Topic 'hash&' related to ['hash&', 'string&', 'insert&', 'reg+##ex&', 'select&']
# Topic 'data+structures&' related to ['data+structures&', 'types&', 'stored+procedures&', 'arrays&', 'collections&']
# Topic 'has+##kell&' related to ['has+##kell&', 'c++++&', 'c+#&', 'per+##l&', 'c&']
# Topic 'types&' related to ['types&', 'arrays&', 'methods&', 'variables&', 'properties&']
# Topic 'api&' related to ['api&', 'or+##m&', 'j+##sp&', 'wc+##f&', 'interface&']
# Topic 'ruby+on+rails&' related to ['ruby+on+rails&', '.+net&', 'as+##p+.+net&', 'ruby&', 'v+##b+.+net&']
# Topic 'cs+##s&' related to ['cs+##s&', 'html&', 'x+##sl+##t&', 'cs+##v&', 'w+##pf&']
# Topic 'grid+##view&' related to ['grid+##view&', 'data+##gr+##id+##view&', 'data+##gr+##id&', 'list+##view&', 'view&']
# Topic 'x+##code&' related to ['x+##code&', 'em+##ac+##s&', 'j+##que+##ry&', 'w+##pf&', 'powers+##hell&']
# Topic 'os+##x&' related to ['os+##x&', 'em+##ac+##s&', 'powers+##hell&', 'windows&', 'fire+##fo+##x&']
# Topic 'swing&' related to ['swing&', 'w+##pf&', 'st+##rut+##s+##2&', 'x+##code&', 'flex&']
# Topic 'silver+##light&' related to ['silver+##light&', 'w+##pf&', 'net+##be+##ans&', 'fire+##fo+##x&', 'sd+##k&']
# Topic 'dj+##ango&' related to ['dj+##ango&', 'j+##que+##ry&', 'as+##p+.+net+mv+##c&', 'my+##s+##q+##l&', 'v+##b+.+net&']
# Topic 'ur+##l&' related to ['ur+##l&', 'if+##ram+##e&', 'file&', 'reg+##ex&', 'path&']
# Topic 'index+##ing&' related to ['index+##ing&', 'sorting&', 'par+##sing&', 'ca+##ching&', 'pa+##gina+##tion&']
# Topic 'ca+##ching&' related to ['ca+##ching&', 'logging&', 'de+##bu+##gging&', 'serial+##ization&', 'pa+##gina+##tion&']
# Topic 'wc+##f&' related to ['wc+##f&', 'ft+##p&', 'proxy&', 'ss+##l&', 'ii+##s&']
# Topic 'session&' related to ['session&', 'log+##in&', 'file&', 'process&', 'if+##ram+##e&']
# Topic 'arrays&' related to ['arrays&', 'types&', 'pointer+##s&', 'loops&', 'variables&']
# Topic 'lambda&' related to ['lambda&', 'function&', 'construct+##or&', 'st+##ru+##ct&', 'lin+##q&']
# Topic 'o+##op&' related to ['o+##op&', 'w+##pf&', 'or+##m&', 'x+##am+##l&', 'lin+##q&']
# Topic 'pdf&' related to ['pdf&', 'cs+##v&', 'html&', 'cs+##s&', 'x+##sl+##t&']
# Topic 'import&' related to ['import&', 'dl+##l&', 'x+##am+##l&', 'j+##son&', 'j+##sp&']
# Topic 'eclipse&' related to ['eclipse&', 'net+##be+##ans&', 'silver+##light&', 'fire+##fo+##x&', '.+net&']
# Topic 'com&' related to ['com&', 'wc+##f&', 'm+##fc&', 'dl+##l&', 'command+line&']
# Topic 'per+##l&' related to ['per+##l&', 'st+##l&', 'my+##s+##q+##l&', 'c+#&', 'post+##gre+##s+##q+##l&']
# Topic 'forms&' related to ['forms&', 'template+##s&', 'parameters&', 'stored+procedures&', 'plug+##ins&']
# Topic 'if+##ram+##e&' related to ['if+##ram+##e&', 'ur+##l&', 'file&', 'up+##load&', 'auto+##com+##ple+##te&']
# Topic 'rec+##urs+##ion&' related to ['rec+##urs+##ion&', 'sorting&', 'algorithm&', 'par+##sing&', 'syntax&']
# Topic 'graphics&' related to ['graphics&', 'open+##gl&', '3d&', 'animation&', 'cs+##s&']
# Topic 'audio&' related to ['audio&', 'video&', 'ff+##mp+##eg&', 'bit+##ma+##p&', 'pdf&']
# Topic 'f+#&' related to ['f+#&', 'c+#&', 'c++++&', 'c&', 'st+##l&']
# Topic 'assembly&' related to ['assembly&', 'c&', 'c++++&', 'st+##l&', 'lu+##a&']
# Topic 'download&' related to ['download&', 'up+##load&', 'red+##ire+##ct&', 'log+##in&', 'if+##ram+##e&']
# Topic 'bash&' related to ['bash&', 'cm+##d&', 'shell&', 'vi+##m&', 'gr+##oo+##vy&']
# Topic 'web+applications&' related to ['web+applications&', 'web+services&', 'plug+##ins&', 'browser&', 'ii+##s&']
# Topic 'ft+##p&' related to ['ft+##p&', 'wc+##f&', 'proxy&', 'http&', 'ss+##l&']
# Topic 'ss+##is&' related to ['ss+##is&', 'ii+##s&', 'wc+##f&', 't+##fs&', 'j+##bos+##s&']
# Topic 'code+##ign+##iter&' related to ['code+##ign+##iter&', 'j+##que+##ry&', 'as+##p+.+net+mv+##c&', 'dj+##ango&', 'dr+##up+##al&']
# Topic 'zen+##d+framework&' related to ['zen+##d+framework&', 'net+##be+##ans&', 'entity+framework&', 'as+##p+.+net&', 'as+##p+.+net+mv+##c&']
# Topic 'encryption&' related to ['encryption&', 'authentication&', 'security&', 'serial+##ization&', 'ca+##ching&']
# Topic 't+##fs&' related to ['t+##fs&', 'ss+##is&', 'ii+##s&', 'wc+##f&', 'j+##bos+##s&']
# Topic 'nh+##ibe+##rna+##te&' related to ['nh+##ibe+##rna+##te&', 'hi+##ber+##nate&', 'or+##m&', 'lin+##q&', 'j+##que+##ry&']
# Topic 'ff+##mp+##eg&' related to ['ff+##mp+##eg&', 'audio&', 'w+##pf&', 'x+##code&', 'video&']
# Topic 'configuration&' related to ['configuration&', 'build&', 'ca+##ching&', 'up+##load&', 'logging&']
# Topic 'dom&' related to ['dom&', 'x+##am+##l&', 'dl+##l&', 'command+line&', 'j+##son&']
# Topic 'memory+leaks&' related to ['memory+leaks&', 'ca+##ching&', 'events&', 'transactions&', 'de+##bu+##gging&']
# Topic 'dictionary&' related to ['dictionary&', 'list&', 'reg+##ex&', 'string&', 'reference&']
# Topic 'properties&' related to ['properties&', 'methods&', 'parameters&', 'variables&', 'collections&']
# Topic 'command+line&' related to ['command+line&', 'dl+##l&', 'shell&', 'cm+##d&', 'auto+##com+##ple+##te&']
# Topic 'parameters&' related to ['parameters&', 'variables&', 'properties&', 'events&', 'pointer+##s&']
# Topic 'macro+##s&' related to ['macro+##s&', 'template+##s&', 'generic+##s&', 'stored+procedures&', 'plug+##ins&']
# Topic 'permission+##s&' related to ['permission+##s&', 'triggers&', 'events&', 'parameters&', 'stored+procedures&']
# Topic 'u+##bu+##nt+##u&' related to ['u+##bu+##nt+##u&', 'fire+##fo+##x&', 'os+##x&', '.+net&', 'powers+##hell&']
# Topic 'iphone&' related to ['iphone&', 'ios&', 'android&', 'mobile&', 'safari&']
# Topic 'reference&' related to ['reference&', 'function&', 'construct+##or&', 'object&', 'st+##ru+##ct&']
# Topic 'v+##ba&' related to ['v+##ba&', 'x+##am+##l&', 'dl+##l&', 'lu+##a&', 'w+##pf&']
# Topic 'cocoa&' related to ['cocoa&', 'net+##be+##ans&', 'java&', 'x+##code&', '.+net&']
# Topic 'events&' related to ['events&', 'triggers&', 'parameters&', 'variables&', 'permission+##s&']
# Topic 'time&' related to ['time&', 'date+##time&', 'date&', 'timer&', 'memory&']
# Topic 'win+##ap+##i&' related to ['win+##ap+##i&', 'm+##fc&', 'x+##code&', 'x+##am+##l&', 'w+##pf&']
# Topic 'routing&' related to ['routing&', 'ca+##ching&', 'pa+##gina+##tion&', 'log+##in&', '.+h+##ta+##cc+##ess&']
# Topic 'math&' related to ['math&', 'design&', 'syntax&', 'rec+##urs+##ion&', 'o+##op&']
# Topic 'path&' related to ['path&', 'dl+##l&', 'file&', 'class&', 'ur+##l&']
# Topic 'loops&' related to ['loops&', 'arrays&', 'methods&', 'pointer+##s&', 'collections&']
# Topic 'object&' related to ['object&', 'class&', 'construct+##or&', 'st+##ru+##ct&', 'reference&']
# Topic 'design+patterns&' related to ['design+patterns&', 'design&', 'data+structures&', 'stored+procedures&', 'template+##s&']
# Topic 'gi+##t&' related to ['gi+##t&', 'sv+##n&', 'cm+##d&', 'dl+##l&', 'w+##pf&']
# Topic 'pay+##pal&' related to ['pay+##pal&', 'facebook&', 'share+##point&', 'cold+##fusion&', 'youtube&']
# Topic 'scala&' related to ['scala&', 'java&', 'st+##l&', 'net+##be+##ans&', 'python&']
# Topic 'list&' related to ['list&', 'array+##list&', 'dictionary&', 'string&', 'reference&']
# Topic 'cake+##ph+##p&' related to ['cake+##ph+##p&', 'dr+##up+##al&', 'j+##que+##ry&', 'as+##p+.+net+mv+##c&', 'gr+##ail+##s&']
# Topic 'pd+##o&' related to ['pd+##o&', 'my+##s+##q+##l&', 'lin+##q&', 'ts+##q+##l&', 'per+##l&']
# Topic 'https&' related to ['https&', 'ss+##l&', 'http&', 'd+##ns&', 'ft+##p&']
# Topic 'variables&' related to ['variables&', 'parameters&', 'pointer+##s&', 'types&', 'methods&']
# Topic 'service&' related to ['service&', 'proxy&', 'wc+##f&', 'ft+##p&', 'ss+##is&']
# Topic 'st+##ru+##ct&' related to ['st+##ru+##ct&', 'object&', 'construct+##or&', 'reference&', 'function&']
# Topic 'safari&' related to ['safari&', 'fire+##fo+##x&', 'google+chrome&', 'silver+##light&', 'flash&']
# Topic 'auto+##com+##ple+##te&' related to ['auto+##com+##ple+##te&', 'x+##am+##l&', 'j+##que+##ry&', 'if+##ram+##e&', 'command+line&']
# Topic 'list+##view&' related to ['list+##view&', 'data+##gr+##id+##view&', 'data+##gr+##id&', 'grid+##view&', 'if+##ram+##e&']
# Topic 'jp+##a&' related to ['jp+##a&', 'or+##m&', 'oracle&', 'xp+##ath&', 'j+##sp&']
# Topic 'transactions&' related to ['transactions&', 'stored+procedures&', 'triggers&', 'events&', 'collections&']
# Topic 'encoding&' related to ['encoding&', 'bit+##ma+##p&', 'binary&', 'character+encoding&', 'xp+##ath&']
# Topic 'module&' related to ['module&', 'class&', 'construct+##or&', 'interface&', 'dl+##l&']
# Topic 'build&' related to ['build&', 'up+##load&', 'configuration&', 'de+##bu+##gging&', 'process&']
# Topic 'networking&' related to ['networking&', 'wc+##f&', 'tc+##p&', 'ft+##p&', 'ss+##l&']
# Topic 'post&' related to ['post&', 'red+##ire+##ct&', 'get&', 'ur+##l&', 'download&']
# Topic 'google+app+engine&' related to ['google+app+engine&', 'as+##p+.+net+mv+##c&', 'share+##point&', 'as+##p+.+net&', 'zen+##d+framework&']
# Topic 'file+up+##load&' related to ['file+up+##load&', 'up+##load&', 'ca+##ching&', 'download&', 'pa+##gina+##tion&']
# Topic 'jar&' related to ['jar&', 'dl+##l&', 'cm+##d&', 'gi+##t&', 'batch+file&']
# Topic 'facebook&' related to ['facebook&', 'twitter&', 'youtube&', 'word+##press&', 'dr+##up+##al&']
# Topic 'gr+##oo+##vy&' related to ['gr+##oo+##vy&', 'cl+##oj+##ure&', 'gr+##ail+##s&', 'j+##que+##ry&', 'vi+##m&']
# Topic 'mat+##lab&' related to ['mat+##lab&', 'python&', 'per+##l&', 'v+##b+.+net&', 'c++++&']
# Topic 'font+##s&' related to ['font+##s&', 'cs+##s&', 'forms&', 'html&', 'pdf&']
# Topic 'unix&' related to ['unix&', 'linux&', 'os+##x&', 'windows&', 'powers+##hell&']
# Topic 'shell&' related to ['shell&', 'cm+##d&', 'powers+##hell&', 'command+line&', 'per+##l&']
# Topic 'fore+##ach&' related to ['fore+##ach&', 'function&', 'construct+##or&', 'st+##ru+##ct&', 'reg+##ex&']
# Topic 'as+##yn+##ch+##ron+##ous&' related to ['as+##yn+##ch+##ron+##ous&', 'static&', 'dynamic&', 'fore+##ach&', 'de+##bu+##gging&']
# Topic 'tree&' related to ['tree&', 'graph&', 'list&', 'data+##table&', 'dictionary&']
# Topic 'active+##re+##cor+##d&' related to ['active+##re+##cor+##d&', 'rs+##pe+##c&', 'nh+##ibe+##rna+##te&', 'as+##p+.+net+mv+##c&', 'j+##que+##ry&']
# Topic 'array+##list&' related to ['array+##list&', 'list&', 'arrays&', 'string&', 'dictionary&']
# Topic 'reporting+services&' related to ['reporting+services&', 'web+services&', 'ss+##is&', 'sql+server&', 'web+applications&']
# Topic 'jd+##bc&' related to ['jd+##bc&', 'sql+##ite&', 'post+##gre+##s+##q+##l&', 'g+##cc&', 'oracle&']
# Topic 'search&' related to ['search&', 'list+##view&', 'if+##ram+##e&', 'pa+##gina+##tion&', 'ca+##ching&']
# Topic 'mobile&' related to ['mobile&', 'android&', 'iphone&', 'ios&', 'blue+##tooth&']
# Topic 'x+##am+##l&' related to ['x+##am+##l&', 'dl+##l&', 'w+##pf&', 'j+##son&', 'x+##sl+##t&']
# Topic 'triggers&' related to ['triggers&', 'events&', 'stored+procedures&', 'parameters&', 'transactions&']
# Topic 'cookies&' related to ['cookies&', 'ser+##v+##lets&', 'if+##ram+##e&', 'ca+##ching&', 'plug+##ins&']
# Topic 'visual+c++++&' related to ['visual+c++++&', 'c++++&', 'del+##phi&', 'objective+c&', 'visual+studio&']
# Topic 'construct+##or&' related to ['construct+##or&', 'function&', 'class&', 'object&', 'reference&']
# Topic 'ng+##in+##x&' related to ['ng+##in+##x&', 'tom+##cat&', 'sv+##n&', 'ss+##l&', 'ser+##v+##lets&']
# Topic 'cs+##v&' related to ['cs+##v&', 'j+##son&', 'xp+##ath&', 'x+##sl+##t&', 'j+##sp&']
# Topic 'binary&' related to ['binary&', 'encoding&', 'bit+##ma+##p&', 'string&', 'reg+##ex&']
# Topic 'get&' related to ['get&', 'post&', 'select&', 'replace&', 'red+##ire+##ct&']
# Topic 'sockets&' related to ['sockets&', 'ser+##v+##lets&', 'ft+##p&', 'd+##ns&', 'wc+##f&']
# Topic 'g+##wt&' related to ['g+##wt&', 'q+##t&', 'w+##pf&', 'wc+##f&', 'net+##be+##ans&']
# Topic 'j+##bos+##s&' related to ['j+##bos+##s&', 'ii+##s&', 'as+##p+.+net&', 'as+##p+.+net+mv+##c&', 'net+##be+##ans&']
# Topic 'java+ee&' related to ['java+ee&', 'java&', '.+net&', 'linux&', 'apache&']
# Topic 'memory+management&' related to ['memory+management&', 'exception+handling&', 'version+control&', 'ca+##ching&', 'logging&']
# Topic 'pa+##gina+##tion&' related to ['pa+##gina+##tion&', 'ca+##ching&', 'search&', 'list+##view&', 'routing&']
# Topic 'view&' related to ['view&', 'data+##gr+##id&', 'data+##gr+##id+##view&', 'grid+##view&', 'list+##view&']
# Topic 'nu+##mp+##y&' related to ['nu+##mp+##y&', 'per+##l&', 'vi+##m&', 'python&', 'st+##l&']
# Topic 'syntax&' related to ['syntax&', 'par+##sing&', 'ts+##q+##l&', 'lin+##q&', 'dictionary&']
# Topic 'boost&' related to ['boost&', 'g+##cc&', 'st+##l&', 'x+##am+##l&', 'dl+##l&']
# Topic 'count&' related to ['count&', 'select&', 'replace&', 'hash&', 'insert&']
# Topic '3d&' related to ['3d&', 'graphics&', 'open+##gl&', 'animation&', 'nu+##mp+##y&']
# Topic 'split&' related to ['split&', 'replace&', 'reg+##ex&', 'string&', 'select&']
# Topic 'multi+##th+##rea+##ding&' related to ['multi+##th+##rea+##ding&', 'ca+##ching&', 'de+##bu+##gging&', 'pa+##gina+##tion&', 'concurrency&']
# Topic 'ms+access&' related to ['ms+access&', 'ss+##is&', 'or+##m&', 'sql+##ite&', 'oracle&']
# Topic 'bit+##ma+##p&' related to ['bit+##ma+##p&', 'j+##son&', 'cs+##v&', 'encoding&', 'binary&']
# Topic 'interface&' related to ['interface&', 'module&', 'class&', 'controller&', 'api&']
# Topic 'plot&' related to ['plot&', 'scroll&', 'canvas&', 'layout&', 'colors&']
# Topic 'sorting&' related to ['sorting&', 'par+##sing&', 'index+##ing&', 'rec+##urs+##ion&', 'data+binding&']
# Topic 'net+##be+##ans&' related to ['net+##be+##ans&', '.+net&', 'java&', 'as+##p+.+net&', 'j+##bos+##s&']
# Topic 'dr+##up+##al&' related to ['dr+##up+##al&', 'j+##que+##ry&', 'as+##p+.+net+mv+##c&', 'dj+##ango&', 'silver+##light&']
# Topic 'matrix&' related to ['matrix&', 'vector&', 'array+##list&', 'rec+##urs+##ion&', 'hash&']
# Topic 'dependency+injection&' related to ['dependency+injection&', 'active+##re+##cor+##d&', 'multi+##th+##rea+##ding&', 'inheritance&', 'ca+##ching&']
# Topic 'timer&' related to ['timer&', 'combo+##box&', 'process&', 'session&', 'date+##time&']
# Topic 'for+loop&' related to ['for+loop&', 'reg+##ex&', 'while+loop&', 'batch+file&', 'get&']
# Topic 'database+design&' related to ['database+design&', 'design&', 'architecture&', 'or+##m&', 'entity+framework&']
# Topic 'intel+##li+##j+idea&' related to ['intel+##li+##j+idea&', 'eclipse&', 'dj+##ango&', 'as+##p+.+net+mv+##c&', 'jun+##it&']
# Topic 'button&' related to ['button&', 'scroll&', 'menu&', 'hyper+##link&', 'view&']
# Topic 'my+##s+##q+##li&' related to ['my+##s+##q+##li&', 'j+##son&', 'my+##s+##q+##l&', 'per+##l&', 'php+##my+##ad+##min&']
# Topic 'generic+##s&' related to ['generic+##s&', 'template+##s&', 'methods&', 'collections&', 'class&']
# Topic 'ms+word&' related to ['ms+word&', 'vi+##m&', 'cs+##s&', 'v+##bs+##cript&', 'reg+##ex&']
# Topic 'excel+v+##ba&' related to ['excel+v+##ba&', 'excel&', 'ms+word&', 'v+##ba&', 'vi+##m&']
# Topic 'data+##gr+##id&' related to ['data+##gr+##id&', 'data+##gr+##id+##view&', 'combo+##box&', 'list+##view&', 'reg+##ex&']
# Topic 'filter&' related to ['filter&', 'data+##gr+##id&', 'combo+##box&', 'list+##view&', 'data+##gr+##id+##view&']
# Topic 'google+maps&' related to ['google+maps&', 'ex+##t+##js&', 'map+##red+##uce&', 'share+##point&', 'as+##p+.+net+mv+##c&']
# Topic 'hyper+##link&' related to ['hyper+##link&', 'image&', 'view&', 'menu&', 'ur+##l&']
# Topic 'serial+##ization&' related to ['serial+##ization&', 'ca+##ching&', 'logging&', 'par+##sing&', 'j+##son&']
# Topic 'spring+security&' related to ['spring+security&', 'security&', 'authentication&', 'encryption&', 'ss+##h&']
# Topic 'google+analytics&' related to ['google+analytics&', 'google+app+engine&', 'google+maps&', 'share+##point&', 'j+##bos+##s&']
# Topic 'controller&' related to ['controller&', 'interface&', 'module&', 'process&', 'configuration&']
# Topic 'j+##son&' related to ['j+##son&', 'x+##sl+##t&', 'j+##sp&', 'xp+##ath&', 'x+##am+##l&']
# Topic 'jun+##it&' related to ['jun+##it&', 'rs+##pe+##c&', 'nh+##ibe+##rna+##te&', 'j+##sp&', 'j+##que+##ry&']
# Topic 'j+##sf&' related to ['j+##sf&', 'w+##pf&', 'j+##que+##ry&', 'j+##sp&', 'st+##rut+##s+##2&']
# Topic 'internet+explorer&' related to ['internet+explorer&', 'fire+##fo+##x&', 'as+##p+.+net&', '.+net&', 'sd+##k&']
# Topic 'batch+file&' related to ['batch+file&', 'file&', 'dl+##l&', 'command+line&', 'if+##ram+##e&']
# Topic 'replace&' related to ['replace&', 'insert&', 'select&', 'get&', 'string&']
# Topic 'lu+##a&' related to ['lu+##a&', 'st+##l&', 'dl+##l&', 'x+##am+##l&', 'j+##son&']
# Topic 'en+##ums&' related to ['en+##ums&', 'arrays&', 'types&', 'variables&', 'methods&']
# Topic 'st+##l&' related to ['st+##l&', 'c++++&', 'per+##l&', 'g+##cc&', 'c&']
# Topic 'data+##gr+##id+##view&' related to ['data+##gr+##id+##view&', 'data+##gr+##id&', 'list+##view&', 'grid+##view&', 'combo+##box&']
# Topic 'data+binding&' related to ['data+binding&', 'binding&', 'serial+##ization&', 'inheritance&', 'validation&']
# Topic 'curl&' related to ['curl&', 'lin+##q&', 'j+##que+##ry&', 'vi+##m&', 'st+##rut+##s+##2&']
# Topic 'join&' related to ['join&', 'select&', 'list&', 'hash&', 'replace&']
# Topic 'ex+##t+##js&' related to ['ex+##t+##js&', 'as+##p+.+net+mv+##c&', 'net+##be+##ans&', 'as+##p+.+net&', 'j+##que+##ry&']
# Topic 'select&' related to ['select&', 'insert&', 'replace&', 'get&', 'red+##ire+##ct&']
# Topic 'twitter&' related to ['twitter&', 'facebook&', 'word+##press&', 'dr+##up+##al&', 'email&']
# Topic 'tc+##p&' related to ['tc+##p&', 'ft+##p&', 'ss+##l&', 'd+##ns&', 'wc+##f&']
# Topic 'background&' related to ['background&', 'image&', 'hyper+##link&', 'menu&', 'canvas&']
# Topic 'charts&' related to ['charts&', 'cs+##s&', 'forms&', 'layout&', 'web+##forms&']
# Topic 'check+##box&' related to ['check+##box&', 'combo+##box&', 'data+##gr+##id&', 'reg+##ex&', 'if+##ram+##e&']
# Topic 'cu+##da&' related to ['cu+##da&', 'st+##l&', 'c&', 'c++++&', 'lu+##a&']
# Topic 'image+processing&' related to ['image+processing&', 'graphics&', 'animation&', '3d&', 'memory+management&']
# Topic 'red+##ire+##ct&' related to ['red+##ire+##ct&', 'post&', 'log+##in&', 'download&', 'if+##ram+##e&']
# Topic 'scope&' related to ['scope&', 'st+##ru+##ct&', 'object&', 'reference&', 'function&']
# Topic 'dl+##l&' related to ['dl+##l&', 'x+##am+##l&', 'j+##son&', 'st+##l&', 'command+line&']
# Topic 'date+##pic+##ker&' related to ['date+##pic+##ker&', 'auto+##com+##ple+##te&', 'if+##ram+##e&', 'j+##que+##ry&', '.+h+##ta+##cc+##ess&']
# Topic 'x+##sd&' related to ['x+##sd&', 'xml&', 'x+##sl+##t&', 'xp+##ath&', 'j+##sp&']
# Topic 'if+statement&' related to ['if+statement&', 'while+loop&', 'reference&', 'join&', 'function&']
# Topic 'had+##oop&' related to ['had+##oop&', 'em+##ac+##s&', 'open+##c+##v&', 'v+##b+.+net&', 'powers+##hell&']
# Topic 'vector&' related to ['vector&', 'string&', 'st+##ru+##ct&', 'matrix&', 'reference&']
# Topic 'cm+##d&' related to ['cm+##d&', 'shell&', 'powers+##hell&', 'em+##ac+##s&', 'gi+##t&']
# Topic 'amazon+s+##3&' related to ['amazon+s+##3&', 'dr+##up+##al&', 'cold+##fusion&', 'as+##p+.+net+mv+##c&', 'gi+##th+##ub&']
# Topic 'input&' related to ['input&', 'string&', 'function&', 'replace&', 'insert&']
# Topic 'open+##gl+es&' related to ['open+##gl+es&', 'open+##gl&', 'silver+##light&', 'em+##ac+##s&', 'fire+##fo+##x&']
# Topic 'c+#+4+.+0&' related to ['c+#+4+.+0&', 'visual+studio+2010&', 'as+##p+classic&', 'actions+##cript+3&', 'v+##b+.+net&']
# Topic 'error+handling&' related to ['error+handling&', 'exception+handling&', 'de+##bu+##gging&', 'ca+##ching&', 'validation&']
# Topic 'gi+##th+##ub&' related to ['gi+##th+##ub&', 'as+##p+.+net&', '.+net&', 'share+##point&', 'sv+##n&']
# Topic 'static&' related to ['static&', 'dynamic&', 'as+##yn+##ch+##ron+##ous&', 'fore+##ach&', 'object&']
# Topic 'open+##c+##v&' related to ['open+##c+##v&', 'silver+##light&', 'em+##ac+##s&', 'q+##t&', 'se+##len+##ium&']
# Topic 'model&' related to ['model&', 'binding&', 'validation&', 'construct+##or&', 'module&']
# Topic 'php+##my+##ad+##min&' related to ['php+##my+##ad+##min&', 'php&', 'my+##s+##q+##l&', 'post+##gre+##s+##q+##l&', 'my+##s+##q+##li&']
# Topic 'tab+##s&' related to ['tab+##s&', 'parameters&', 'menu&', 'template+##s&', 'events&']
# Topic 'ui+##table+##view&' related to ['ui+##table+##view&', 'ui+##sc+##roll+##view&', 'ui+##we+##b+##view&', 'grid+##view&', 'data+##gr+##id+##view&']
# Topic 'concurrency&' related to ['concurrency&', 'multi+##th+##rea+##ding&', 'ca+##ching&', 'memory+leaks&', 'rec+##urs+##ion&']
# Topic 'methods&' related to ['methods&', 'properties&', 'types&', 'generic+##s&', 'variables&']
# Topic 'azure&' related to ['azure&', 'share+##point&', '.+net&', 'as+##p+.+net&', 'ii+##s&']
# Topic 'st+##rut+##s+##2&' related to ['st+##rut+##s+##2&', 'j+##sf&', 'w+##pf&', 'q+##t&', 'm+##fc&']
# Topic 'as+##p+classic&' related to ['as+##p+classic&', 'v+##bs+##cript&', 'v+##b+.+net&', 'j+##que+##ry&', 'c+#&']
# Topic 'machine+learning&' related to ['machine+learning&', 'math&', 'mat+##lab&', 'algorithm&', 'image+processing&']
# Topic 'dynamic&' related to ['dynamic&', 'static&', 'as+##yn+##ch+##ron+##ous&', 'fore+##ach&', 'binary&']
# Topic 'web+##forms&' related to ['web+##forms&', 'win+##forms&', 'as+##p+.+net+mv+##c&', 'w+##pf&', 'j+##que+##ry&']
# Topic 'call+##back&' related to ['call+##back&', '.+h+##ta+##cc+##ess&', 'gi+##t&', 'post&', 'auto+##com+##ple+##te&']
# Topic 'aw+##k&' related to ['aw+##k&', 'reg+##ex&', 'se+##d&', 'nu+##mp+##y&', 'x+##am+##l&']
# Topic 'youtube&' related to ['youtube&', 'facebook&', 'word+##press&', 'dr+##up+##al&', 'share+##point&']
# Topic 'mv+##v+##m&' related to ['mv+##v+##m&', 'w+##pf&', 'as+##p+.+net+mv+##c&', 'm+##fc&', 'or+##m&']
# Topic 'canvas&' related to ['canvas&', 'image&', 'view&', 'background&', 'hyper+##link&']
# Topic 'java+##f+##x&' related to ['java+##f+##x&', 'had+##oop&', 'fire+##fo+##x&', 'eclipse&', 'silver+##light&']
# Topic 'ur+##l+re+##writing&' related to ['ur+##l+re+##writing&', 'mod+re+##write&', 'pa+##gina+##tion&', 'routing&', '.+h+##ta+##cc+##ess&']
# Topic 'null+##point+##ere+##x+##ception&' related to ['null+##point+##ere+##x+##ception&', 'exception&', 'for+loop&', 'get&', '.+h+##ta+##cc+##ess&']
# Topic 'web&' related to ['web&', 'share+##point&', 'facebook&', 'twitter&', 'browser&']
# Topic 'ser+##v+##lets&' related to ['ser+##v+##lets&', 'wc+##f&', 'as+##p+.+net+mv+##c&', 'ng+##in+##x&', 'post+##gre+##s+##q+##l&']
# Topic 'j+##que+##ry+ui&' related to ['j+##que+##ry+ui&', 'j+##que+##ry&', 'ui+##we+##b+##view&', 'ui+##view&', 'ui+##table+##view&']
# Topic 'log+##in&' related to ['log+##in&', 'session&', 'red+##ire+##ct&', 'download&', 'up+##load&']
# Topic 'ios&' related to ['ios&', 'iphone&', 'android&', 'mobile&', 'sd+##k&']
# Topic 'joo+##ml+##a&' related to ['joo+##ml+##a&', 'ex+##t+##js&', 'zen+##d+framework&', 'net+##be+##ans&', 'as+##p+.+net+mv+##c&']
# Topic 'while+loop&' related to ['while+loop&', 'for+loop&', 'string&', 'pointer+##s&', 'reference&']
# Topic 'windows+7&' related to ['windows+7&', 'windows&', 'visual+studio+2008&', 'visual+studio+2010&', 'sql+server+2005&']
# Topic 'camera&' related to ['camera&', 'flash&', 'silver+##light&', 'browser&', 'sd+##k&']
# Topic 'r&' related to ['r&', 'c&', 'st+##l&', 'f+#&', 'nu+##mp+##y&']
# Topic 'insert&' related to ['insert&', 'select&', 'replace&', 'red+##ire+##ct&', 'get&']
# Topic 'multi+##dim+##ens+##ional+array&' related to ['multi+##dim+##ens+##ional+array&', 'array+##list&', 'arrays&', 'data+##table&', 'st+##ru+##ct&']
# Topic 'spring+mv+##c&' related to ['spring+mv+##c&', 'java+##script&', 'as+##p+.+net+mv+##c&', 'as+##p+.+net&', 'ajax&']
# Topic 'cl+##oj+##ure&' related to ['cl+##oj+##ure&', 'gr+##oo+##vy&', 'nu+##mp+##y&', 'per+##l&', 'em+##ac+##s&']
# Topic 'mod+re+##write&' related to ['mod+re+##write&', 'ur+##l+re+##writing&', '.+h+##ta+##cc+##ess&', 'de+##bu+##gging&', 'make+##fi+##le&']
# Topic 'sd+##k&' related to ['sd+##k&', 'ii+##s&', 'as+##p+.+net+mv+##c&', 'as+##p+.+net&', 'share+##point&']
# Topic 'ui+##we+##b+##view&' related to ['ui+##we+##b+##view&', 'ui+##table+##view&', 'data+##gr+##id+##view&', 'if+##ram+##e&', 'ui+##sc+##roll+##view&']
# Topic 'compilation&' related to ['compilation&', 'serial+##ization&', 'binding&', 'par+##sing&', 'data+binding&']
# Topic 'graph&' related to ['graph&', 'tree&', 'data+##table&', 'grid+##view&', 'data+##gr+##id&']
# Topic 'mage+##nto&' related to ['mage+##nto&', 'pay+##pal&', 'facebook&', 'amazon+s+##3&', 'amazon+ec+##2&']
# Topic 'ui+##view&' related to ['ui+##view&', 'ui+##we+##b+##view&', 'ui+##table+##view&', 'ui+##sc+##roll+##view&', 'w+##pf&']
# Topic 'visual+studio+2010&' related to ['visual+studio+2010&', 'c+#+4+.+0&', 'visual+studio+2008&', 'visual+studio&', 'eclipse&']
# Topic 'cocoa+touch&' related to ['cocoa+touch&', 'active+##re+##cor+##d&', 'm+##fc&', 'as+##p+.+net+mv+##c&', 'win+##forms&']
# Topic 'character+encoding&' related to ['character+encoding&', 'encoding&', 'cs+##s&', 'x+##sl+##t&', 'par+##sing&']
# Topic 'mat+##pl+##ot+##lib&' related to ['mat+##pl+##ot+##lib&', 'gr+##oo+##vy&', 'nu+##mp+##y&', 'python&', 'em+##ac+##s&']
# Topic 'amazon+ec+##2&' related to ['amazon+ec+##2&', 'amazon+s+##3&', 'open+##c+##v&', 'tom+##cat&', 'fire+##fo+##x&']
# Topic 'ui+##sc+##roll+##view&' related to ['ui+##sc+##roll+##view&', 'ui+##table+##view&', 'ui+##we+##b+##view&', 'grid+##view&', 'ui+##view&']
# Topic 'core+data&' related to ['core+data&', 'data+##table&', 'object&', 'reference&', 'scope&']
# Topic 'ui+##view+##con+##tro+##ller&' related to ['ui+##view+##con+##tro+##ller&', 'ui+##we+##b+##view&', 'win+##forms&', 'plug+##ins&', 'controller&']
# Topic 'blue+##tooth&' related to ['blue+##tooth&', 'tc+##p&', 'networking&', 'mobile&', 'ss+##l&']
# Topic 'map+##red+##uce&' related to ['map+##red+##uce&', 'as+##p+.+net+mv+##c&', 'cake+##ph+##p&', 'pa+##gina+##tion&', 'active+##re+##cor+##d&']
# Topic 'sol+##r&' related to ['sol+##r&', 'reg+##ex&', 'lin+##q&', 'vi+##m&', 'pd+##o&']
# -------------------------
# Topic 'sv+##n&' related to ['sv+##n&', 'gi+##t&', 'wc+##f&', 'ng+##in+##x&', 'ft+##p&']
# Topic 'sql&' related to ['sql&', 'lin+##q+to+sql&', 'ts+##q+##l&', 'sql+##ite&', 'my+##s+##q+##l&']
# Topic 'as+##p+.+net&' related to ['as+##p+.+net&', '.+net&', 'as+##p+.+net+mv+##c&', 'share+##point&', 'v+##b+.+net&']
# Topic 'algorithm&' related to ['algorithm&', 'rec+##urs+##ion&', 'or+##m&', 'optimization&', 'nu+##mp+##y&']
# Topic 'colors&' related to ['colors&', 'background&', 'canvas&', 'image&', 'plot&']
# Topic 'c+#&' related to ['c+#&', 'c++++&', 'c&', 'f+#&', 'per+##l&']
# Topic '.+net&' related to ['.+net&', 'as+##p+.+net&', 'v+##b+.+net&', 'net+##be+##ans&', 'as+##p+.+net+mv+##c&']
# Topic 'c++++&' related to ['c++++&', 'c+#&', 'c&', 'st+##l&', 'per+##l&']
# Topic 'class&' related to ['class&', 'object&', 'construct+##or&', 'module&', 'function&']
# Topic 'web+services&' related to ['web+services&', 'reporting+services&', 'web+applications&', 'service&', 'ss+##is&']
# Topic 'sql+server&' related to ['sql+server&', 'ss+##is&', 'oracle&', 'as+##p+.+net&', 'share+##point&']
# Topic 'sql+server+2005&' related to ['sql+server+2005&', 'sql+server+2008&', 'sql+server&', 'visual+studio+2008&', 'j+##bos+##s&']
# Topic 'deployment&' related to ['deployment&', 'build&', 'configuration&', 'testing&', 'service&']
# Topic 'visual+studio&' related to ['visual+studio&', 'open+##gl&', 'silver+##light&', '.+net&', 'v+##b+.+net&']
# Topic 'windows&' related to ['windows&', 'os+##x&', 'linux&', 'ii+##s&', 'unix&']
# Topic 'database&' related to ['database&', 'jp+##a&', 'data+##table&', 'configuration&', 'or+##m&']
# Topic 'd+##ns&' related to ['d+##ns&', 'ss+##l&', 'proxy&', 'http&', 'ft+##p&']
# Topic 'unit+testing&' related to ['unit+testing&', 'testing&', 'design&', 'deployment&', 'validation&']
# Topic 'testing&' related to ['testing&', 'unit+testing&', 'deployment&', 'design&', 'validation&']
# Topic 'post+##gre+##s+##q+##l&' related to ['post+##gre+##s+##q+##l&', 'my+##s+##q+##l&', 'ts+##q+##l&', 'per+##l&', 'j+##que+##ry&']
# Topic 'stored+procedures&' related to ['stored+procedures&', 'template+##s&', 'transactions&', 'triggers&', 'methods&']
# Topic 'data+##table&' related to ['data+##table&', 'data+##gr+##id&', 'database&', 'object&', 'lin+##q&']
# Topic 'html&' related to ['html&', 'cs+##s&', 'x+##sl+##t&', 'java+##script&', 'j+##sp&']
# Topic 'c&' related to ['c&', 'c++++&', 'c+#&', 'st+##l&', 'f+#&']
# Topic 'flash&' related to ['flash&', 'silver+##light&', 'w+##pf&', 'j+##que+##ry&', 'safari&']
# Topic 'video&' related to ['video&', 'audio&', 'flash&', 'animation&', 'image&']
# Topic 'powers+##hell&' related to ['powers+##hell&', 'em+##ac+##s&', 'shell&', 'v+##b+.+net&', 'os+##x&']
# Topic 'optimization&' related to ['optimization&', 'rec+##urs+##ion&', 'performance&', 'algorithm&', 'design&']
# Topic 'win+##forms&' related to ['win+##forms&', 'as+##p+.+net+mv+##c&', 'w+##pf&', 'j+##que+##ry&', 'q+##t&']
# Topic 'php&' related to ['php&', 'my+##s+##q+##l&', 'post+##gre+##s+##q+##l&', 'j+##que+##ry&', 'java+##script&']
# Topic 'objective+c&' related to ['objective+c&', 'c++++&', 'c&', 'c+#&', 'python&']
# Topic 'function&' related to ['function&', 'construct+##or&', 'reference&', 'object&', 'st+##ru+##ct&']
# Topic 'pointer+##s&' related to ['pointer+##s&', 'variables&', 'arrays&', 'parameters&', 'methods&']
# Topic 'lin+##q&' related to ['lin+##q&', 'ts+##q+##l&', 'reg+##ex&', 'x+##am+##l&', 'pd+##o&']
# Topic 'string&' related to ['string&', 'reg+##ex&', 'input&', 'function&', 'dictionary&']
# Topic 'as+##p+.+net+mv+##c&' related to ['as+##p+.+net+mv+##c&', 'as+##p+.+net&', 'win+##forms&', 'j+##que+##ry&', 'w+##pf&']
# Topic 'binding&' related to ['binding&', 'data+binding&', 'model&', 'reference&', 'scope&']
# Topic 'flex&' related to ['flex&', 'q+##t&', 'w+##pf&', 'st+##rut+##s+##2&', 'flash&']
# Topic 'em+##ac+##s&' related to ['em+##ac+##s&', 'powers+##hell&', 'x+##code&', 'v+##b+.+net&', 'os+##x&']
# Topic 'up+##load&' related to ['up+##load&', 'download&', 'if+##ram+##e&', 'file&', 'build&']
# Topic 'python&' related to ['python&', 'java&', 'per+##l&', 'c++++&', 'c+#&']
# Topic 'sql+##ite&' related to ['sql+##ite&', 'sql&', 'post+##gre+##s+##q+##l&', 'my+##s+##q+##l&', 'oracle&']
# Topic 'sql+server+2008&' related to ['sql+server+2008&', 'sql+server+2005&', 'visual+studio+2008&', 'sql+server&', 'del+##phi&']
# Topic 'ii+##s&' related to ['ii+##s&', 'ss+##is&', 'j+##bos+##s&', 'wc+##f&', 't+##fs&']
# Topic 'ajax&' related to ['ajax&', 'j+##que+##ry&', 'java+##script&', 'php&', 'j+##son&']
# Topic 'performance&' related to ['performance&', 'optimization&', 'model&', 'validation&', 'rec+##urs+##ion&']
# Topic 'xml&' related to ['xml&', 'xp+##ath&', 'x+##sl+##t&', 'x+##sd&', 'j+##son&']
# Topic 'v+##bs+##cript&' related to ['v+##bs+##cript&', 'per+##l&', 'my+##s+##q+##l&', 'j+##que+##ry&', 'c+#&']
# Topic 'j+##sp&' related to ['j+##sp&', 'j+##son&', 'x+##sl+##t&', 'xp+##ath&', 'x+##am+##l&']
# Topic 'exception&' related to ['exception&', 'binding&', 'reference&', 'construct+##or&', 'function&']
# Topic 'open+##gl&' related to ['open+##gl&', 'em+##ac+##s&', 'silver+##light&', '.+net&', 'x+##code&']
# Topic 'actions+##cript+3&' related to ['actions+##cript+3&', 'v+##bs+##cript&', 'st+##rut+##s+##2&', 'w+##pf&', 'powers+##hell&']
# Topic 'security&' related to ['security&', 'authentication&', 'encryption&', 'deployment&', 'logging&']
# Topic 'menu&' related to ['menu&', 'view&', 'combo+##box&', 'hyper+##link&', 'button&']
# Topic 'vi+##m&' related to ['vi+##m&', 'x+##am+##l&', 'w+##pf&', 'j+##que+##ry&', 'x+##code&']
# ...
# Topic 'as+##yn+##ch+##ron+##ous&' related to ['as+##yn+##ch+##ron+##ous&', 'static&', 'dynamic&', 'de+##bu+##gging&', 'random&']
# Topic 'tree&' related to ['tree&', 'graph&', 'list&', 'dictionary&', 'data+##table&']
# Topic 'active+##re+##cor+##d&' related to ['active+##re+##cor+##d&', 'nh+##ibe+##rna+##te&', 'rs+##pe+##c&', 'as+##p+.+net+mv+##c&', 'j+##que+##ry&']
# Topic 'array+##list&' related to ['array+##list&', 'list&', 'arrays&', 'string&', 'dictionary&']
# Topic 'reporting+services&' related to ['reporting+services&', 'web+services&', 'ss+##is&', 'sql+server&', 'share+##point&']
# Topic 'jd+##bc&' related to ['jd+##bc&', 'sql+##ite&', 'post+##gre+##s+##q+##l&', 'g+##cc&', 'my+##s+##q+##l&']
# Topic 'search&' related to ['search&', 'list+##view&', 'if+##ram+##e&', 'ca+##ching&', 'auto+##com+##ple+##te&']
# Topic 'mobile&' related to ['mobile&', 'android&', 'iphone&', 'ios&', 'windows&']
# Topic 'x+##am+##l&' related to ['x+##am+##l&', 'dl+##l&', 'w+##pf&', 'j+##son&', 'x+##sl+##t&']
# Topic 'triggers&' related to ['triggers&', 'events&', 'stored+procedures&', 'transactions&', 'parameters&']
# Topic 'cookies&' related to ['cookies&', 'ser+##v+##lets&', 'if+##ram+##e&', 'ca+##ching&', 'plug+##ins&']
# Topic 'visual+c++++&' related to ['visual+c++++&', 'c++++&', 'del+##phi&', 'objective+c&', 'visual+studio&']
# Topic 'construct+##or&' related to ['construct+##or&', 'function&', 'class&', 'object&', 'reference&']
# Topic 'ng+##in+##x&' related to ['ng+##in+##x&', 'tom+##cat&', 'sv+##n&', 'ss+##l&', 'ser+##v+##lets&']
# Topic 'cs+##v&' related to ['cs+##v&', 'j+##son&', 'xp+##ath&', 'x+##sl+##t&', 'j+##sp&']
# Topic 'binary&' related to ['binary&', 'encoding&', 'bit+##ma+##p&', 'string&', 'reg+##ex&']
# Topic 'get&' related to ['get&', 'post&', 'select&', 'replace&', 'red+##ire+##ct&']
# Topic 'sockets&' related to ['sockets&', 'ser+##v+##lets&', 'ft+##p&', 'wc+##f&', 'd+##ns&']
# Topic 'g+##wt&' related to ['g+##wt&', 'q+##t&', 'w+##pf&', 'wc+##f&', 'net+##be+##ans&']
# Topic 'j+##bos+##s&' related to ['j+##bos+##s&', 'ii+##s&', 'as+##p+.+net+mv+##c&', 'as+##p+.+net&', 'cold+##fusion&']
# Topic 'java+ee&' related to ['java+ee&', 'java&', '.+net&', 'apache&', 'linux&']
# Topic 'memory+management&' related to ['memory+management&', 'exception+handling&', 'version+control&', 'ca+##ching&', 'logging&']
# Topic 'pa+##gina+##tion&' related to ['pa+##gina+##tion&', 'ca+##ching&', 'search&', 'list+##view&', 'routing&']
# Topic 'view&' related to ['view&', 'data+##gr+##id+##view&', 'data+##gr+##id&', 'grid+##view&', 'list+##view&']
# Topic 'nu+##mp+##y&' related to ['nu+##mp+##y&', 'vi+##m&', 'per+##l&', 'python&', 'x+##am+##l&']
# Topic 'syntax&' related to ['syntax&', 'par+##sing&', 'lin+##q&', 'ts+##q+##l&', 'reg+##ex&']
# Topic 'boost&' related to ['boost&', 'g+##cc&', 'st+##l&', 'w+##pf&', 'x+##am+##l&']
# Topic 'count&' related to ['count&', 'select&', 'replace&', 'split&', 'insert&']
# Topic '3d&' related to ['3d&', 'graphics&', 'open+##gl&', 'animation&', 'nu+##mp+##y&']
# Topic 'split&' related to ['split&', 'replace&', 'reg+##ex&', 'string&', 'select&']
# Topic 'multi+##th+##rea+##ding&' related to ['multi+##th+##rea+##ding&', 'ca+##ching&', 'de+##bu+##gging&', 'concurrency&', 'logging&']
# Topic 'ms+access&' related to ['ms+access&', 'ss+##is&', 'or+##m&', 'sql+##ite&', 'oracle&']
# Topic 'bit+##ma+##p&' related to ['bit+##ma+##p&', 'j+##son&', 'cs+##v&', 'encoding&', 'binary&']
# Topic 'interface&' related to ['interface&', 'module&', 'class&', 'api&', 'controller&']
# Topic 'plot&' related to ['plot&', 'scroll&', 'canvas&', 'layout&', 'colors&']
# Topic 'sorting&' related to ['sorting&', 'par+##sing&', 'index+##ing&', 'rec+##urs+##ion&', 'binding&']
# Topic 'net+##be+##ans&' related to ['net+##be+##ans&', '.+net&', 'java&', 'as+##p+.+net&', 'ii+##s&']
# Topic 'dr+##up+##al&' related to ['dr+##up+##al&', 'j+##que+##ry&', 'as+##p+.+net+mv+##c&', 'dj+##ango&', 'silver+##light&']
# Topic 'matrix&' related to ['matrix&', 'vector&', 'rec+##urs+##ion&', 'hash&', 'reg+##ex&']
# Topic 'dependency+injection&' related to ['dependency+injection&', 'active+##re+##cor+##d&', 'de+##bu+##gging&', 'ca+##ching&', 'logging&']
# Topic 'timer&' related to ['timer&', 'combo+##box&', 'process&', 'date+##time&', 'data+##gr+##id&']
# Topic 'for+loop&' related to ['for+loop&', 'reg+##ex&', 'replace&', 'batch+file&', 'split&']
# Topic 'database+design&' related to ['database+design&', 'design&', 'architecture&', 'or+##m&', 'testing&']
# Topic 'intel+##li+##j+idea&' related to ['intel+##li+##j+idea&', 'eclipse&', 'dj+##ango&', 'j+##que+##ry&', 'jun+##it&']
# Topic 'button&' related to ['button&', 'scroll&', 'menu&', 'hyper+##link&', 'view&']
# Topic 'my+##s+##q+##li&' related to ['my+##s+##q+##li&', 'j+##son&', 'my+##s+##q+##l&', 'per+##l&', 'post+##gre+##s+##q+##l&']
# Topic 'generic+##s&' related to ['generic+##s&', 'template+##s&', 'collections&', 'methods&', 'properties&']
# Topic 'ms+word&' related to ['ms+word&', 'vi+##m&', 'cs+##s&', 'reg+##ex&', 'v+##bs+##cript&']
# Topic 'excel+v+##ba&' related to ['excel+v+##ba&', 'excel&', 'v+##ba&', 'vi+##m&', 'dj+##ango&']
# Topic 'data+##gr+##id&' related to ['data+##gr+##id&', 'data+##gr+##id+##view&', 'combo+##box&', 'reg+##ex&', 'list+##view&']
# Topic 'filter&' related to ['filter&', 'data+##gr+##id&', 'combo+##box&', 'data+##gr+##id+##view&', 'list+##view&']
# Topic 'google+maps&' related to ['google+maps&', 'ex+##t+##js&', 'share+##point&', 'as+##p+.+net+mv+##c&', 'map+##red+##uce&']
# Topic 'hyper+##link&' related to ['hyper+##link&', 'image&', 'view&', 'menu&', 'ur+##l&']
# Topic 'serial+##ization&' related to ['serial+##ization&', 'ca+##ching&', 'logging&', 'par+##sing&', 'j+##son&']
# Topic 'spring+security&' related to ['spring+security&', 'security&', 'authentication&', 'encryption&', 'gr+##ail+##s&']
# Topic 'google+analytics&' related to ['google+analytics&', 'google+app+engine&', 'google+maps&', 'share+##point&', 'j+##bos+##s&']
# Topic 'controller&' related to ['controller&', 'interface&', 'module&', 'process&', 'configuration&']
# Topic 'j+##son&' related to ['j+##son&', 'j+##sp&', 'x+##sl+##t&', 'xp+##ath&', 'x+##am+##l&']
# Topic 'jun+##it&' related to ['jun+##it&', 'rs+##pe+##c&', 'nh+##ibe+##rna+##te&', 'j+##que+##ry&', 'q+##t&']
# Topic 'j+##sf&' related to ['j+##sf&', 'w+##pf&', 'j+##que+##ry&', 'j+##sp&', 'st+##rut+##s+##2&']
# Topic 'internet+explorer&' related to ['internet+explorer&', 'fire+##fo+##x&', 'as+##p+.+net&', '.+net&', 'sd+##k&']
# Topic 'batch+file&' related to ['batch+file&', 'file&', 'dl+##l&', 'command+line&', 'if+##ram+##e&']
# Topic 'replace&' related to ['replace&', 'insert&', 'select&', 'reg+##ex&', 'get&']
# Topic 'lu+##a&' related to ['lu+##a&', 'st+##l&', 'dl+##l&', 'x+##am+##l&', 'j+##son&']
# Topic 'en+##ums&' related to ['en+##ums&', 'arrays&', 'types&', 'variables&', 'loops&']
# Topic 'st+##l&' related to ['st+##l&', 'c++++&', 'per+##l&', 'g+##cc&', 'c&']
# Topic 'data+##gr+##id+##view&' related to ['data+##gr+##id+##view&', 'data+##gr+##id&', 'grid+##view&', 'list+##view&', 'if+##ram+##e&']
# Topic 'data+binding&' related to ['data+binding&', 'binding&', 'serial+##ization&', 'validation&', 'inheritance&']
# Topic 'curl&' related to ['curl&', 'lin+##q&', 'vi+##m&', 'j+##que+##ry&', 'st+##rut+##s+##2&']
# Topic 'join&' related to ['join&', 'select&', 'list&', 'replace&', 'hash&']
# Topic 'ex+##t+##js&' related to ['ex+##t+##js&', 'as+##p+.+net+mv+##c&', 'net+##be+##ans&', 'j+##que+##ry&', 'as+##p+.+net&']
# Topic 'select&' related to ['select&', 'insert&', 'replace&', 'get&', 'split&']
# Topic 'twitter&' related to ['twitter&', 'facebook&', 'dr+##up+##al&', 'word+##press&', 'email&']
# Topic 'tc+##p&' related to ['tc+##p&', 'ft+##p&', 'ss+##l&', 'd+##ns&', 'wc+##f&']
# Topic 'background&' related to ['background&', 'image&', 'canvas&', 'menu&', 'view&']
# Topic 'charts&' related to ['charts&', 'layout&', 'cs+##s&', 'forms&', 'web+##forms&']
# Topic 'check+##box&' related to ['check+##box&', 'combo+##box&', 'data+##gr+##id&', 'reg+##ex&', 'if+##ram+##e&']
# Topic 'cu+##da&' related to ['cu+##da&', 'st+##l&', 'c&', 'c++++&', 'lu+##a&']
# Topic 'image+processing&' related to ['image+processing&', 'graphics&', 'animation&', 'design&', 'printing&']
# Topic 'red+##ire+##ct&' related to ['red+##ire+##ct&', 'post&', 'log+##in&', 'download&', 'if+##ram+##e&']
# Topic 'scope&' related to ['scope&', 'st+##ru+##ct&', 'object&', 'reference&', 'function&']
# Topic 'dl+##l&' related to ['dl+##l&', 'x+##am+##l&', 'j+##son&', 'st+##l&', 'command+line&']
# Topic 'date+##pic+##ker&' related to ['date+##pic+##ker&', 'auto+##com+##ple+##te&', 'if+##ram+##e&', 'nh+##ibe+##rna+##te&', 'j+##que+##ry&']
# Topic 'x+##sd&' related to ['x+##sd&', 'xml&', 'x+##sl+##t&', 'xp+##ath&', 'j+##sp&']
# Topic 'if+statement&' related to ['if+statement&', 'reference&', 'join&', 'function&', 'string&']
# Topic 'had+##oop&' related to ['had+##oop&', 'em+##ac+##s&', 'open+##c+##v&', 'v+##b+.+net&', 'powers+##hell&']
# Topic 'vector&' related to ['vector&', 'string&', 'st+##ru+##ct&', 'reference&', 'matrix&']
# Topic 'cm+##d&' related to ['cm+##d&', 'shell&', 'powers+##hell&', 'em+##ac+##s&', 'gi+##t&']
# Topic 'amazon+s+##3&' related to ['amazon+s+##3&', 'dr+##up+##al&', 'cold+##fusion&', 'as+##p+.+net+mv+##c&', 'tom+##cat&']
# Topic 'input&' related to ['input&', 'string&', 'function&', 'replace&', 'reg+##ex&']
# Topic 'open+##gl+es&' related to ['open+##gl+es&', 'open+##gl&', 'silver+##light&', 'em+##ac+##s&', 'os+##x&']
# Topic 'c+#+4+.+0&' related to ['c+#+4+.+0&', 'visual+studio+2010&', 'v+##b+.+net&', 'as+##p+classic&', 'actions+##cript+3&']
# Topic 'error+handling&' related to ['error+handling&', 'de+##bu+##gging&', 'ca+##ching&', 'exception+handling&', 'validation&']
# Topic 'gi+##th+##ub&' related to ['gi+##th+##ub&', 'as+##p+.+net&', '.+net&', 'sv+##n&', 'share+##point&']
# Topic 'static&' related to ['static&', 'dynamic&', 'as+##yn+##ch+##ron+##ous&', 'fore+##ach&', 'object&']
# Topic 'open+##c+##v&' related to ['open+##c+##v&', 'silver+##light&', 'em+##ac+##s&', 'q+##t&', 'se+##len+##ium&']
# Topic 'model&' related to ['model&', 'binding&', 'validation&', 'module&', 'construct+##or&']
# Topic 'php+##my+##ad+##min&' related to ['php+##my+##ad+##min&', 'php&', 'my+##s+##q+##l&', 'my+##s+##q+##li&', 'post+##gre+##s+##q+##l&']
# Topic 'tab+##s&' related to ['tab+##s&', 'parameters&', 'menu&', 'template+##s&', 'events&']
# Topic 'ui+##table+##view&' related to ['ui+##table+##view&', 'ui+##sc+##roll+##view&', 'ui+##we+##b+##view&', 'grid+##view&', 'w+##pf&']
# Topic 'concurrency&' related to ['concurrency&', 'multi+##th+##rea+##ding&', 'ca+##ching&', 'rec+##urs+##ion&', 'memory+leaks&']
# Topic 'methods&' related to ['methods&', 'properties&', 'types&', 'generic+##s&', 'variables&']
# Topic 'azure&' related to ['azure&', 'share+##point&', '.+net&', 'as+##p+.+net&', 'ii+##s&']
# Topic 'st+##rut+##s+##2&' related to ['st+##rut+##s+##2&', 'j+##sf&', 'w+##pf&', 'q+##t&', 'm+##fc&']
# Topic 'as+##p+classic&' related to ['as+##p+classic&', 'v+##bs+##cript&', 'v+##b+.+net&', 'j+##que+##ry&', 'em+##ac+##s&']
# Topic 'machine+learning&' related to ['machine+learning&', 'math&', 'algorithm&', 'mat+##lab&', 'or+##m&']
# Topic 'dynamic&' related to ['dynamic&', 'static&', 'as+##yn+##ch+##ron+##ous&', 'binary&', 'binding&']
# Topic 'web+##forms&' related to ['web+##forms&', 'win+##forms&', 'as+##p+.+net+mv+##c&', 'w+##pf&', 'j+##que+##ry&']
# Topic 'call+##back&' related to ['call+##back&', '.+h+##ta+##cc+##ess&', 'gi+##t&', 'post&', 'auto+##com+##ple+##te&']
# Topic 'aw+##k&' related to ['aw+##k&', 'reg+##ex&', 'nu+##mp+##y&', 'vi+##m&', 'per+##l&']
# Topic 'youtube&' related to ['youtube&', 'facebook&', 'dr+##up+##al&', 'word+##press&', 'share+##point&']
# Topic 'mv+##v+##m&' related to ['mv+##v+##m&', 'w+##pf&', 'as+##p+.+net+mv+##c&', 'm+##fc&', 'or+##m&']
# Topic 'canvas&' related to ['canvas&', 'image&', 'view&', 'background&', 'scroll&']
# Topic 'java+##f+##x&' related to ['java+##f+##x&', 'had+##oop&', 'fire+##fo+##x&', 'silver+##light&', 'eclipse&']
# Topic 'ur+##l+re+##writing&' related to ['ur+##l+re+##writing&', 'mod+re+##write&', 'routing&', 'de+##bu+##gging&', 'pa+##gina+##tion&']
# Topic 'null+##point+##ere+##x+##ception&' related to ['null+##point+##ere+##x+##ception&', 'exception&', 'for+loop&', 'get&', '.+h+##ta+##cc+##ess&']
# Topic 'web&' related to ['web&', 'share+##point&', 'facebook&', 'twitter&', 'browser&']
# Topic 'ser+##v+##lets&' related to ['ser+##v+##lets&', 'wc+##f&', 'as+##p+.+net+mv+##c&', 'ng+##in+##x&', 'post+##gre+##s+##q+##l&']
# Topic 'j+##que+##ry+ui&' related to ['j+##que+##ry+ui&', 'j+##que+##ry&', 'ui+##we+##b+##view&', 'dj+##ango&', 'ui+##table+##view&']
# Topic 'log+##in&' related to ['log+##in&', 'session&', 'red+##ire+##ct&', 'download&', 'if+##ram+##e&']
# Topic 'ios&' related to ['ios&', 'iphone&', 'android&', 'mobile&', 'sd+##k&']
# Topic 'joo+##ml+##a&' related to ['joo+##ml+##a&', 'ex+##t+##js&', 'net+##be+##ans&', 'as+##p+.+net+mv+##c&', 'zen+##d+framework&']
# Topic 'while+loop&' related to ['while+loop&', 'for+loop&', 'string&', 'pointer+##s&', 'reference&']
# Topic 'windows+7&' related to ['windows+7&', 'windows&', 'visual+studio+2008&', 'visual+studio+2010&', 'sql+server+2005&']
# Topic 'camera&' related to ['camera&', 'flash&', 'silver+##light&', 'browser&', 'sd+##k&']
# Topic 'r&' related to ['r&', 'c&', 'f+#&', 'nu+##mp+##y&', 'st+##l&']
# Topic 'insert&' related to ['insert&', 'select&', 'replace&', 'red+##ire+##ct&', 'get&']
# Topic 'multi+##dim+##ens+##ional+array&' related to ['multi+##dim+##ens+##ional+array&', 'array+##list&', 'arrays&', 'data+##table&', 'st+##ru+##ct&']
# Topic 'spring+mv+##c&' related to ['spring+mv+##c&', 'java+##script&', 'as+##p+.+net+mv+##c&', 'as+##p+.+net&', 'ajax&']
# Topic 'cl+##oj+##ure&' related to ['cl+##oj+##ure&', 'gr+##oo+##vy&', 'nu+##mp+##y&', 'per+##l&', 'dj+##ango&']
# Topic 'mod+re+##write&' related to ['mod+re+##write&', 'ur+##l+re+##writing&', '.+h+##ta+##cc+##ess&', 'de+##bu+##gging&', 'make+##fi+##le&']
# Topic 'sd+##k&' related to ['sd+##k&', 'ii+##s&', 'as+##p+.+net+mv+##c&', 'as+##p+.+net&', 'share+##point&']
# Topic 'ui+##we+##b+##view&' related to ['ui+##we+##b+##view&', 'ui+##table+##view&', 'data+##gr+##id+##view&', 'if+##ram+##e&', 'w+##pf&']
# Topic 'compilation&' related to ['compilation&', 'serial+##ization&', 'binding&', 'par+##sing&', 'data+binding&']
# Topic 'graph&' related to ['graph&', 'tree&', 'data+##table&', 'grid+##view&', 'data+##gr+##id+##view&']
# Topic 'mage+##nto&' related to ['mage+##nto&', 'pay+##pal&', 'facebook&', 'amazon+s+##3&', 'tom+##cat&']
# Topic 'ui+##view&' related to ['ui+##view&', 'ui+##we+##b+##view&', 'ui+##table+##view&', 'ui+##sc+##roll+##view&', 'w+##pf&']
# Topic 'visual+studio+2010&' related to ['visual+studio+2010&', 'c+#+4+.+0&', 'visual+studio+2008&', 'visual+studio&', 'silver+##light&']
# Topic 'cocoa+touch&' related to ['cocoa+touch&', 'active+##re+##cor+##d&', 'm+##fc&', 'as+##p+.+net+mv+##c&', 'q+##t&']
# Topic 'character+encoding&' related to ['character+encoding&', 'encoding&', 'cs+##s&', 'x+##sl+##t&', 'par+##sing&']
# Topic 'mat+##pl+##ot+##lib&' related to ['mat+##pl+##ot+##lib&', 'gr+##oo+##vy&', 'nu+##mp+##y&', 'python&', 'em+##ac+##s&']
# Topic 'amazon+ec+##2&' related to ['amazon+ec+##2&', 'amazon+s+##3&', 'tom+##cat&', 'open+##c+##v&', 'fire+##fo+##x&']
# Topic 'ui+##sc+##roll+##view&' related to ['ui+##sc+##roll+##view&', 'ui+##table+##view&', 'ui+##we+##b+##view&', 'grid+##view&', 'ui+##view&']
# Topic 'core+data&' related to ['core+data&', 'data+##table&', 'object&', 'reference&', 'list&']
# Topic 'ui+##view+##con+##tro+##ller&' related to ['ui+##view+##con+##tro+##ller&', 'ui+##we+##b+##view&', 'win+##forms&', 'plug+##ins&', 'ui+##table+##view&']
# Topic 'blue+##tooth&' related to ['blue+##tooth&', 'tc+##p&', 'networking&', 'mobile&', 'ss+##l&']
# Topic 'map+##red+##uce&' related to ['map+##red+##uce&', 'as+##p+.+net+mv+##c&', 'cake+##ph+##p&', 'active+##re+##cor+##d&', 'j+##que+##ry&']
# Topic 'sol+##r&' related to ['sol+##r&', 'reg+##ex&', 'lin+##q&', 'vi+##m&', 'pd+##o&']
# -------------------------

# %% [raw]
# import pdb
# pdb.pm()
